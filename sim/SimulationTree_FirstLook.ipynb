# %%
from standardInclude import *
# Out:
# Welcome to JupyROOT 6.12/06
# For interactive plots, run: setint()
# To return to non-interactive plots (default state), run: noint()

# %%
#f = r.TFile("./SimuTreeMaker.root")
f = r.TFile("./data/gm2offline_ana.root")
f.cd("SimuTreeMaker")
f.ls()
# Out:
# TFile**		./data/gm2offline_ana.root
#  TFile*		./data/gm2offline_ana.root
#   TDirectoryFile*		SimuTreeMaker	SimuTreeMaker (SimuTreeMaker) folder
#    KEY: TTree	gm2ringsimTree;2	gm2ringsimTree
#    KEY: TTree	gm2ringsimTree;1	gm2ringsimTree
#   KEY: TDirectoryFile	SimuTreeMaker;1	SimuTreeMaker (SimuTreeMaker) folder

# %%
t = f.Get("SimuTreeMaker").Get("gm2ringsimTree")
t.Print()
# Out:
# ******************************************************************************
# *Tree    :gm2ringsimTree: gm2ringsimTree                                         *
# *Entries :     4000 : Total =       209471971 bytes  File  Size =   37358567 *
# *        :          : Tree compression factor =   5.61                       *
# ******************************************************************************
# *Br    0 :runNum    : runNum/I                                               *
# *Entries :     4000 : Total  Size=      16655 bytes  File Size  =        322 *
# *Baskets :        2 : Basket Size=      39936 bytes  Compression=  50.20     *
# *............................................................................*
# *Br    1 :subRunNum : subRunNum/I                                            *
# *Entries :     4000 : Total  Size=      16673 bytes  File Size  =        323 *
# *Baskets :        2 : Basket Size=      39936 bytes  Compression=  50.07     *
# ...

# %%
c = r.TCanvas("c","c",1500,500)
c.Divide(3)
c.cd(1)
t.Draw("muDecayPx")
c.cd(2)
t.Draw("muDecayPy")
c.cd(3)
t.Draw("muDecayPz")
c.Draw()

# %%
c = r.TCanvas("c","c",1500,500)
c.Divide(3)
c.cd(1)
t.Draw("muDecayPr")
c.cd(2)
t.Draw("muDecayPtheta")
c.cd(3)
t.Draw("muDecayPyrel")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
c = r.TCanvas("c","c",1500,500)
c.Divide(3)
c.cd(1)
t.Draw("muDecayX")
c.cd(2)
t.Draw("muDecayY")
c.cd(3)
t.Draw("muDecayZ")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
c = r.TCanvas("c","c",1500,500)
c.Divide(3)
c.cd(1)
t.Draw("muDecayR")
c.cd(2)
t.Draw("muDecayTheta")
c.cd(3)
t.Draw("muDecayYrel")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
c = r.TCanvas("c","c",1500,500)
c.Divide(3)
c.cd(1)
t.Draw("muDecayPolR")
c.cd(2)
t.Draw("muDecayPolTheta")
c.cd(3)
t.Draw("muDecayPolYrel")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
c = r.TCanvas()
t.Draw("muDecayPolThetaRel:muDecayPolPhiRel","","colz")
c.Draw()

# %%
c = r.TCanvas()
t.Draw("1:muDecayPolPhiRel","","pol lego2 ")
c.SetTheta(90.)
c.SetPhi(0)
c.Draw()

# %%
c = r.TCanvas()
t.Draw("1:muDecayPolThetaRel","","pol lego2 ")
c.SetTheta(90.)
c.SetPhi(0)
c.Draw()

# %%
c = r.TCanvas()
t.Draw("eCaloFrameV:eCaloFrameR","","colz")
#c.SetTheta(90.)
#c.SetPhi(0)
c.Draw()

# %%
c = r.TCanvas()
t.Draw("@eCaloFrameT.size()","","")
#c.SetTheta(90.)
#c.SetPhi(0)
#c.SetLogy()
c.Draw()

# %%
c = r.TCanvas()
t.Draw("TMath::ACos(muDecayZ / TMath::Sqrt(muDecayX**2 + muDecayY**2 + muDecayZ**2)):TMath::Sqrt(muDecayX**2 + muDecayY**2 + muDecayZ**2)",
       "",
       "colz")
#t.Draw("eCaloX:eCaloZ","eCaloNum == 1","same")
c.Draw()

# %%
c = r.TCanvas()
h = r.TH2D("h","h", 50, 0, 3.15, 8000,0,8000)
t.Draw("TMath::Sqrt(muDecayX**2 + muDecayY**2 + muDecayZ**2):TMath::ACos(muDecayZ / TMath::Sqrt(muDecayX**2 + muDecayY**2 + muDecayZ**2))>>h",
       "",
       "goff")
# Out:
# 4000

# %%
c = r.TCanvas()
h.Draw("lego2 pol")
c.SetTheta(75.)
c.SetPhi(0)
#t.Draw("eCaloX:eCaloZ","eCaloNum == 1","same")
c.Draw()

# %%
c = r.TCanvas()
caloNum = 1
condition = "eCaloNum == "+str(caloNum)
fout = r.TFile("temp_tree_storage.root","recreate")
fout.cd()
t_partial = t.CopyTree(condition)
t_partial.SetLineColor(2)
#t_partial.Print()
t_partial.Draw("muDecayY:TMath::Sqrt(muDecayX**2 + muDecayY**2 + muDecayZ**2)","","colz")
c.Draw()

# %%
c = r.TCanvas()
t_partial.Draw("muDecayX:muDecayZ>>hist(800,-8000,8000,800,-8000,8000)")
t_partial.Draw("eCaloX:eCaloZ","","same")
c.Draw()

# %%
c = r.TCanvas()
t.Draw("muDecayX:muDecayZ>>hist(800,-8000,8000,800,-8000,8000)",condition)
t.Draw("eCaloX:eCaloZ",condition,"same")
c.Draw()

# %%
c = r.TCanvas()
t.Draw("eCaloNum","eCaloNum[0] == 1","")
c.SetLogy()
c.Draw()

# %%
c = r.TCanvas()

t_partial.Draw("eCaloNum","","")
t.Draw("eCaloNum",condition,"same")

c.SetLogy()
c.Draw()

# %%
c = r.TCanvas()
t_partial.Draw("muDecayX:muDecayZ>>hist(800,-8000,8000,800,-8000,8000)","@eCaloE.size() == 5","")
c.Draw()

# %%
c = r.TCanvas()
#t_partial.Draw("@eCaloE.size()")
t.Draw("@eCaloE.size()>>hist(100,0,100)", "", "")
c.SetLogy()
c.Draw()

# %%
c = r.TCanvas()
#t_partial.Draw("@eCaloE.size()")
h = r.TH2D("h","eCaloE vs. Length of eCaloE; Energy [MeV?]; Length[eCaloE]",6000,0,3000,1000,0,1000)
t.Draw("@eCaloE.size():eCaloE>>h", "", "goff")
h.GetXaxis().SetRangeUser(0,5)
h.Draw("colz")

c.SetLogz()
c.Draw()
# Out:
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: h (Potential memory leak).

# %%
t_partial.Draw("eCaloY:TMath::Sqrt(eCaloX**2 + eCaloY**2 + eCaloZ**2):eCaloE","","colz")
c.Draw()

# %%
c = r.TCanvas()
t.Draw("eCaloNum")
c.Draw()

# %%
c = r.TCanvas()
t.Draw("@eCaloE.size()")
c.SetLogy()
c.Draw()

# %%
c = r.TCanvas()
t.Draw("eCaloT[0]-eBirthT:eCaloNum","","")
c.Draw()

# %%
c = r.TCanvas("c","c",1500,500)
c.Divide(3)
c.cd(1)
t.Draw("eCaloPx")
c.cd(2)
t.Draw("eCaloPy")
c.cd(3)
t.Draw("eCaloPz")
c.Draw()

# %%
c = r.TCanvas("c","c",1200,600)
c.Divide(2)
c.cd(1)
t.Draw("muDecayX:muDecayZ","@eCaloE.size() == 0","colz")
c.cd(2)
t.Draw("muDecayX:muDecayZ","@eCaloE.size() > 0","colz")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
c = r.TCanvas("c","c",1200,600)
c.Divide(2)
c.cd(1)
t.Draw("muDecayPx:muDecayPz","@eCaloE.size() == 0","colz")
c.cd(2)
t.Draw("muDecayPx:muDecayPz","@eCaloE.size() > 0","colz")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
c = r.TCanvas("c","c",1200,600)
c.Divide(2)
c.cd(1)
t.Draw("muDecayPz","@eCaloE.size() == 0","colz")
c.cd(2)
t.Draw("muDecayPz","@eCaloE.size() > 0","colz")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
c = r.TCanvas("c","c",1200,600)
c.Divide(2)
c.cd(1)
t.Draw("TMath::ACos( muDecayY / TMath::Sqrt(muDecayX**2 + muDecayY**2 + muDecayZ**2) )","@eCaloE.size() == 0","colz")
c.cd(2)
t.Draw("TMath::ACos( muDecayY / TMath::Sqrt(muDecayX**2 + muDecayY**2 + muDecayZ**2) )","@eCaloE.size() > 0","colz")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
h = r.TH1D("h","h",100,0,100)
h2 = r.TH1D("h2","h2",100,0,100)

t.Draw("muDecayX>>h")
t.Draw("muDecayX>>h2")
# Out:
# Info in <TCanvas::MakeDefCanvas>:  created default TCanvas with name c1

# %%
h.Add(h2,1)
# Out:
# True

# %%
c = r.TCanvas()
h.Draw()
c.Draw()
