# %%
import ROOT as r
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use('./gm2.mplstyle')

# %%
fig,ax = plt.subplots(figsize=(8,8))
data = np.sin(np.linspace(0, 2 * np.pi))
plt.plot(data,"o-")
plt.xlabel('x [xtals]')
plt.ylabel('N / 1 c.t.')
plt.text(0.1,-1,"Sine Wave")
plt.savefig("ding.eps")
plt.show()
