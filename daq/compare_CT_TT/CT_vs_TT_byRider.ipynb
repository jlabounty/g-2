# %%
#General imports.
import ROOT as r
import math
from BlindersPy3 import Blinders
from BlindersPy3 import FitType
r.gStyle.SetOptStat(0)
r.gStyle.SetOptFit(1111)
import matplotlib.pyplot as plt
import csv
import pandas

import seaborn as sns
sns.set(style="ticks", color_codes=True)
import numpy as np
import matplotlib.pyplot as plt
import matplotlib 
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
import os
import scipy

import uproot # https://indico.cern.ch/event/686641/contributions/2894906/attachments/1606247/2548596/pivarski-uproot.pdf
from awkward import JaggedArray
from root_pandas import read_root # https://github.com/scikit-hep/root_pandas

#import warnings
#warnings.filterwarnings('once')

# %matplotlib inline

# %%
fct = r.TFile("./waveforms_19016_CTbanks_first50.root")
runNum = 19016
subRunNum = "00467"

# %%
fct.cd("islands/fill1/calo7")
#fct.ls()
# Out:
# True

# %%
ftt = r.TFile("./waveforms_19016_TTbanks_first50.root")

# %%
ftt.cd("islands/fill5/calo7")
#ftt.ls()
# Out:
# True

# %%
tc = fct.Get("islands/islands/islandTree") #CT banks
tt = ftt.Get("islands/islands/islandTree") #TT banks
tc.Print()
# Out:
# ******************************************************************************
# *Tree    :islandTree: Tree of xtal traces                                    *
# *Entries :     3705 : Total =        21447435 bytes  File  Size =   12765795 *
# *        :          : Tree compression factor =   1.68                       *
# ******************************************************************************
# *Br    0 :xtal0     : vector<short>                                          *
# *Entries :     3705 : Total  Size=     452527 bytes  File Size  =     268240 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.68     *
# *............................................................................*
# *Br    1 :xtal1     : vector<short>                                          *
# *Entries :     3705 : Total  Size=     452527 bytes  File Size  =     270826 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.67     *
# *............................................................................*
# *Br    2 :xtal2     : vector<short>                                          *
# *Entries :     3705 : Total  Size=     452277 bytes  File Size  =     267656 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.69     *
# *............................................................................*
# *Br    3 :xtal3     : vector<short>                                          *
# *Entries :     3705 : Total  Size=     452277 bytes  File Size  =     265859 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.70     *
# *............................................................................*
# *Br    4 :xtal4     : vector<short>                                          *
# *Entries :     3705 : Total  Size=     452277 bytes  File Size  =     268593 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.68     *
# *............................................................................*
# *Br    5 :xtal5     : vector<short>                                          *
# *Entries :     3705 : Total  Size=     452277 bytes  File Size  =     263167 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.72     *
# *............................................................................*
# *Br    6 :xtal6     : vector<short>                                          *
# *Entries :     3705 : Total  Size=     452665 bytes  File Size  =     267798 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.69     *
# *............................................................................*
# *Br    7 :xtal7     : vector<short>                                          *
# *Entries :     3705 : Total  Size=     452885 bytes  File Size  =     267274 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.69     *
# *............................................................................*
# *Br    8 :xtal8     : vector<short>                                          *
# *Entries :     3705 : Total  Size=     452885 bytes  File Size  =     268075 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.69     *
# *............................................................................*
# *Br    9 :xtal9     : vector<short>                                          *
# *Entries :     3705 : Total  Size=     452527 bytes  File Size  =     268958 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.68     *
# *............................................................................*
# *Br   10 :xtal10    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     452555 bytes  File Size  =     264585 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.71     *
# *............................................................................*
# *Br   11 :xtal11    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     452305 bytes  File Size  =     267009 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.69     *
# *............................................................................*
# *Br   12 :xtal12    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     453085 bytes  File Size  =     267345 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.69     *
# *............................................................................*
# *Br   13 :xtal13    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     453085 bytes  File Size  =     267715 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.69     *
# *............................................................................*
# *Br   14 :xtal14    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     453085 bytes  File Size  =     265953 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.70     *
# *............................................................................*
# *Br   15 :xtal15    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     453093 bytes  File Size  =     265628 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.70     *
# *............................................................................*
# *Br   16 :xtal16    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     453463 bytes  File Size  =     270225 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.68     *
# *............................................................................*
# *Br   17 :xtal17    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     453463 bytes  File Size  =     270172 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.68     *
# *............................................................................*
# *Br   18 :xtal18    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     452305 bytes  File Size  =     267463 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.69     *
# *............................................................................*
# *Br   19 :xtal19    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     452475 bytes  File Size  =     264377 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.71     *
# *............................................................................*
# *Br   20 :xtal20    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     452475 bytes  File Size  =     265256 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.70     *
# *............................................................................*
# *Br   21 :xtal21    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     453205 bytes  File Size  =     264156 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.71     *
# *............................................................................*
# *Br   22 :xtal22    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     455735 bytes  File Size  =     270164 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.68     *
# *............................................................................*
# *Br   23 :xtal23    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     455735 bytes  File Size  =     264658 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.72     *
# *............................................................................*
# *Br   24 :xtal24    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     455355 bytes  File Size  =     285798 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.59     *
# *............................................................................*
# *Br   25 :xtal25    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     453025 bytes  File Size  =     271611 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.66     *
# *............................................................................*
# *Br   26 :xtal26    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     453025 bytes  File Size  =     268688 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.68     *
# *............................................................................*
# *Br   27 :xtal27    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     452455 bytes  File Size  =     269446 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.68     *
# *............................................................................*
# *Br   28 :xtal28    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     452625 bytes  File Size  =     272184 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.66     *
# *............................................................................*
# *Br   29 :xtal29    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     452525 bytes  File Size  =     267763 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.69     *
# *............................................................................*
# *Br   30 :xtal30    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     318145 bytes  File Size  =     192668 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.65     *
# *............................................................................*
# *Br   31 :xtal31    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     321025 bytes  File Size  =     195059 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.64     *
# *............................................................................*
# *Br   32 :xtal32    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     322315 bytes  File Size  =     199654 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.61     *
# *............................................................................*
# *Br   33 :xtal33    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     321935 bytes  File Size  =     194374 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.65     *
# *............................................................................*
# *Br   34 :xtal34    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     320465 bytes  File Size  =     193386 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.65     *
# *............................................................................*
# *Br   35 :xtal35    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     319175 bytes  File Size  =     192518 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.65     *
# *............................................................................*
# *Br   36 :xtal36    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     317545 bytes  File Size  =     191422 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.65     *
# *............................................................................*
# *Br   37 :xtal37    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     317715 bytes  File Size  =     193557 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.64     *
# *............................................................................*
# *Br   38 :xtal38    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     317465 bytes  File Size  =     192893 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.64     *
# *............................................................................*
# *Br   39 :xtal39    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     317415 bytes  File Size  =     192035 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.65     *
# *............................................................................*
# *Br   40 :xtal40    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     320245 bytes  File Size  =     191428 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.67     *
# *............................................................................*
# *Br   41 :xtal41    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     322135 bytes  File Size  =     195343 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.65     *
# *............................................................................*
# *Br   42 :xtal42    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     322135 bytes  File Size  =     196102 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.64     *
# *............................................................................*
# *Br   43 :xtal43    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     320815 bytes  File Size  =     193919 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.65     *
# *............................................................................*
# *Br   44 :xtal44    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     318925 bytes  File Size  =     193539 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.64     *
# *............................................................................*
# *Br   45 :xtal45    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     317545 bytes  File Size  =     191787 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.65     *
# *............................................................................*
# *Br   46 :xtal46    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     317545 bytes  File Size  =     193198 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.64     *
# *............................................................................*
# *Br   47 :xtal47    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     317295 bytes  File Size  =     195520 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.62     *
# *............................................................................*
# *Br   48 :xtal48    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     317245 bytes  File Size  =     192215 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.65     *
# *............................................................................*
# *Br   49 :xtal49    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     317595 bytes  File Size  =     193127 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.64     *
# *............................................................................*
# *Br   50 :xtal50    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     319485 bytes  File Size  =     194203 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.64     *
# *............................................................................*
# *Br   51 :xtal51    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     319485 bytes  File Size  =     197080 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.62     *
# *............................................................................*
# *Br   52 :xtal52    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     320815 bytes  File Size  =     193318 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.66     *
# *............................................................................*
# *Br   53 :xtal53    : vector<short>                                          *
# *Entries :     3705 : Total  Size=     318925 bytes  File Size  =     195820 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.62     *
# *............................................................................*
# *Br   54 :caloNum   : caloNum/I                                              *
# *Entries :     3705 : Total  Size=      17533 bytes  File Size  =       4372 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   3.83     *
# *............................................................................*
# *Br   55 :islandLength : islandLength/I                                      *
# *Entries :     3705 : Total  Size=      17673 bytes  File Size  =       6362 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   2.65     *
# *............................................................................*
# *Br   56 :islandStart : islandStart/I                                        *
# *Entries :     3705 : Total  Size=      17645 bytes  File Size  =      11079 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   1.52     *
# *............................................................................*
# *Br   57 :uniqueID  : uniqueID/L                                             *
# *Entries :     3705 : Total  Size=      32389 bytes  File Size  =       9525 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   3.32     *
# *............................................................................*
# *Br   58 :runNum    : runNum/I                                               *
# *Entries :     3705 : Total  Size=      17505 bytes  File Size  =       2592 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   6.45     *
# *............................................................................*
# *Br   59 :subRunNum : subRunNum/I                                            *
# *Entries :     3705 : Total  Size=      17589 bytes  File Size  =       2664 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   6.30     *
# *............................................................................*
# *Br   60 :fillNum   : fillNum/I                                              *
# *Entries :     3705 : Total  Size=      17533 bytes  File Size  =       2616 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   6.40     *
# *............................................................................*
# *Br   61 :islandNum : islandNum/I                                            *
# *Entries :     3705 : Total  Size=      17589 bytes  File Size  =       5773 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   2.91     *
# *............................................................................*
# *Br   62 :riderNum  : riderNum/I                                             *
# *Entries :     3705 : Total  Size=      17561 bytes  File Size  =       3029 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   5.53     *
# *............................................................................*
# *Br   63 :channelNum : channelNum/I                                          *
# *Entries :     3705 : Total  Size=      17617 bytes  File Size  =       3018 *
# *Baskets :       24 : Basket Size=      32000 bytes  Compression=   5.57     *
# *............................................................................*

# %%
tt.Print()
# Out:
# ******************************************************************************
# *Tree    :islandTree: Tree of xtal traces                                    *
# *Entries :    10336 : Total =        55766458 bytes  File  Size =   23812996 *
# *        :          : Tree compression factor =   2.34                       *
# ******************************************************************************
# *Br    0 :xtal0     : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024029 bytes  File Size  =     444885 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.30     *
# *............................................................................*
# *Br    1 :xtal1     : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024029 bytes  File Size  =     417832 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.45     *
# *............................................................................*
# *Br    2 :xtal2     : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024029 bytes  File Size  =     470994 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.17     *
# *............................................................................*
# *Br    3 :xtal3     : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024029 bytes  File Size  =     392238 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.61     *
# *............................................................................*
# *Br    4 :xtal4     : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024029 bytes  File Size  =     453334 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.26     *
# *............................................................................*
# *Br    5 :xtal5     : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024029 bytes  File Size  =     403211 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.54     *
# *............................................................................*
# *Br    6 :xtal6     : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024029 bytes  File Size  =     403092 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.54     *
# *............................................................................*
# *Br    7 :xtal7     : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024029 bytes  File Size  =     411750 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.48     *
# *............................................................................*
# *Br    8 :xtal8     : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024029 bytes  File Size  =     448190 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.28     *
# *............................................................................*
# *Br    9 :xtal9     : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024029 bytes  File Size  =     414634 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.47     *
# *............................................................................*
# *Br   10 :xtal10    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     420017 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.44     *
# *............................................................................*
# *Br   11 :xtal11    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     462287 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.21     *
# *............................................................................*
# *Br   12 :xtal12    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     436638 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.34     *
# *............................................................................*
# *Br   13 :xtal13    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     489464 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.09     *
# *............................................................................*
# *Br   14 :xtal14    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     506471 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.02     *
# *............................................................................*
# *Br   15 :xtal15    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     424812 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.41     *
# *............................................................................*
# *Br   16 :xtal16    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     505923 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.02     *
# *............................................................................*
# *Br   17 :xtal17    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     452251 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.26     *
# *............................................................................*
# *Br   18 :xtal18    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     393498 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.60     *
# *............................................................................*
# *Br   19 :xtal19    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     406601 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.52     *
# *............................................................................*
# *Br   20 :xtal20    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     407987 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.51     *
# *............................................................................*
# *Br   21 :xtal21    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     395521 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.59     *
# *............................................................................*
# *Br   22 :xtal22    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     437014 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.34     *
# *............................................................................*
# *Br   23 :xtal23    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     411662 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.49     *
# *............................................................................*
# *Br   24 :xtal24    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     432082 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.37     *
# *............................................................................*
# *Br   25 :xtal25    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     496688 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.06     *
# *............................................................................*
# *Br   26 :xtal26    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     425671 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.40     *
# *............................................................................*
# *Br   27 :xtal27    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     421048 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.43     *
# *............................................................................*
# *Br   28 :xtal28    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     425040 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.41     *
# *............................................................................*
# *Br   29 :xtal29    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     421789 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.43     *
# *............................................................................*
# *Br   30 :xtal30    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     507253 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.02     *
# *............................................................................*
# *Br   31 :xtal31    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     413044 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.48     *
# *............................................................................*
# *Br   32 :xtal32    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     410288 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.49     *
# *............................................................................*
# *Br   33 :xtal33    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     429522 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.38     *
# *............................................................................*
# *Br   34 :xtal34    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     514991 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   1.99     *
# *............................................................................*
# *Br   35 :xtal35    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     449690 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.27     *
# *............................................................................*
# *Br   36 :xtal36    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     435951 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.35     *
# *............................................................................*
# *Br   37 :xtal37    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     393964 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.60     *
# *............................................................................*
# *Br   38 :xtal38    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     412819 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.48     *
# *............................................................................*
# *Br   39 :xtal39    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     466568 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.19     *
# *............................................................................*
# *Br   40 :xtal40    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     463677 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.21     *
# *............................................................................*
# *Br   41 :xtal41    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     412028 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.48     *
# *............................................................................*
# *Br   42 :xtal42    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     439254 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.33     *
# *............................................................................*
# *Br   43 :xtal43    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     420521 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.43     *
# *............................................................................*
# *Br   44 :xtal44    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     408725 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.50     *
# *............................................................................*
# *Br   45 :xtal45    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     386833 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.64     *
# *............................................................................*
# *Br   46 :xtal46    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     411034 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.49     *
# *............................................................................*
# *Br   47 :xtal47    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     404395 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.53     *
# *............................................................................*
# *Br   48 :xtal48    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     654380 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   1.56     *
# *............................................................................*
# *Br   49 :xtal49    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     464066 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.20     *
# *............................................................................*
# *Br   50 :xtal50    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     443376 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.31     *
# *............................................................................*
# *Br   51 :xtal51    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     509668 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.01     *
# *............................................................................*
# *Br   52 :xtal52    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     395610 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.59     *
# *............................................................................*
# *Br   53 :xtal53    : vector<short>                                          *
# *Entries :    10336 : Total  Size=    1024070 bytes  File Size  =     435424 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   2.35     *
# *............................................................................*
# *Br   54 :caloNum   : caloNum/I                                              *
# *Entries :    10336 : Total  Size=      42237 bytes  File Size  =       1001 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=  41.70     *
# *............................................................................*
# *Br   55 :islandLength : islandLength/I                                      *
# *Entries :    10336 : Total  Size=      42282 bytes  File Size  =      12467 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=   3.35     *
# *............................................................................*
# *Br   56 :islandStart : islandStart/I                                        *
# *Entries :    10336 : Total  Size=      42273 bytes  File Size  =      26968 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=   1.55     *
# *............................................................................*
# *Br   57 :uniqueID  : uniqueID/L                                             *
# *Entries :    10336 : Total  Size=      83598 bytes  File Size  =      18519 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=   4.49     *
# *............................................................................*
# *Br   58 :runNum    : runNum/I                                               *
# *Entries :    10336 : Total  Size=      42228 bytes  File Size  =        755 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=  55.28     *
# *............................................................................*
# *Br   59 :subRunNum : subRunNum/I                                            *
# *Entries :    10336 : Total  Size=      42255 bytes  File Size  =        771 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=  54.16     *
# *............................................................................*
# *Br   60 :fillNum   : fillNum/I                                              *
# *Entries :    10336 : Total  Size=      42237 bytes  File Size  =        757 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=  55.14     *
# *............................................................................*
# *Br   61 :islandNum : islandNum/I                                            *
# *Entries :    10336 : Total  Size=      42255 bytes  File Size  =      16490 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=   2.53     *
# *............................................................................*
# *Br   62 :riderNum  : riderNum/I                                             *
# *Entries :    10336 : Total  Size=      42246 bytes  File Size  =        762 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=  54.79     *
# *............................................................................*
# *Br   63 :channelNum : channelNum/I                                          *
# *Entries :    10336 : Total  Size=      42264 bytes  File Size  =        772 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=  54.09     *
# *............................................................................*

# %%
c = r.TCanvas()
c.Divide(2)
c.cd(1)
tc.Draw("riderNum:channelNum")
c.cd(2)
tc.Draw("islandNum:fillNum")
c.Draw()

# %%
c = r.TCanvas()
c.Divide(2)
c.cd(1)
tt.Draw("riderNum*10+channelNum:fillNum")
c.cd(2)
tt.Draw("islandNum:fillNum")
c.Draw()
