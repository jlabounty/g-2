# %%
from evwTools import *
# Out:
# Welcome to JupyROOT 6.12/06

# %%
f = r.TFile("./data/TestEvents_Calo11_Band.root")

# %%
t = f.Get("evwTree")

# %%
print("run subrun fill calo island")
for i, e in enumerate(t):
    if (i > 100):
        break
    print(e.runNum, e.subRunNum, e.fill, e.caloNum, e.islandWest)
# Out:
# run subrun fill calo island
# 15968 161 7 11 127
# 15968 161 9 11 147
# 15968 161 16 11 206
# 15968 161 18 11 108
# 15968 161 57 11 163
# 15968 161 93 11 182
# 15968 161 106 11 103
# 15930 455 10 11 177
# 15930 455 29 11 168
# 15930 455 63 11 157
# 15930 455 80 11 138
# 15930 455 107 11 96
# 15930 455 114 11 99
# 15930 455 135 11 130
# 15930 455 135 11 110
# 15968 324 11 11 203
# 15968 324 26 11 106
# 15968 324 28 11 159
# 15968 324 30 11 150
# 15968 324 45 11 172
# 15968 324 106 11 122
# 15968 324 121 11 123
# 15968 324 125 11 183
# 15963 120 6 11 91
# 15963 120 40 11 56
# 15963 120 117 11 169
# 15963 120 121 11 107
# 15963 120 136 11 101
# 15963 120 141 11 115
# 15922 189 14 11 141
# 15922 189 24 11 103
# 15922 189 50 11 162
# 15922 189 60 11 153
# 15922 189 65 11 163
# 15922 189 75 11 138
# 15922 189 84 11 80
# 15922 189 109 11 155
# 15922 189 120 11 136
# 15922 189 126 11 94
# 15949 259 11 11 125
# 15949 259 37 11 107
# 15949 259 44 11 197
# 15949 259 152 11 175
# ...
