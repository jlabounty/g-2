# %%
from standardInclude import *
# Out:
# Welcome to JupyROOT 6.12/06
# For interactive plots, run: setint()
# To return to non-interactive plots (default state), run: noint()

# %%
f = r.TFile("./data/gm2offline_ana.root")
f.ls()
f.cd("farline/evw_calo2")
f.ls()
# Out:
# TFile**		./data/gm2offline_ana.root
#  TFile*		./data/gm2offline_ana.root
#   KEY: TDirectoryFile	farline;1	farline (ReconComparisonEastVsWest) folder
# TFile**		./data/gm2offline_ana.root
#  TFile*		./data/gm2offline_ana.root
#   TDirectoryFile*		farline	farline (ReconComparisonEastVsWest) folder
#    TDirectoryFile*		evw_calo2	evw_calo2
#     KEY: TH2I	evwDeltaXDeltaY;1	DeltaX vs. DeltaY in Calo 2
#     KEY: TH2I	evwDeltaXDeltaY_LowEnergy;1	DeltaX vs. DeltaY in Calo 2
#     KEY: TH2I	evwDeltaXDeltaE;1	DeltaX vs. DeltaE in Calo 2
#     KEY: TH2I	evwDeltaYDeltaE;1	DeltaY vs. DeltaE in Calo 2
#     KEY: TH2I	evwEnergyEvW;1	EnergyEast vs. EnergyWest in Calo 2
#     KEY: TH1F	evwDeltaT;1	DeltaT in Calo 2
#     KEY: TH1F	evwDeltaT_LowEnergy;1	DeltaT in Calo 2
#     KEY: TH2I	evwEnergyWestdeltaT;1	deltaT [Corrected] vs. EnergyWest in Calo 2
#    KEY: TDirectoryFile	evw_calo1;1	evw_calo1
#    KEY: TDirectoryFile	evw_calo2;1	evw_calo2
#    KEY: TDirectoryFile	evw_calo3;1	evw_calo3
# ...

# %%
t = f.Get("farline/evwTree")

# %%
t.Print()
# Out:
# ******************************************************************************
# *Tree    :evwTree   : evwTree                                                *
# *Entries :   185916 : Total =        83950659 bytes  File  Size =   34978278 *
# *        :          : Tree compression factor =   2.40                       *
# ******************************************************************************
# *Br    0 :runNum    : runNum/i                                               *
# *Entries :   185916 : Total  Size=     745989 bytes  File Size  =       6003 *
# *Baskets :       21 : Basket Size=    1916928 bytes  Compression= 124.15     *
# *............................................................................*
# *Br    1 :subRunNum : subRunNum/i                                            *
# *Entries :   185916 : Total  Size=     746064 bytes  File Size  =       6045 *
# *Baskets :       21 : Basket Size=    1916928 bytes  Compression= 123.30     *
# ...

# %%
c = r.TCanvas()
t.Draw("timeEast - timeWest:timeWest*1.25/1000.>>hist(700,0,700,300,-2,2)","","colz")
c.Draw()
