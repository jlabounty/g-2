# %%
#General imports.
import ROOT as r
import math
from BlindersPy3 import Blinders
from BlindersPy3 import FitType
r.gStyle.SetOptStat(0)
r.gStyle.SetOptFit(1111)
import matplotlib.pyplot as plt
import csv
import pandas

import seaborn as sns
sns.set(style="ticks", color_codes=True)
import numpy as np
import matplotlib.pyplot as plt
import matplotlib 
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
import os
import scipy

import uproot #https://indico.cern.ch/event/686641/contributions/2894906/attachments/1606247/2548596/pivarski-uproot.pdf
from awkward import JaggedArray
from root_pandas import read_root # https://github.com/scikit-hep/root_pandas

import warnings
warnings.filterwarnings('once')

# %matplotlib inline
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed',)).History will not be written to the database.
# Welcome to JupyROOT 6.12/06

# %%
c = r.TCanvas("c","c",1800,400)

mean1 = -20

g1 = r.TF1("g1","gaus",-40,40)
g1.SetTitle("Example Cluster ID")
g1.SetParameters(1,mean1,1)
g1.GetXaxis().SetTitle("Time [c.t.]")
g1.Draw()
g1.SetNpx(5000)

g2 = r.TF1("g2","gaus",-40,40)
g2.SetTitle("Example Cluster ID")
g2.SetParameters(1,mean1+10,1)
g2.SetLineColor(4)
g2.SetNpx(5000)

leg = r.TLegend(0.7,0.8,0.9,0.9)
leg.AddEntry(g1 ,"Recon East Clusters")
leg.AddEntry(g2 ,"Recon West Clusters")
leg.Draw()

c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
box = r.TBox(mean1-15,0,mean1+15,1)
box.SetFillColorAlpha(2,0.2)
box.Draw("SAME")
c.Draw()

# %%
g2 = r.TF1("g2","gaus",-40,40)
g2.SetTitle("Example Cluster ID")
g2.SetParameters(1,mean1+10,1)
g2.SetLineColor(2)
g2.SetNpx(5000)
g2.Draw("SAME")

t1 = r.TText(30,.5,"Rejected");
t1.SetTextAlign(22);
t1.SetTextColor(2);
t1.SetTextFont(43);
t1.SetTextSize(40);
t1.Draw();

c.Draw()

# %%
g2 = r.TF1("g2","gaus",-40,40)
g2.SetTitle("Example Cluster ID")
g2.SetParameters(1,mean1+30,1)
g2.SetLineColor(4)
g2.SetNpx(5000)
g2.Draw("SAME")

t1 = r.TText(30,.5,"Rejected");
t1.SetTextAlign(22);
t1.SetTextColor(2);
t1.SetTextFont(43);
t1.SetTextSize(40);
t1.Draw();

c.Draw()

# %%
g2 = r.TF1("g2","gaus",-40,40)
g2.SetTitle("Example Cluster ID")
g2.SetParameters(1,mean1+5,1)
g2.SetLineColor(4)
g2.SetNpx(5000)
g2.Draw("SAME")

t1 = r.TText(30,.5,"Accepted");
t1.SetTextAlign(22);
t1.SetTextColor(2);
t1.SetTextFont(43);
t1.SetTextSize(40);
t1.Draw();

c.Draw()

# %% [markdown]
# g3 = r.TF1("g3","gaus",-40,40)
# g3.SetTitle("Example Cluster ID")
# g3.SetParameters(1,mean1+20,1)
# g3.SetLineColor(4)
# g3.SetNpx(5000)
# g3.Draw("SAME")
#
# t1 = r.TText(30,.75,"Accepted");
# t1.SetTextAlign(22);
# t1.SetTextColor(2);
# t1.SetTextFont(43);
# t1.SetTextSize(40);
# t1.Draw();
#
# t2 = r.TText(30,.25,"Rejected");
# t2.SetTextAlign(22);
# t2.SetTextColor(4);
# t2.SetTextFont(43);
# t2.SetTextSize(40);
# t2.Draw();
#
# box2 = r.TBox(mean1-15+5,0,mean1+15+5,1)
# box2.SetFillColorAlpha(4,0.2)
# box2.Draw("SAME")
# c.Draw()
#
# c.Draw()

# %%
g4 = r.TF1("g4","gaus",-40,40)
g4.SetTitle("Example Cluster ID")
g4.SetParameters(1,mean1-10,1)
g4.SetLineColor(4)
g4.SetNpx(5000)
g4.Draw("SAME")

t1 = r.TText(30,.5,"Rejected");
t1.SetTextAlign(22);
t1.SetTextColor(2);
t1.SetTextFont(43);
t1.SetTextSize(40);
t1.Draw();

c.Draw()

# %%
g5 = r.TF1("g5","gaus",-40,40)
g5.SetTitle("Example Cluster ID")
g5.SetParameters(1,mean1-8,1)
g5.SetLineColor(2)
g5.SetNpx(5000)
g5.Draw("SAME")

t1 = r.TText(30,.5,"Rejected");
t1.SetTextAlign(22);
t1.SetTextColor(4);
t1.SetTextFont(43);
t1.SetTextSize(40);
t1.Draw();

c.Draw()
