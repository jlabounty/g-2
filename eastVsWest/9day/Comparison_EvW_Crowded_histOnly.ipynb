# %%
from standardInclude import *
# Out:
# Welcome to JupyROOT 6.12/06
# For interactive plots, run: setint()
# To return to non-interactive plots (default state), run: noint()

# %%
f = r.TFile("../data/results_histOnly_crowdedClusters_9day.root")

# %%
f.cd("farline")
f.ls()
# Out:
# TFile**		../data/results_histOnly_crowdedClusters_9day.root
#  TFile*		../data/results_histOnly_crowdedClusters_9day.root
#   TDirectoryFile*		farline	farline (ReconComparisonEvWClusterSum) folder
#    KEY: TH2D	evwEnergyEvW;1	EnergyEast vs. EnergyWest
#    KEY: TH2D	counterHist;1	Number of Clusters Per Island in East and West
#    KEY: TH2D	counterHistHighEnergy;1	Number of Clusters Per Island in East and West [All Clusters Above Energy Cutoff]
#    KEY: TH2D	evwDeltaXDeltaY;1	Energy Weighted #deltaX vs. #deltaY
#    KEY: TH2D	evwDeltaTCalo;1	Energy Weighted #deltaT
#    KEY: TH1D	evwDeltaE;1	#deltaE (n:n Islands Only)
#    KEY: TH1D	evwDeltaEAll;1	#deltaE (All Islands)
#    KEY: TH2D	counterWestVsTime;1	Number of Clusters Per Island in Recon West vs. t_{west} (Max Energy)
#    KEY: TH2D	counterEastVsTime;1	Number of Clusters Per Island in Recon East vs. t_{east} (Max Energy)
# ...

# %%
c = r.TCanvas()
evwEnergyEvW = f.Get("farline").Get("evwEnergyEvW").Clone()
evwEnergyEvW.Draw("colz")
c.SetLogz()
c.Draw()

# %%
c = r.TCanvas()
counterHist = f.Get("farline").Get("counterHist").Clone()
counterHist.Draw("colz")
c.SetLogz()
c.Draw()

# %%
c = r.TCanvas()
counterHistHighEnergy = f.Get("farline").Get("counterHistHighEnergy").Clone()
counterHistHighEnergy.Draw("colz")
c.SetLogz()
c.Draw()

# %%
c = r.TCanvas()
evwEnergyEvW = f.Get("farline").Get("evwEnergyEvW").Clone()
evwEnergyEvW.Draw("colz")
c.SetLogz()
c.Draw()

# %%
c = r.TCanvas()
evwDeltaXDeltaY = f.Get("farline").Get("evwDeltaXDeltaY").Clone()
evwDeltaXDeltaY.Draw("colz")
c.SetLogz()
c.Draw()

# %%
c = r.TCanvas()
evwDeltaTCalo = f.Get("farline").Get("evwDeltaTCalo").Clone()
evwDeltaTCalo.Draw("colz")
c.SetLogz()
c.Draw()

# %%
c = r.TCanvas()
evwDeltaE = f.Get("farline").Get("evwDeltaE").Clone()
evwDeltaE.Draw("colz")
c.SetLogz()
c.Draw()

# %%
c = r.TCanvas()
evwDeltaEAll = f.Get("farline").Get("evwDeltaEAll").Clone()
evwDeltaEAll.Draw("colz")
c.SetLogz()
c.Draw()

# %%
c = r.TCanvas()
counterWestVsTime = f.Get("farline").Get("counterWestVsTime").Clone()
counterWestVsTime.Draw("colz")
c.SetLogz()
c.Draw()

# %%
c = r.TCanvas()
counterEastVsTime = f.Get("farline").Get("counterEastVsTime").Clone()
counterEastVsTime.Draw("colz")
c.SetLogz()
c.Draw()

# %%
c = r.TCanvas()
counterEastVsCounterWestVsTime = f.Get("farline").Get("counterEastVsCounterWestVsTime").Clone()
counterEastVsCounterWestVsTime.Draw()
c.Draw()
