# %%
from standardInclude import *

# %%
fh = r.TFile("from_hist.root")
fh.ls()
# Out:
# TFile**		from_hist.root
#  TFile*		from_hist.root
#   KEY: TH3I	trackerVsCaloY;1	Y-Distribution in Calo vs. Tracker vs. Time

# %%
ft = r.TFile("from_tree.root")
ft.ls()
# Out:
# TFile**		from_tree.root
#  TFile*		from_tree.root
#   KEY: TH3I	h;1	Extrapolated Calo Positions vs. Time

# %%
h1 = fh.Get("trackerVsCaloY").Clone()
h2 = ft.Get("h").Clone()
h2.SetLineColor(2)

# %%
c = r.TCanvas()
h1.Project3D("y").Draw()
h2.Project3D("y").Draw("SAME")
c.Draw()

# %%
c = r.TCanvas()
h1.Project3D("x").Draw()
h2.Project3D("x").Draw("SAME")
c.Draw()

# %%
c = r.TCanvas()
h1.Project3D("z").Draw()
h2.Project3D("z").Draw("SAME")
c.Draw()
