// %%
TFile ibmsfile("./gm2offline_ibms.root");
TFile ibmsfile_baseline("./gm2offline_ibms_baseline.root")
// Out:
// (TFile &) Name: ./gm2offline_ibms_baseline.root Title:
// Warning in <TClass::Init>: no dictionary for class gm2aux::IBMSRawArtRecord is available
// Warning in <TClass::Init>: no dictionary for class gm2aux::IBMSBeamProfileArtRecord is available

// %%
//%jsroot on

// %%
TDirectory::Cd(ibmsAnalyzer->GetPath());

// %%
ibmsfile.ls()
// Out:
// TFile**		./gm2offline_ibms.root
//  TFile*		./gm2offline_ibms.root
//   KEY: TDirectoryFile	ibmsAnalyzer;1	ibmsAnalyzer (IBMSAnalyzer) folder

// %%
//t_ibms->Print()

// %%
TCanvas *c = new TCanvas();

// %%
TCanvas *c2 = new TCanvas();

// %%
%jsroot off
c->cd();
t_ibms->Draw("ibms1YIntegral");
c->Draw();
c2->cd();
t_ibms->Draw("ibms2YIntegral");
c2->Draw();

// %%
TCanvas *c3 = new TCanvas();

// %%
c3->cd();
t_ibms->Draw("ibms1XMean:ibms1YMean");
c3->Draw();

// %%
t_ibms->Draw("ibms2XMean:ibms2YMean");
c3->Draw();

// %%
t_ibms->Draw("trace[63][1]");
c3->Draw();

// %%
t_ibms->GetEntry(12);
t_ibms->Show()
// Out:
// ======> EVENT:12
//  runNum          = 15953
//  subRunNum       = 316
//  fillNum         = 33
//  ibms            = (gm2aux::IBMSRawArtRecord*)0x7f8d345837b0
//  sys_clock[80]   = 241342454 , 241342454 , 241342454 , 241342454 , 241342454 ,
//                     241342454 , 241342454 , 241342454 , 241342454 , 241342454 ,
//                     241342454 , 241342454 , 241342454 , 241342454 , 241342454 ,
//                     241342454 , 241342454 , 241342454 , 241342454 , 241342454
//
//  dev_clock[80]   = 942815338 , 942815338 , 942815338 , 942815338 , 942815338 ,
//                     942815338 , 942815338 , 942815338 , 942815338 , 942815338 ,
//                     942815338 , 942815338 , 942815338 , 942815338 , 942815338 ,
//                     942815338 , 942815338 , 942815338 , 942815338 , 942815338
//
//  trace[80][1024] = 603 , 605 , 607 , 605 , 600 , 600 , 601 , 606 , 603 , 599 ,
//                     605 , 603 , 607 , 607 , 606 , 607 , 608 , 604 , 607 , 605
//
// ...

// %%
TCanvas *c4 = new TCanvas();

// %%
c4->cd();
t_ibms->GetEntry(13);
t_ibms->Draw("fiberBaseline");
c4->Draw();

// %%
1008/63
// Out:
// (int) 16
