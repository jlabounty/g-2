# %%
import ROOT as r
import math
import numpy as np
from BlindersPy3 import Blinders
from BlindersPy3 import FitType
r.gStyle.SetOptStat(0)
r.gStyle.SetOptFit(1111)
# Out:
# Welcome to JupyROOT 6.12/06

# %%
filewindow = r.TFile("./FourierWiggle_output_Window.root")
filenowindow = r.TFile("./FourierWiggle_output_noWindow.root")

# %%
#filewindow.ls()
filewindow.cd()
# Out:
# True

# %%
def GetKeyNames( self, dir = "" ):
        self.cd(dir)
        return [key.GetName() for key in r.gDirectory.GetListOfKeys()]
r.TFile.GetKeyNames = GetKeyNames

keyList = filewindow.GetKeyNames("")
print ("\nKeys in file:", keyList)
# Out:
# Keys in file: ['time0_window', 'time1_window', 'time2_window', 'time3_window', 'time4_window', 'time5_window', 'time6_window', 'time7_window', 'time8_window', 'time9_window', 'time10_window', 'time11_window', 'time12_window', 'time13_window', 'time14_window', 'time15_window', 'time16_window', 'time17_window', 'time18_window', 'time19_window', 'time20_window', 'time21_window', 'time22_window', 'time23_window', 'time24_window', 'time25_window', 'time26_window', 'time27_window', 'time28_window', 'time29_window', 'time30_window', 'time31_window', 'time32_window', 'time33_window', 'time34_window', 'time35_window', 'time36_window', 'time37_window', 'time38_window', 'time39_window', 'time40_window', 'time41_window', 'time42_window', 'time43_window', 'time44_window', 'time45_window', 'time46_window', 'time47_window']

# %%
def peak_fit(x, p):
    return p[0]*r.TMath.Exp(-0.5*((x[0]-p[1])/p[2])*((x[0]-p[1])/p[2])) + p[3] + p[4]*r.TMath.Exp(-p[5]*x[0])
def peak_fit_simple(x, p):
    return p[0]*r.TMath.Exp(-0.5*((x[0]-p[1])/p[2])*((x[0]-p[1])/p[2])) + p[3]
def peak_fit_bw(x, p):
    return p[0]*r.TMath.BreitWigner(x[0],p[1],p[2]) + p[3]

# %%
'''
func = r.TF1("func", peak_fit_simple, .22,.25,4)
func.SetParNames('A','Mean','#sigma','+ C')
func.SetParameters(.0001,.23,.1,0)
func.SetLineColor(2)
func.SetNpx(1000)
'''
# Out:
# '\nfunc = r.TF1("func", peak_fit_simple, .22,.25,4)\nfunc.SetParNames(\'A\',\'Mean\',\'#sigma\',\'+ C\')\nfunc.SetParameters(.0001,.23,.1,0)\nfunc.SetLineColor(2)\nfunc.SetNpx(1000)\n'

# %%
func = r.TF1("func", peak_fit_bw, .22,.27,4)
func.SetParNames('A','Mean','#gamma','+ C')
func.SetParameters(.0001,.23,.1,0)
func.SetParLimits(1,.22,.25)
func.SetLineColor(2)
func.SetNpx(1000)

# %%
'''
func = r.TF1("func", peak_fit, .22,.26,6)
func.SetParNames('A','Mean','#sigma','+ C', '+ D','e^(-E*x)' )
func.SetParameters(.0001,.23,.1,0,0,-1)
func.SetParLimits(0,0,1)
func.SetParLimits(1,.22,.25)
func.SetLineColor(2)
func.SetNpx(1000)
'''
# Out:
# '\nfunc = r.TF1("func", peak_fit, .22,.26,6)\nfunc.SetParNames(\'A\',\'Mean\',\'#sigma\',\'+ C\', \'+ D\',\'e^(-E*x)\' )\nfunc.SetParameters(.0001,.23,.1,0,0,-1)\nfunc.SetParLimits(0,0,1)\nfunc.SetParLimits(1,.22,.25)\nfunc.SetLineColor(2)\nfunc.SetNpx(1000)\n'

# %%
meanlist_noWindow = []
stdlist_noWindow = []
meanlist_window = []
stdlist_window = []

# %%
#for i in range(0,1):
for i in range(0,len(keyList)):
    ding = r.TH1D()
    filewindow.GetObject(keyList[i], ding)
    c = r.TCanvas()
#    c.SetLogy()
    ding.Draw("HIST P0 L")
    ding.GetXaxis().SetRangeUser(.15,.35)
    ding.GetYaxis().SetRangeUser(0.000000001,.00001)
    ding.Fit("func","REMB")
    func.Draw("SAME")
    c.Draw()
    c2 = r.TCanvas()
    func.Draw()
    meanlist_window.append(func.GetParameter(1))
    stdlist_window.append(func.GetParError(1))
    print(func.GetParameter(1), func.GetParError(1))
    c2.Draw()
# Out:
# 0.22996142670161443 0.00801117158319739
# 0.22998802308553115 0.008082040183385195
# 0.22998424900243328 0.008147969893700216
# 0.22995068104740302 0.008207661319249451
# 0.22989285508720778 0.008233215247702874
# 0.22982887212755765 0.008230318742994916
# 0.22976901777571407 0.00820186533623056
# 0.22972125730741846 0.008149232912599641
# 0.2296864741851307 0.008089106094516074
# 0.22966884455220565 0.008023453969588673
# 0.22967303417549362 0.007961241716418613
# 0.2296962751006045 0.007908889304127004
# 0.2297398784189009 0.007874478141375596
# 0.2298007807127535 0.007840335430087525
# 0.22986852190024037 0.007842301252669881
# 0.22993651471043292 0.007881244196611473
# 0.22998987307222715 0.007954064648252004
# 0.23001461847915813 0.008037460178369121
# 0.23000562042792028 0.00810399772286989
# 0.2299680867944396 0.008150186759711561
# 0.22990564095099958 0.008173751851921165
# 0.22982554882161482 0.008166752224324211
# 0.229754590920995 0.008132430775782934
# 0.2296987850896318 0.008076409970017628
# 0.22966554838297823 0.008010739802140246
# 0.22964576902138267 0.007951924358954823
# 0.22965235408444845 0.007885350139047786
# 0.22968354230531102 0.007836686797897008
# 0.22973305094453686 0.007786692689591035
# 0.2298065020804899 0.0077627738792850065
# 0.229884875376238 0.007773024570314049
# 0.22995669279295952 0.007819189973842885
# 0.2300135514697017 0.007901452641773513
# 0.23003909714324428 0.007992660844523644
# 0.23002241364435078 0.00806303514904122
# 0.22997684636013166 0.008108626002947136
# 0.2299004815866811 0.008126990242945484
# 0.22981603864919306 0.008116747104467595
# 0.22974207075910247 0.008081553001528477
# 0.2296848201765556 0.008027210985335084
# 0.22964499558958434 0.00797740603848511
# 0.22963046781078195 0.007898337964931432
# 0.22964368726491954 0.007830844373789503
# 0.2296805027718996 0.00776333844555166
# 0.22974031878830029 0.0077196519355301335
# 0.22982218381549682 0.007697430506453898
# 0.22990275375960956 0.007722464990595604
# 0.22998474265107868 0.0077745357507619794
#  FCN=0.00122728 FROM MINOS     STATUS=PROBLEMS     1814 CALLS        8261 TOTAL
#                      EDM=8.1849e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            5.50850e-08   1.68959e-07  -1.03239e-07   3.71294e+02
#    2  Mean         2.29961e-01   8.01117e-03   5.15207e-02  -2.86731e-05
#    3  #gamma       4.90115e-03   2.24264e-02  -2.66139e-03  -1.47247e-02
#    4  + C          2.01262e-07   1.88341e-06   1.88341e-06   5.94402e+02
#  FCN=0.0014228 FROM MINOS     STATUS=PROBLEMS     1689 CALLS        7449 TOTAL
#                      EDM=9.07592e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            5.49536e-08   1.70385e-07  -4.28596e-08   2.48146e+03
#    2  Mean         2.29988e-01   8.08204e-03   1.09751e-01  -1.70347e-04
#    3  #gamma       4.92348e-03   2.27977e-02  -1.41137e-03  -8.71752e-02
#    4  + C          2.20255e-07   1.94678e-06   1.94678e-06  -1.14122e+02
#  FCN=0.00138409 FROM MINOS     STATUS=PROBLEMS     1285 CALLS        7034 TOTAL
#                      EDM=5.64561e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            5.52296e-08   1.71991e-07   1.05995e-07   2.07004e+02
#    2  Mean         2.29984e-01   8.14797e-03   5.38599e-02  -6.67596e-05
#    3  #gamma       4.99063e-03   2.32862e-02   3.15466e-03  -5.94970e-03
#    4  + C          2.27912e-07   1.97549e-06   1.97549e-06   1.79533e+01
#  FCN=0.00113662 FROM MINOS     STATUS=PROBLEMS     1638 CALLS        7756 TOTAL
#                      EDM=4.83173e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            5.60406e-08   1.73711e-07  -3.59789e-07  -9.86284e+02
#    2  Mean         2.29951e-01   8.20766e-03   5.18499e-02  -1.19300e-04
#    3  #gamma       5.11852e-03   2.39778e-02  -9.99961e-03   3.15280e-02
#    4  + C          2.19444e-07   1.96612e-06   1.96612e-06   1.84579e+02
#  FCN=0.000881761 FROM MINOS     STATUS=PROBLEMS     1569 CALLS        7867 TOTAL
#                      EDM=4.9247e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            5.70945e-08   1.74786e-07   0.00000e+00  -1.19081e+05
#    2  Mean         2.29893e-01   8.23322e-03  -0.00000e+00   1.01685e-02
#    3  #gamma       5.24078e-03   2.44332e-02  -0.00000e+00   3.56916e+00
#    4  + C          1.98305e-07   1.91338e-06   1.91338e-06   9.25769e+02
#  FCN=0.00079569 FROM MINOS     STATUS=PROBLEMS     1823 CALLS        7326 TOTAL
#                      EDM=1.47869e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            5.82289e-08   1.74973e-07   1.20170e-07   1.47739e+02
#    2  Mean         2.29829e-01   8.23032e-03   4.67949e-02  -7.89334e-05
#    3  #gamma       5.33869e-03   2.45874e-02   3.27625e-03  -4.35933e-03
#    4  + C          1.67261e-07   1.82301e-06   1.82301e-06  -1.63739e+02
#  FCN=0.000901099 FROM MINOS     STATUS=PROBLEMS     1782 CALLS        7459 TOTAL
#                      EDM=8.0671e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            5.94329e-08   1.74265e-07   1.63340e-07  -1.86193e+03
#    2  Mean         2.29769e-01   8.20187e-03   6.82421e-02   3.28236e-05
#    3  #gamma       5.41235e-03   2.44542e-02   4.75835e-03   6.38178e-02
#    4  + C          1.28831e-07   1.69562e-06   1.69562e-06  -5.56900e+01
#  FCN=0.00120946 FROM MINOS     STATUS=PROBLEMS     1677 CALLS        6868 TOTAL
#                      EDM=1.6722e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.06926e-08   1.72636e-07   6.36977e-08   6.66459e+03
#    2  Mean         2.29721e-01   8.14923e-03  -5.94793e-02   3.22031e-03
#    3  #gamma       5.46356e-03   2.40504e-02   1.55681e-03  -1.41531e-01
#    4  + C          8.51146e-08   1.52547e-06   1.52547e-06   3.40939e+02
#  FCN=0.00177229 FROM MINOS     STATUS=PROBLEMS     1258 CALLS        5926 TOTAL
#                      EDM=1.38652e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.21205e-08   1.70004e-07   6.75006e-08  -1.99418e+02
#    2  Mean         2.29686e-01   8.08911e-03   2.50885e-02   2.15370e-05
#    3  #gamma       5.52748e-03   2.35884e-02   2.74490e-03   4.77074e-03
#    4  + C          3.72253e-08   1.29492e-06   1.29492e-06  -4.88655e+02
#  FCN=0.001816 FROM MINOS     STATUS=PROBLEMS     1623 CALLS        7447 TOTAL
#                      EDM=4.0395e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.27764e-08   1.67812e-07   2.64053e-08   5.03612e+03
#    2  Mean         2.29669e-01   8.02345e-03  -3.85649e-02   9.94613e-05
#    3  #gamma       5.50701e-03   2.29167e-02   1.27349e-03  -1.00781e-01
#    4  + C          1.00341e-08   1.13806e-06   1.13806e-06  -2.34942e+00
#  FCN=0.00192453 FROM MINOS     STATUS=PROBLEMS      889 CALLS        7095 TOTAL
#                      EDM=2.78036e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.30175e-08   1.66949e-07   1.26815e-08   6.90552e+03
#    2  Mean         2.29673e-01   7.96124e-03   2.62240e-02   2.35947e-02
#    3  #gamma       5.46315e-03   2.24670e-02   7.88627e-04  -9.00732e-01
#    4  + C          3.31322e-09   1.08996e-06   1.08996e-06   5.94175e+02
#  FCN=0.00166021 FROM MINOS     STATUS=PROBLEMS      920 CALLS        6156 TOTAL
#                      EDM=2.11958e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.27243e-08   1.67981e-07   1.90892e-09   3.48112e+03
#    2  Mean         2.29696e-01   7.90889e-03   1.25783e-02   4.83946e-03
#    3  #gamma       5.39276e-03   2.23229e-02   2.43403e-04  -2.77235e-01
#    4  + C          2.56215e-08   1.21005e-06   1.21005e-06  -2.92360e+03
#  FCN=0.00144493 FROM MINOS     STATUS=PROBLEMS      124 CALLS        5434 TOTAL
#                      EDM=4.81747e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.19866e-08   1.70273e-07  -4.81806e-09  -2.79753e+06
#    2  Mean         2.29740e-01   7.87448e-03   7.37430e-05  -4.30469e-01
#    3  #gamma       5.30321e-03   2.23856e-02  -4.44853e-02  -2.71988e+01
#    4  + C          6.70819e-08   1.41590e-06   1.41590e-06  -9.69342e+00
#  FCN=0.00118897 FROM MINOS     STATUS=PROBLEMS     1536 CALLS        6906 TOTAL
#                      EDM=7.67514e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.10524e-08   1.72724e-07   2.93442e-07   6.46578e+01
#    2  Mean         2.29801e-01   7.84034e-03   6.58844e-04   4.95589e-04
#    3  #gamma       5.18977e-03   2.23537e-02   8.52431e-03  -4.83323e-03
#    4  + C          1.18379e-07   1.63198e-06   1.63198e-06  -9.21826e+01
#  FCN=0.00101992 FROM MINOS     STATUS=PROBLEMS     1892 CALLS        7366 TOTAL
#                      EDM=2.82397e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            5.99253e-08   1.74694e-07   1.07870e-07  -2.20240e+03
#    2  Mean         2.29869e-01   7.84230e-03   5.70320e-02   2.74852e-04
#    3  #gamma       5.08010e-03   2.23492e-02   2.91515e-03   7.63843e-02
#    4  + C          1.72695e-07   1.82390e-06   1.82390e-06  -7.45109e+02
#  FCN=0.0011058 FROM MINOS     STATUS=PROBLEMS     1086 CALLS        6455 TOTAL
#                      EDM=3.907e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            5.87863e-08   1.76191e-07   1.49131e-07   1.04599e+03
#    2  Mean         2.29937e-01   7.88124e-03  -7.22180e-02  -5.17395e-05
#    3  #gamma       4.98652e-03   2.23850e-02   6.28344e-03  -2.58317e-02
#    4  + C          2.23909e-07   1.98312e-06   1.98312e-06  -7.66574e+02
#  FCN=0.00136787 FROM MINOS     STATUS=PROBLEMS     1690 CALLS        7727 TOTAL
#                      EDM=3.37138e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            5.79010e-08   1.77436e-07   1.22210e-07   6.41692e+02
#    2  Mean         2.29990e-01   7.95406e-03  -5.22741e-02   1.95087e-05
#    3  #gamma       4.93531e-03   2.25488e-02   2.88371e-03  -2.68554e-02
#    4  + C          2.63972e-07   2.09924e-06   2.09924e-06   7.72324e+02
#  FCN=0.00149035 FROM MINOS     STATUS=PROBLEMS     1709 CALLS        7528 TOTAL
#                      EDM=1.75752e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            5.75471e-08   1.78766e-07  -1.02111e-08  -1.39313e+03
#    2  Mean         2.30015e-01   8.03746e-03  -1.02294e-01   1.55474e-04
#    3  #gamma       4.94930e-03   2.29204e-02   1.05194e-05   6.00172e-02
#    4  + C          2.87237e-07   2.16792e-06   2.16792e-06   7.97889e+02
#  FCN=0.00132456 FROM MINOS     STATUS=PROBLEMS     1451 CALLS        7243 TOTAL
#                      EDM=6.1378e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            5.77416e-08   1.80261e-07   1.15395e-07   2.04033e+03
#    2  Mean         2.30006e-01   8.10400e-03   5.99929e-03  -6.06475e-03
#    3  #gamma       5.01511e-03   2.34042e-02   3.09237e-03  -6.42635e-02
#    4  + C          2.94291e-07   2.19221e-06   2.19221e-06   4.58788e+02
#  FCN=0.00103522 FROM MINOS     STATUS=PROBLEMS     1709 CALLS        7582 TOTAL
#                      EDM=2.37922e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            5.86069e-08   1.81848e-07  -0.00000e+00   5.41717e+04
#    2  Mean         2.29968e-01   8.15019e-03  -0.00000e+00   1.60561e-02
#    3  #gamma       5.14136e-03   2.40400e-02   0.00000e+00  -2.39908e+00
#    4  + C          2.81459e-07   2.17376e-06   2.17376e-06  -1.25467e+00
#  FCN=0.000838888 FROM MINOS     STATUS=PROBLEMS     1806 CALLS        7217 TOTAL
#                      EDM=1.65934e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            5.99151e-08   1.82915e-07   2.28958e-07   2.64039e+03
#    2  Mean         2.29906e-01   8.17375e-03   8.40616e-02  -4.99883e-05
#    3  #gamma       5.29043e-03   2.45896e-02   5.32641e-03  -1.12488e-01
#    4  + C          2.50322e-07   2.10085e-06   2.10085e-06  -1.42690e+02
#  FCN=0.000890622 FROM MINOS     STATUS=PROBLEMS     2076 CALLS        7767 TOTAL
#                      EDM=3.36422e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.16065e-08   1.83110e-07  -4.74787e-08   3.34440e+02
#    2  Mean         2.29826e-01   8.16675e-03  -2.54841e-02   2.37625e-05
#    3  #gamma       5.43592e-03   2.48568e-02  -1.28623e-03  -1.34071e-02
#    4  + C          2.01671e-07   1.96990e-06   1.96990e-06  -7.62197e+02
#  FCN=0.00119512 FROM MINOS     STATUS=PROBLEMS     1870 CALLS        6899 TOTAL
#                      EDM=8.96924e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.34061e-08   1.82133e-07  -7.08758e-08  -3.89685e+03
#    2  Mean         2.29755e-01   8.13243e-03   5.89848e-02  -8.92351e-04
#    3  #gamma       5.55313e-03   2.47791e-02  -1.75864e-03   1.34504e-01
#    4  + C          1.44630e-07   1.79134e-06   1.79134e-06  -1.35885e+02
#  FCN=0.00173612 FROM MINOS     STATUS=PROBLEMS     1321 CALLS        6673 TOTAL
#                      EDM=4.85709e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.53065e-08   1.79952e-07   1.03301e-08   1.24609e+03
#    2  Mean         2.29699e-01   8.07641e-03   3.05980e-02   1.91328e-04
#    3  #gamma       5.65183e-03   2.44297e-02   4.38921e-04  -4.18713e-02
#    4  + C          8.25396e-08   1.55556e-06   1.55556e-06  -7.43099e+02
#  FCN=0.0027843 FROM MINOS     STATUS=PROBLEMS     1751 CALLS        7404 TOTAL
#                      EDM=9.31263e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.74820e-08   1.76327e-07   4.72532e-08  -6.97818e+03
#    2  Mean         2.29666e-01   8.01074e-03   1.83421e-02  -2.21886e-04
#    3  #gamma       5.77177e-03   2.39934e-02   2.02005e-03   1.65086e-01
#    4  + C          1.68317e-08   1.21811e-06   1.21811e-06  -2.16768e+02
#  FCN=0.00214055 FROM MINOS     STATUS=PROBLEMS     1534 CALLS        8264 TOTAL
#                      EDM=3.78211e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.76044e-08   1.74655e-07  -4.42691e-08   3.41233e+02
#    2  Mean         2.29646e-01   7.95192e-03  -1.65996e-02   4.95844e-05
#    3  #gamma       5.69494e-03   2.32214e-02  -2.35022e-03  -6.78721e-03
#    4  + C          2.20739e-09   1.13616e-06   1.13616e-06  -4.94617e+01
#  FCN=0.00201603 FROM MINOS     STATUS=PROBLEMS     1713 CALLS        7910 TOTAL
#                      EDM=2.06171e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.75036e-08   1.74788e-07  -1.67068e-08   8.27349e+02
#    2  Mean         2.29652e-01   7.88535e-03  -5.95840e-03  -1.02191e-04
#    3  #gamma       5.60993e-03   2.27580e-02  -6.64423e-04  -1.98856e-02
#    4  + C          9.03579e-09   1.17962e-06   1.17962e-06  -6.11404e+02
#  FCN=0.00247745 FROM MINOS     STATUS=PROBLEMS     1759 CALLS        7303 TOTAL
#                      EDM=6.03115e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.75374e-08   1.75675e-07  -5.24760e-09   1.89919e+03
#    2  Mean         2.29684e-01   7.83669e-03   4.21684e-02  -6.48020e-05
#    3  #gamma       5.58294e-03   2.27930e-02  -2.61768e-04  -4.87581e-02
#    4  + C          3.01897e-08   1.26892e-06   1.26892e-06   1.53926e+03
#  FCN=0.00147985 FROM MINOS     STATUS=PROBLEMS     1735 CALLS        7619 TOTAL
#                      EDM=1.12923e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.58432e-08   1.79477e-07  -1.92998e-08   1.28641e+03
#    2  Mean         2.29733e-01   7.78669e-03  -4.13937e-02  -2.68066e-06
#    3  #gamma       5.38435e-03   2.25993e-02  -6.26433e-04  -4.00805e-02
#    4  + C          1.00680e-07   1.61183e-06   1.61183e-06   1.44620e+02
#  FCN=0.00087436 FROM MINOS     STATUS=PROBLEMS     1228 CALLS        5724 TOTAL
#                      EDM=2.35348e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.43581e-08   1.82035e-07   9.75585e-08   1.11304e+03
#    2  Mean         2.29807e-01   7.76277e-03   2.91012e-02  -7.16842e-05
#    3  #gamma       5.23546e-03   2.25198e-02   2.81896e-03  -3.79775e-02
#    4  + C          1.70764e-07   1.86258e-06   1.86258e-06   1.01335e+01
#  FCN=0.000712559 FROM MINOS     STATUS=PROBLEMS     1777 CALLS        7479 TOTAL
#                      EDM=5.84696e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.29943e-08   1.83714e-07  -2.15103e-06   4.56032e+02
#    2  Mean         2.29885e-01   7.77302e-03  -1.57289e-01  -6.94229e-04
#    3  #gamma       5.11639e-03   2.24890e-02  -6.17992e-02  -1.24316e-02
#    4  + C          2.34437e-07   2.05315e-06   2.05315e-06  -4.81205e+01
#  FCN=0.00098583 FROM MINOS     STATUS=PROBLEMS     1767 CALLS        7227 TOTAL
#                      EDM=5.46106e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.17287e-08   1.84760e-07   1.18623e-07   2.06984e+03
#    2  Mean         2.29957e-01   7.81919e-03   8.85208e-02  -1.47625e-04
#    3  #gamma       5.02045e-03   2.24831e-02   2.55583e-03  -9.08772e-02
#    4  + C          2.88097e-07   2.19612e-06   2.19612e-06   6.77002e+02
#  FCN=0.00148891 FROM MINOS     STATUS=PROBLEMS     1861 CALLS        7583 TOTAL
#                      EDM=4.01013e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.07463e-08   1.85601e-07   1.52241e-07   8.93808e+02
#    2  Mean         2.30014e-01   7.90145e-03   4.05013e-02  -1.84243e-04
#    3  #gamma       4.97086e-03   2.26318e-02   3.25481e-03  -3.94030e-02
#    4  + C          3.27708e-07   2.29705e-06   2.29705e-06  -1.23722e-02
#  FCN=0.00178305 FROM MINOS     STATUS=PROBLEMS     1534 CALLS        7487 TOTAL
#                      EDM=1.78098e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.03856e-08   1.86707e-07  -2.58470e-08  -1.91211e+03
#    2  Mean         2.30039e-01   7.99266e-03   5.89216e-02  -8.70013e-05
#    3  #gamma       4.99424e-03   2.30295e-02  -6.25602e-04   7.15021e-02
#    4  + C          3.47958e-07   2.35182e-06   2.35182e-06   6.53212e+02
#  FCN=0.0016488 FROM MINOS     STATUS=PROBLEMS     1175 CALLS        7690 TOTAL
#                      EDM=3.08227e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.07352e-08   1.88252e-07   5.22295e-08  -1.67282e+03
#    2  Mean         2.30022e-01   8.06304e-03   3.29112e-02   2.06139e-04
#    3  #gamma       5.08695e-03   2.36345e-02   1.44586e-03   5.54172e-02
#    4  + C          3.48441e-07   2.36237e-06   2.36237e-06   4.37093e+02
#  FCN=0.00130321 FROM MINOS     STATUS=PROBLEMS      899 CALLS        6656 TOTAL
#                      EDM=1.47296e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.18713e-08   1.90016e-07  -8.57827e-09  -3.13727e+02
#    2  Mean         2.29977e-01   8.10863e-03  -1.59113e-02   3.75218e-03
#    3  #gamma       5.24175e-03   2.43705e-02  -5.83287e-04  -9.77787e-02
#    4  + C          3.27070e-07   2.32472e-06   2.32472e-06  -1.52914e+00
#  FCN=0.00108642 FROM MINOS     STATUS=PROBLEMS     1744 CALLS        7729 TOTAL
#                      EDM=3.35045e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.34718e-08   1.91145e-07   9.77366e-08  -2.67240e+03
#    2  Mean         2.29900e-01   8.12699e-03  -2.01022e-02   2.11934e-04
#    3  #gamma       5.41426e-03   2.49773e-02   2.28577e-03   1.15847e-01
#    4  + C          2.86140e-07   2.23314e-06   2.23314e-06  -6.40533e+01
#  FCN=0.00113483 FROM MINOS     STATUS=PROBLEMS     1668 CALLS        7504 TOTAL
#                      EDM=4.53496e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.53771e-08   1.91290e-07   2.41874e-08  -2.75512e+02
#    2  Mean         2.29816e-01   8.11675e-03   7.63225e-03   1.69483e-05
#    3  #gamma       5.57107e-03   2.52595e-02   7.02718e-04   9.29885e-03
#    4  + C          2.29953e-07   2.08943e-06   2.08943e-06   1.05114e+03
#  FCN=0.00145075 FROM MINOS     STATUS=PROBLEMS     1145 CALLS        7146 TOTAL
#                      EDM=1.05162e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.74202e-08   1.90248e-07   3.07890e-08  -2.87204e+03
#    2  Mean         2.29742e-01   8.08155e-03   5.25902e-02  -1.62318e-03
#    3  #gamma       5.70114e-03   2.52043e-02   1.07021e-03   1.62286e-01
#    4  + C          1.65718e-07   1.89801e-06   1.89801e-06  -7.52941e+00
#  FCN=0.00209425 FROM MINOS     STATUS=PROBLEMS     1512 CALLS        6616 TOTAL
#                      EDM=1.14065e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.97416e-08   1.87840e-07   4.02931e-07  -1.70616e+03
#    2  Mean         2.29685e-01   8.02721e-03   8.16412e-04  -7.93651e-04
#    3  #gamma       5.82999e-03   2.49246e-02   1.32710e-02   5.09130e-02
#    4  + C          9.31997e-08   1.63269e-06   1.63269e-06   1.31641e+01
#  FCN=0.00290019 FROM MINOS     STATUS=PROBLEMS     1787 CALLS        7576 TOTAL
#                      EDM=3.32999e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            7.21702e-08   1.83671e-07   1.80658e-08   1.54621e+03
#    2  Mean         2.29645e-01   7.97741e-03   3.43721e-02  -8.67356e-05
#    3  #gamma       5.97321e-03   2.45475e-02   6.38365e-04  -3.90904e-02
#    4  + C          2.01139e-08   1.26450e-06   1.26450e-06   3.89456e+03
#  FCN=0.00253064 FROM MINOS     STATUS=PROBLEMS     1504 CALLS        7193 TOTAL
#                      EDM=2.78609e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            7.25088e-08   1.82540e-07  -3.16538e-09  -6.29756e+02
#    2  Mean         2.29630e-01   7.89834e-03  -2.57717e-02   5.45569e-05
#    3  #gamma       5.88971e-03   2.37212e-02  -8.12233e-05   1.24456e-02
#    4  + C          1.35864e-09   1.18614e-06   1.18614e-06  -8.06780e+00
#  FCN=0.00269292 FROM MINOS     STATUS=PROBLEMS     1694 CALLS        8158 TOTAL
#                      EDM=3.7744e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            7.26790e-08   1.82452e-07   2.45359e-07   6.04069e+03
#    2  Mean         2.29644e-01   7.83084e-03  -7.49939e-02   1.10445e-03
#    3  #gamma       5.83353e-03   2.33634e-02   1.00204e-02  -1.39483e-01
#    4  + C          8.71741e-09   1.21032e-06   1.21032e-06  -4.54565e+02
#  FCN=0.00184442 FROM MINOS     STATUS=PROBLEMS     1331 CALLS        6817 TOTAL
#                      EDM=6.96017e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            7.09955e-08   1.86235e-07  -3.95872e-07   5.16059e+02
#    2  Mean         2.29681e-01   7.76334e-03  -1.47358e-01  -1.30956e-04
#    3  #gamma       5.61894e-03   2.30360e-02  -1.36691e-02  -1.56870e-02
#    4  + C          7.49512e-08   1.56166e-06   1.56166e-06   4.11677e+01
#  FCN=0.00122647 FROM MINOS     STATUS=PROBLEMS     1527 CALLS        7756 TOTAL
#                      EDM=3.94813e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.94411e-08   1.89069e-07   3.29394e-05   7.84627e+02
#    2  Mean         2.29740e-01   7.71965e-03  -1.57836e+01   6.16303e-07
#    3  #gamma       5.45345e-03   2.28843e-02   1.06516e+00  -2.79524e-02
#    4  + C          1.49002e-07   1.83768e-06   1.83768e-06  -9.17634e+01
#  FCN=0.000836602 FROM MINOS     STATUS=PROBLEMS     1772 CALLS        7404 TOTAL
#                      EDM=4.95182e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.78899e-08   1.91215e-07   5.77661e-08   2.56499e+03
#    2  Mean         2.29822e-01   7.69743e-03  -8.08188e-02   1.71354e-04
#    3  #gamma       5.30597e-03   2.27696e-02   1.34984e-03  -9.91391e-02
#    4  + C          2.25444e-07   2.06956e-06   2.06956e-06  -2.41905e+02
#  FCN=0.000871615 FROM MINOS     STATUS=PROBLEMS     1726 CALLS        7373 TOTAL
#                      EDM=5.94836e-11    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.63096e-08   1.92540e-07  -1.50358e-08   1.84717e+03
#    2  Mean         2.29903e-01   7.72246e-03  -7.37117e-02   8.89010e-05
#    3  #gamma       5.18531e-03   2.27535e-02  -4.76015e-04  -8.37211e-02
#    4  + C          2.95067e-07   2.25219e-06   2.25219e-06  -1.05661e+01
#  FCN=0.00136884 FROM MINOS     STATUS=PROBLEMS     1834 CALLS        7681 TOTAL
#                      EDM=6.97989e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.48475e-08   1.93196e-07  -4.85012e-08  -6.93410e+01
#    2  Mean         2.29985e-01   7.77454e-03  -1.91442e-03   8.53639e-05
#    3  #gamma       5.07516e-03   2.26563e-02  -9.24321e-04   2.91639e-03
#    4  + C          3.52760e-07   2.38951e-06   2.38951e-06   2.19393e+02

# %%
print(meanlist_window)
# Out:
# [0.22996142670161443, 0.22998802308553115, 0.22998424900243328, 0.22995068104740302, 0.22989285508720778, 0.22982887212755765, 0.22976901777571407, 0.22972125730741846, 0.2296864741851307, 0.22966884455220565, 0.22967303417549362, 0.2296962751006045, 0.2297398784189009, 0.2298007807127535, 0.22986852190024037, 0.22993651471043292, 0.22998987307222715, 0.23001461847915813, 0.23000562042792028, 0.2299680867944396, 0.22990564095099958, 0.22982554882161482, 0.229754590920995, 0.2296987850896318, 0.22966554838297823, 0.22964576902138267, 0.22965235408444845, 0.22968354230531102, 0.22973305094453686, 0.2298065020804899, 0.229884875376238, 0.22995669279295952, 0.2300135514697017, 0.23003909714324428, 0.23002241364435078, 0.22997684636013166, 0.2299004815866811, 0.22981603864919306, 0.22974207075910247, 0.2296848201765556, 0.22964499558958434, 0.22963046781078195, 0.22964368726491954, 0.2296805027718996, 0.22974031878830029, 0.22982218381549682, 0.22990275375960956, 0.22998474265107868]

# %%
gr = r.TGraphErrors()

for i in range(0,len(meanlist_window)):
#    print(i, meanlist_window[i])
    gr.SetPoint(i,i+1,meanlist_window[i])
#    gr.SetPointError(i,0,stdlist_window[i])
    
c = r.TCanvas()
gr.Draw()
c.Draw()

# %%
filenowindow.cd()
keyListNoWindow = filenowindow.GetKeyNames("")
print ("\nKeys in file:", keyListNoWindow)
# Out:
# Keys in file: ['time0_noWindow', 'time1_noWindow', 'time2_noWindow', 'time3_noWindow', 'time4_noWindow', 'time5_noWindow', 'time6_noWindow', 'time7_noWindow', 'time8_noWindow', 'time9_noWindow', 'time10_noWindow', 'time11_noWindow', 'time12_noWindow', 'time13_noWindow', 'time14_noWindow', 'time15_noWindow', 'time16_noWindow', 'time17_noWindow', 'time18_noWindow', 'time19_noWindow', 'time20_noWindow', 'time21_noWindow', 'time22_noWindow', 'time23_noWindow', 'time24_noWindow', 'time25_noWindow', 'time26_noWindow', 'time27_noWindow', 'time28_noWindow', 'time29_noWindow', 'time30_noWindow', 'time31_noWindow', 'time32_noWindow', 'time33_noWindow', 'time34_noWindow', 'time35_noWindow', 'time36_noWindow', 'time37_noWindow', 'time38_noWindow', 'time39_noWindow', 'time40_noWindow', 'time41_noWindow', 'time42_noWindow', 'time43_noWindow', 'time44_noWindow', 'time45_noWindow', 'time46_noWindow', 'time47_noWindow']

# %%
for i in range(0,len(keyListNoWindow)):
    ding = r.TH1D()
    filenowindow.GetObject(keyListNoWindow[i], ding)
    c = r.TCanvas()
    c.SetLogy()
    ding.Draw("HIST P0 L")
    ding.GetXaxis().SetRangeUser(.15,.75)
    ding.Fit("func","REM")
    func.Draw("SAME")
    c.Draw()
    c2 = r.TCanvas()
    func.Draw()
    meanlist_noWindow.append(func.GetParameter(1))
    stdlist_noWindow.append(func.GetParError(1))
    print(func.GetParameter(1), func.GetParError(1))
    c2.Draw()
# Out:
# 0.23048437524477794 0.006423558379109573
# 0.23064131832187737 0.006626879604969715
# 0.23068205033436856 0.006776156074220982
# 0.23055337791504 0.006792711653839614
# 0.23026320350191692 0.006711407210730977
# 0.22990577275852728 0.006636861882991549
# 0.22956232154068293 0.006587409115190859
# 0.22929759326330743 0.00652850770314127
# 0.22913503464288262 0.0064592146812153806
# 0.22908344009622109 0.006431843821593189
# 0.22913913044094583 0.006331417182016158
# 0.22927466615758454 0.006234278538495411
# 0.22947821957618023 0.006164012151144205
# 0.22972056549775705 0.006131938451998456
# 0.22999277400796964 0.006160033779439286
# 0.2302729794652836 0.006275615310080931
# 0.23051275908353783 0.006470775629818917
# 0.23066080850278628 0.006685447316671214
# 0.23067764868708057 0.00681689787281857
# 0.23054881314696304 0.006818824452905006
# 0.2302705825006845 0.006728275227232544
# 0.22988529661218857 0.0066410717478238845
# 0.2295282305715366 0.006586118789788389
# 0.2292638130432576 0.006522307630534491
# 0.22912030788184518 0.006457327663960857
# 0.22908294532281884 0.0064312795185099
# 0.2291454719323645 0.006313757323537214
# 0.22928283003206232 0.006228380498842667
# 0.2294922928986148 0.006165197131861977
# 0.22975203188087734 0.0061400705992809695
# 0.23003289955527007 0.006181780973709014
# 0.23030409030918103 0.006308066711404395
# 0.23053665638866247 0.006512876596620656
# 0.23067511717178255 0.006725364458897751
# 0.23068053542228656 0.006855925327641371
# 0.2305122146446972 0.006833204069733409
# 0.2302064226732389 0.0067385271909088384
# 0.22983459187337946 0.006660604351300892
# 0.22950458882641764 0.006607803564029513
# 0.2292618464424269 0.006541804808635365
# 0.2291246869908082 0.006472976959295662
# 0.22910045243168561 0.006441364909225117
# 0.2291743663721639 0.006314752755680192
# 0.22932975863751362 0.006224833325680981
# 0.2295466894950747 0.00616876450215556
# 0.2298083646129933 0.006158391704359001
# 0.23008895313786967 0.006216153709265648
# 0.23035919986452397 0.006364839593632349
#  FCN=0.0111678 FROM MINOS     STATUS=PROBLEMS     1543 CALLS        8247 TOTAL
#                      EDM=2.68107e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.31860e-07   6.41567e-07  -1.21561e-07   1.95743e+02
#    2  Mean         2.30484e-01   6.42356e-03  -7.05451e-03   2.64199e-05
#    3  #gamma       8.15610e-03   2.21098e-02  -6.96952e-04  -3.44557e-02
#    4  + C          4.13220e-06   8.93402e-06   8.93402e-06   3.94992e+02
#  FCN=0.0160098 FROM MINOS     STATUS=PROBLEMS     1506 CALLS        7874 TOTAL
#                      EDM=1.71338e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.11739e-07   6.24329e-07  -1.68780e-07   5.36461e+02
#    2  Mean         2.30641e-01   6.62688e-03  -2.88655e-02   1.19048e-04
#    3  #gamma       7.89816e-03   2.20709e-02  -9.37638e-04  -9.91748e-02
#    4  + C          4.29464e-06   8.96787e-06   8.96787e-06   1.74330e+01
#  FCN=0.0169037 FROM MINOS     STATUS=PROBLEMS     1031 CALLS        7495 TOTAL
#                      EDM=6.49443e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            2.99184e-07   6.13490e-07   4.91601e-08  -2.07555e+03
#    2  Mean         2.30682e-01   6.77616e-03   4.27874e-02   2.60144e-03
#    3  #gamma       7.84840e-03   2.24333e-02  -5.48466e-05   1.68494e-01
#    4  + C          4.22856e-06   8.87491e-06   8.87491e-06   3.30217e+02
#  FCN=0.0114759 FROM MINOS     STATUS=PROBLEMS     1373 CALLS        7939 TOTAL
#                      EDM=3.10803e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            2.98898e-07   6.14819e-07   1.44716e-07   1.59543e+02
#    2  Mean         2.30553e-01   6.79271e-03  -2.88004e-02   8.88592e-05
#    3  #gamma       8.10457e-03   2.33347e-02   8.09293e-04  -2.45200e-02
#    4  + C          3.91115e-06   8.66485e-06   8.66485e-06   8.08656e+01
#  FCN=0.00550867 FROM MINOS     STATUS=PROBLEMS     1302 CALLS        7739 TOTAL
#                      EDM=1.46841e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.11520e-07   6.24356e-07  -1.45751e-07   1.61299e+02
#    2  Mean         2.30263e-01   6.71141e-03   2.63894e-03  -1.16832e-04
#    3  #gamma       8.57865e-03   2.42588e-02  -8.49539e-04  -2.81125e-02
#    4  + C          3.36210e-06   8.29848e-06   8.29848e-06   1.86483e+02
#  FCN=0.00323228 FROM MINOS     STATUS=PROBLEMS     1329 CALLS        7048 TOTAL
#                      EDM=1.92575e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.32630e-07   6.31665e-07   6.83999e-08   2.16973e+02
#    2  Mean         2.29906e-01   6.63686e-03   1.66623e-02  -2.05370e-04
#    3  #gamma       9.05732e-03   2.44913e-02   3.89269e-04  -2.63199e-02
#    4  + C          2.67690e-06   7.75599e-06   7.75599e-06  -1.28364e+02
#  FCN=0.0038657 FROM MINOS     STATUS=PROBLEMS     1352 CALLS        6640 TOTAL
#                      EDM=7.11447e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.58810e-07   6.30981e-07   1.17892e-07  -9.80612e+01
#    2  Mean         2.29562e-01   6.58741e-03   2.95168e-02   2.40342e-05
#    3  #gamma       9.44151e-03   2.38723e-02   8.30229e-04   1.47016e-02
#    4  + C          1.91748e-06   7.03099e-06   7.03099e-06   2.98235e+01
#  FCN=0.00599206 FROM MINOS     STATUS=PROBLEMS     1199 CALLS        7692 TOTAL
#                      EDM=2.48493e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.88592e-07   6.22379e-07   1.17321e-07   3.36069e+02
#    2  Mean         2.29298e-01   6.52851e-03   2.59158e-02  -2.12778e-04
#    3  #gamma       9.75149e-03   2.27275e-02   9.47939e-04  -3.46427e-02
#    4  + C          1.13059e-06   6.13359e-06   6.13359e-06  -1.10913e+01
#  FCN=0.00816843 FROM MINOS     STATUS=PROBLEMS     1192 CALLS        6163 TOTAL
#                      EDM=3.43363e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.22606e-07   6.09550e-07   1.97476e-09   2.05023e+03
#    2  Mean         2.29135e-01   6.45921e-03   3.46226e-02  -2.44652e-04
#    3  #gamma       1.01118e-02   2.16483e-02  -4.42889e-05  -2.06058e-01
#    4  + C          3.73159e-07   5.04088e-06   5.04088e-06   3.05025e+02
#  FCN=0.00973308 FROM MINOS     STATUS=PROBLEMS     1175 CALLS        6446 TOTAL
#                      EDM=3.08726e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.60153e-07   5.95261e-07  -3.89393e-08   3.06500e+02
#    2  Mean         2.29083e-01   6.43184e-03  -8.42920e-03   3.09325e-04
#    3  #gamma       1.06749e-02   2.12485e-02  -5.13148e-04  -2.74069e-02
#    4  + C         -2.10009e-07   3.71022e-06   3.71022e-06  -1.95647e+02
#  FCN=0.00932662 FROM MINOS     STATUS=PROBLEMS     1084 CALLS        7607 TOTAL
#                      EDM=2.21418e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.57170e-07   6.19369e-07   8.03326e-08  -1.41731e+03
#    2  Mean         2.29139e-01   6.33142e-03  -5.28132e-02  -1.62120e-05
#    3  #gamma       1.04163e-02   2.13500e-02   8.85121e-04   1.24981e-01
#    4  + C          1.37725e-07   4.63912e-06   4.63912e-06   3.80781e+01
#  FCN=0.00736593 FROM MINOS     STATUS=PROBLEMS     1074 CALLS        5964 TOTAL
#                      EDM=5.65697e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.40032e-07   6.45256e-07  -1.36845e-08   4.97698e+01
#    2  Mean         2.29275e-01   6.23428e-03  -1.54498e-02   2.28490e-05
#    3  #gamma       9.98066e-03   2.16104e-02  -1.39484e-04  -8.80570e-03
#    4  + C          8.67671e-07   5.92289e-06   5.92289e-06  -1.72802e+02
#  FCN=0.00553469 FROM MINOS     STATUS=PROBLEMS     1166 CALLS        6471 TOTAL
#                      EDM=4.77709e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.22597e-07   6.62930e-07   2.38741e-07   1.25883e+03
#    2  Mean         2.29478e-01   6.16401e-03  -7.36441e-02  -4.58095e-05
#    3  #gamma       9.63155e-03   2.19690e-02   1.64753e-03  -1.76199e-01
#    4  + C          1.66204e-06   6.92702e-06   6.92702e-06  -1.12497e+02
#  FCN=0.00430455 FROM MINOS     STATUS=PROBLEMS     1184 CALLS        7130 TOTAL
#                      EDM=8.67317e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.04005e-07   6.72368e-07   6.00265e-08   9.74105e+01
#    2  Mean         2.29721e-01   6.13194e-03   1.92835e-02  -2.46868e-05
#    3  #gamma       9.31249e-03   2.22937e-02   3.91022e-04  -1.34289e-02
#    4  + C          2.41857e-06   7.71389e-06   7.71389e-06   5.02130e+01
#  FCN=0.00440706 FROM MINOS     STATUS=PROBLEMS     1258 CALLS        6790 TOTAL
#                      EDM=1.46783e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.81964e-07   6.71780e-07  -3.72494e-07  -5.24972e+02
#    2  Mean         2.29993e-01   6.16003e-03  -4.65176e-02   1.34633e-04
#    3  #gamma       8.96155e-03   2.24677e-02  -2.56300e-03   7.83750e-02
#    4  + C          3.11749e-06   8.31934e-06   8.31934e-06  -1.74125e+02
#  FCN=0.00673586 FROM MINOS     STATUS=PROBLEMS     1392 CALLS        7727 TOTAL
#                      EDM=2.43047e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.56287e-07   6.60767e-07   2.16843e-08   2.12846e+02
#    2  Mean         2.30273e-01   6.27562e-03   2.48026e-02  -1.55341e-05
#    3  #gamma       8.56148e-03   2.24413e-02   1.02020e-04  -3.57171e-02
#    4  + C          3.72001e-06   8.74238e-06   8.74238e-06   2.89755e+01
#  FCN=0.0114985 FROM MINOS     STATUS=PROBLEMS     1603 CALLS        8194 TOTAL
#                      EDM=3.76798e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.30455e-07   6.42488e-07  -1.19801e-07   2.05782e+02
#    2  Mean         2.30513e-01   6.47078e-03  -1.54924e-03  -1.95316e-04
#    3  #gamma       8.17076e-03   2.22750e-02  -6.14083e-04  -3.96949e-02
#    4  + C          4.12628e-06   8.95194e-06   8.95194e-06   3.82598e+02
#  FCN=0.0160678 FROM MINOS     STATUS=PROBLEMS     1695 CALLS        9038 TOTAL
#                      EDM=1.81869e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.09957e-07   6.25085e-07   2.85719e-08   6.85226e+02
#    2  Mean         2.30661e-01   6.68545e-03   5.71247e-02  -1.11263e-04
#    3  #gamma       7.92167e-03   2.23014e-02   1.01305e-04  -1.24809e-01
#    4  + C          4.27873e-06   8.97569e-06   8.97569e-06  -7.71488e+01
#  FCN=0.0160177 FROM MINOS     STATUS=PROBLEMS     1530 CALLS        8115 TOTAL
#                      EDM=1.26373e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            2.99014e-07   6.16334e-07  -4.91278e-07  -2.33642e+01
#    2  Mean         2.30678e-01   6.81690e-03  -2.08216e-02   1.64396e-04
#    3  #gamma       7.90841e-03   2.27508e-02  -2.37462e-03   2.78208e-03
#    4  + C          4.19890e-06   8.88247e-06   8.88247e-06   3.50343e+02
#  FCN=0.0110017 FROM MINOS     STATUS=PROBLEMS     1451 CALLS        7846 TOTAL
#                      EDM=2.5252e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            2.99825e-07   6.18648e-07   3.45904e-08   9.89298e+01
#    2  Mean         2.30549e-01   6.81882e-03   7.75556e-02  -1.89990e-05
#    3  #gamma       8.15797e-03   2.35855e-02   2.36817e-04  -1.27736e-02
#    4  + C          3.90146e-06   8.68923e-06   8.68923e-06  -3.67567e+02
#  FCN=0.00557741 FROM MINOS     STATUS=PROBLEMS     1336 CALLS        7745 TOTAL
#                      EDM=1.36936e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.13471e-07   6.28633e-07   1.11922e-07   2.14397e+02
#    2  Mean         2.30271e-01   6.72828e-03   1.69775e-02  -1.63425e-04
#    3  #gamma       8.63286e-03   2.44571e-02   6.45703e-04  -3.25642e-02
#    4  + C          3.34783e-06   8.32322e-06   8.32322e-06  -7.76611e+01
#  FCN=0.00337468 FROM MINOS     STATUS=PROBLEMS     1306 CALLS        7028 TOTAL
#                      EDM=2.38832e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.37893e-07   6.36989e-07   1.37445e-07   8.86721e+01
#    2  Mean         2.29885e-01   6.64107e-03  -1.16407e-02   1.68984e-04
#    3  #gamma       9.17282e-03   2.46878e-02   9.68315e-04  -1.13600e-02
#    4  + C          2.57610e-06   7.71007e-06   7.71007e-06  -1.51144e+02
#  FCN=0.00431463 FROM MINOS     STATUS=PROBLEMS     1170 CALLS        7776 TOTAL
#                      EDM=2.79048e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.67510e-07   6.35705e-07  -1.62871e-07   8.43680e+02
#    2  Mean         2.29528e-01   6.58612e-03  -3.91003e-02  -2.72008e-05
#    3  #gamma       9.59736e-03   2.39674e-02  -1.21550e-03  -1.11855e-01
#    4  + C          1.74032e-06   6.89386e-06   6.89386e-06  -3.61739e+01
#  FCN=0.00669665 FROM MINOS     STATUS=PROBLEMS     1229 CALLS        7630 TOTAL
#                      EDM=5.26203e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.00433e-07   6.25069e-07   1.94989e-07  -1.35563e+02
#    2  Mean         2.29264e-01   6.52231e-03  -6.49698e-03  -7.57096e-05
#    3  #gamma       9.93692e-03   2.27082e-02   1.68927e-03   1.46824e-02
#    4  + C          8.98023e-07   5.88121e-06   5.88121e-06   3.73504e+01
#  FCN=0.00897198 FROM MINOS     STATUS=PROBLEMS     1082 CALLS        6056 TOTAL
#                      EDM=5.4363e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.36405e-07   6.09990e-07   1.10765e-08  -4.12662e+02
#    2  Mean         2.29120e-01   6.45733e-03   1.65075e-02  -4.66842e-05
#    3  #gamma       1.03401e-02   2.16510e-02   1.28350e-04   4.12217e-02
#    4  + C          1.43554e-07   4.67107e-06   4.67107e-06   2.48653e+02
#  FCN=0.00989769 FROM MINOS     STATUS=PROBLEMS     1115 CALLS        6554 TOTAL
#                      EDM=9.00326e-11    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.67838e-07   5.94413e-07   7.62870e-09   1.88039e+02
#    2  Mean         2.29083e-01   6.43128e-03  -2.04431e-03  -2.15829e-04
#    3  #gamma       1.07889e-02   2.11919e-02   1.49717e-04  -1.26013e-02
#    4  + C         -2.89102e-07   3.48478e-06   3.48478e-06  -4.38674e+02
#  FCN=0.00899471 FROM MINOS     STATUS=PROBLEMS     1200 CALLS        6325 TOTAL
#                      EDM=1.93547e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.55454e-07   6.24708e-07  -3.69354e-08   1.34423e+02
#    2  Mean         2.29145e-01   6.31376e-03   4.98067e-03  -3.62986e-05
#    3  #gamma       1.03295e-02   2.12722e-02  -3.76354e-04  -1.36147e-02
#    4  + C          2.28442e-07   4.86784e-06   4.86784e-06   1.53724e+01
#  FCN=0.00716003 FROM MINOS     STATUS=PROBLEMS     1110 CALLS        5921 TOTAL
#                      EDM=9.83014e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.38900e-07   6.49278e-07   7.03346e-08  -2.14185e+02
#    2  Mean         2.29283e-01   6.22838e-03   9.56660e-03   1.24990e-04
#    3  #gamma       9.92715e-03   2.15818e-02   5.11163e-04   2.84364e-02
#    4  + C          9.62191e-07   6.07344e-06   6.07344e-06   5.08871e+02
#  FCN=0.0052698 FROM MINOS     STATUS=PROBLEMS     1172 CALLS        7792 TOTAL
#                      EDM=3.03983e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.22740e-07   6.67252e-07  -1.28670e-07   1.88457e+02
#    2  Mean         2.29492e-01   6.16520e-03  -5.79339e-04  -6.72307e-04
#    3  #gamma       9.62149e-03   2.20236e-02  -7.82674e-04  -3.12938e-02
#    4  + C          1.73323e-06   7.03559e-06   7.03559e-06  -2.49245e+02
#  FCN=0.00403819 FROM MINOS     STATUS=PROBLEMS     1230 CALLS        7277 TOTAL
#                      EDM=9.37909e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.03684e-07   6.76810e-07  -1.49279e-07   2.26482e+02
#    2  Mean         2.29752e-01   6.14007e-03  -2.91359e-04   1.63505e-04
#    3  #gamma       9.30940e-03   2.24102e-02  -9.28097e-04  -3.60231e-02
#    4  + C          2.50357e-06   7.82638e-06   7.82638e-06  -5.12466e+01
#  FCN=0.0043797 FROM MINOS     STATUS=PROBLEMS     1330 CALLS        6888 TOTAL
#                      EDM=2.98793e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.81306e-07   6.75536e-07   2.34061e-08   9.19125e+01
#    2  Mean         2.30033e-01   6.18178e-03   1.69956e-02  -4.41524e-06
#    3  #gamma       8.96388e-03   2.26151e-02   1.68483e-04  -1.57492e-02
#    4  + C          3.19089e-06   8.41368e-06   8.41368e-06   4.34264e+00
#  FCN=0.00697075 FROM MINOS     STATUS=PROBLEMS     1258 CALLS        7565 TOTAL
#                      EDM=2.66631e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.56512e-07   6.64297e-07  -7.20727e-08  -6.03791e+01
#    2  Mean         2.30304e-01   6.30807e-03   1.33296e-03  -2.85311e-04
#    3  #gamma       8.58713e-03   2.26187e-02  -3.47083e-04   1.14139e-02
#    4  + C          3.74541e-06   8.79668e-06   8.79668e-06  -3.83937e+01
#  FCN=0.0118571 FROM MINOS     STATUS=PROBLEMS     1253 CALLS        8040 TOTAL
#                      EDM=3.85453e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.31515e-07   6.46395e-07   1.90476e-07   9.97995e+01
#    2  Mean         2.30537e-01   6.51288e-03   3.27849e-02  -1.06152e-04
#    3  #gamma       8.22432e-03   2.25254e-02   1.05387e-03  -1.42564e-02
#    4  + C          4.11407e-06   8.98214e-06   8.98214e-06   4.22001e+02
#  FCN=0.0163286 FROM MINOS     STATUS=PROBLEMS     1625 CALLS        9027 TOTAL
#                      EDM=1.95705e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.11590e-07   6.29246e-07  -2.39292e-07   2.26627e+02
#    2  Mean         2.30675e-01   6.72536e-03  -1.78956e-02  -1.42768e-04
#    3  #gamma       7.99192e-03   2.25828e-02  -1.29431e-03  -3.98289e-02
#    4  + C          4.23315e-06   8.98581e-06   8.98581e-06   1.72894e+02
#  FCN=0.0158157 FROM MINOS     STATUS=PROBLEMS     1666 CALLS        8712 TOTAL
#                      EDM=9.09462e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.01536e-07   6.21708e-07   2.29734e-07   5.68267e+02
#    2  Mean         2.30681e-01   6.85593e-03   7.23211e-02  -1.02958e-04
#    3  #gamma       8.01874e-03   2.31616e-02   1.26575e-03  -9.74049e-02
#    4  + C          4.12392e-06   8.87993e-06   8.87993e-06   1.46487e+02
#  FCN=0.0102635 FROM MINOS     STATUS=PROBLEMS     1634 CALLS        8329 TOTAL
#                      EDM=4.49015e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.03845e-07   6.25303e-07   1.78696e-07   1.02232e+03
#    2  Mean         2.30512e-01   6.83320e-03  -5.50530e-02   5.21562e-05
#    3  #gamma       8.31556e-03   2.40786e-02   1.00138e-03  -1.76504e-01
#    4  + C          3.77644e-06   8.65014e-06   8.65014e-06   1.16236e+02
#  FCN=0.0053237 FROM MINOS     STATUS=PROBLEMS     1352 CALLS        7951 TOTAL
#                      EDM=1.53222e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.18455e-07   6.35328e-07   7.91036e-09   1.75527e+02
#    2  Mean         2.30206e-01   6.73853e-03  -5.77524e-03  -2.26061e-04
#    3  #gamma       8.79852e-03   2.48965e-02   1.06266e-04  -2.55028e-02
#    4  + C          3.20971e-06   8.25836e-06   8.25836e-06   8.32420e+01
#  FCN=0.00372942 FROM MINOS     STATUS=PROBLEMS     1411 CALLS        7152 TOTAL
#                      EDM=2.03429e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.41775e-07   6.41861e-07   1.22483e-07   4.88631e+02
#    2  Mean         2.29835e-01   6.66060e-03   5.84123e-03  -3.11530e-04
#    3  #gamma       9.28387e-03   2.49622e-02   8.05275e-04  -7.21133e-02
#    4  + C          2.48720e-06   7.65983e-06   7.65983e-06  -1.18601e+02
#  FCN=0.00471549 FROM MINOS     STATUS=PROBLEMS     1188 CALLS        7180 TOTAL
#                      EDM=1.97697e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.69571e-07   6.39763e-07  -4.20318e-08   1.00540e+01
#    2  Mean         2.29505e-01   6.60780e-03  -4.33732e-03  -1.95998e-04
#    3  #gamma       9.66404e-03   2.41950e-02  -3.62661e-04   9.50346e-04
#    4  + C          1.71264e-06   6.88926e-06   6.88926e-06   3.42126e+02
#  FCN=0.00690477 FROM MINOS     STATUS=PROBLEMS     1225 CALLS        7036 TOTAL
#                      EDM=5.50904e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.01469e-07   6.29729e-07   9.72885e-08  -1.71334e+02
#    2  Mean         2.29262e-01   6.54180e-03   7.60757e-03   6.74308e-05
#    3  #gamma       9.99247e-03   2.29707e-02   8.98943e-04   1.71417e-02
#    4  + C          9.09494e-07   5.92395e-06   5.92395e-06   1.49831e+02
#  FCN=0.00913099 FROM MINOS     STATUS=PROBLEMS     1167 CALLS        6445 TOTAL
#                      EDM=7.93505e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.39459e-07   6.14629e-07   3.35862e-08   1.59381e+02
#    2  Mean         2.29125e-01   6.47298e-03  -1.96321e-02  -1.20781e-04
#    3  #gamma       1.04300e-02   2.18948e-02   3.42729e-04  -1.73496e-02
#    4  + C          1.26252e-07   4.67206e-06   4.67206e-06   4.75493e+01
#  FCN=0.0107411 FROM MINOS     STATUS=PROBLEMS     1215 CALLS        6941 TOTAL
#                      EDM=2.89651e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.71284e-07   6.02128e-07   6.72538e-09   8.27581e+02
#    2  Mean         2.29100e-01   6.44136e-03  -1.72766e-02   2.84600e-06
#    3  #gamma       1.08838e-02   2.14862e-02   1.39355e-04  -5.42592e-02
#    4  + C         -3.12308e-07   3.54367e-06   3.54367e-06   6.28120e+02
#  FCN=0.00852825 FROM MINOS     STATUS=PROBLEMS     1170 CALLS        6092 TOTAL
#                      EDM=7.85548e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.55957e-07   6.32184e-07   2.85363e-08   1.29442e+02
#    2  Mean         2.29174e-01   6.31475e-03  -1.27601e-03  -1.05219e-04
#    3  #gamma       1.03576e-02   2.15015e-02   2.43455e-04  -1.58363e-02
#    4  + C          2.72251e-07   5.02303e-06   5.02303e-06  -3.94393e+01
#  FCN=0.0066708 FROM MINOS     STATUS=PROBLEMS     1138 CALLS        6241 TOTAL
#                      EDM=1.05983e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.38969e-07   6.56721e-07   2.33117e-08  -3.68726e+02
#    2  Mean         2.29330e-01   6.22483e-03  -4.14058e-03  -5.04402e-05
#    3  #gamma       9.94957e-03   2.18292e-02   2.60590e-04   3.81469e-02
#    4  + C          1.04750e-06   6.24218e-06   6.24218e-06   1.25928e+02
#  FCN=0.00488429 FROM MINOS     STATUS=PROBLEMS     1209 CALLS        7251 TOTAL
#                      EDM=2.77949e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.21915e-07   6.73747e-07   2.47492e-09   4.29870e+02
#    2  Mean         2.29547e-01   6.16876e-03   7.48522e-03  -1.48594e-04
#    3  #gamma       9.63266e-03   2.22732e-02  -6.55484e-07  -6.35680e-02
#    4  + C          1.83894e-06   7.19676e-06   7.19676e-06   8.58092e+01
#  FCN=0.00394288 FROM MINOS     STATUS=PROBLEMS     1206 CALLS        7146 TOTAL
#                      EDM=1.51348e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            4.01881e-07   6.81915e-07  -2.79849e-08  -2.86372e+01
#    2  Mean         2.29808e-01   6.15839e-03   4.10177e-03  -2.12735e-04
#    3  #gamma       9.30928e-03   2.26612e-02  -2.22499e-04  -5.88954e-04
#    4  + C          2.61912e-06   7.97243e-06   7.97243e-06   7.09470e+01
#  FCN=0.00473201 FROM MINOS     STATUS=PROBLEMS     1241 CALLS        6960 TOTAL
#                      EDM=5.80771e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.78654e-07   6.78904e-07  -1.18144e-09  -2.86168e+02
#    2  Mean         2.30089e-01   6.21615e-03   1.73921e-02  -3.37124e-04
#    3  #gamma       8.94597e-03   2.28238e-02   8.15515e-05   4.60887e-02
#    4  + C          3.30474e-06   8.53739e-06   8.53739e-06  -6.84170e+01
#  FCN=0.00796366 FROM MINOS     STATUS=PROBLEMS     1319 CALLS        7795 TOTAL
#                      EDM=4.20744e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            3.53002e-07   6.66203e-07   4.39385e-08  -5.26894e+01
#    2  Mean         2.30359e-01   6.36484e-03  -1.09672e-02  -3.24831e-05
#    3  #gamma       8.55551e-03   2.28177e-02   3.00269e-04   6.06088e-03
#    4  + C          3.85773e-06   8.90297e-06   8.90297e-06  -3.21570e+01

# %%
h = r.TH1D()
filenowindow.GetObject(keyListNoWindow[0], h)
for i in range(1,len(keyListNoWindow)):
    ding = r.TH1D()
    filenowindow.GetObject(keyListNoWindow[i], ding)
    h.Add(ding)
c = r.TCanvas()
c.SetLogy()
h.Draw("HIST P0 L")
h.GetXaxis().SetRangeUser(0,1)
c.Draw()

# %%
c = r.TCanvas()
c.SetLogy()
h.Draw("HIST P0 L")
h.GetXaxis().SetRangeUser(0,.5)
h.Fit("func","REM")
func.Draw("SAME")
c.Draw()

print(func.GetParameter(1), func.GetParError(1))

sum_mean = func.GetParameter(1)
# Out:
# 0.22986680083306538 0.0009462218811628759
#  FCN=0.187625 FROM MINOS     STATUS=SUCCESSFUL     82 CALLS        2182 TOTAL
#                      EDM=2.82538e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            1.80581e-05   4.53493e-06   1.84987e-07  -5.63832e+02
#    2  Mean         2.29867e-01   9.46222e-04   2.44561e-04  -5.39209e-03
#    3  #gamma       9.32313e-03   3.36962e-03   1.30728e-04  -6.78699e-01
#    4  + C          1.12669e-04   5.26950e-05   5.26950e-05   1.21841e-01

# %%
outfile = r.TFile("output.root","RECREATE")
outfile.cd()
c.Write()
outfile.Close()

# %%
gr2 = r.TGraphErrors()

for i in range(0,len(meanlist_noWindow)):
#    print(i, meanlist_window[i])
    gr2.SetPoint(i,i+1,meanlist_noWindow[i])
#    gr2.SetPointError(i,0,stdlist_noWindow[i])
    
c = r.TCanvas()
gr2.GetXaxis().SetTitle("Time steps added to transform window (Each step ~0.275 #mus)")
gr2.GetYaxis().SetTitle("Frequency of #omega_{a} peak (MHz)")
gr2.GetYaxis().SetTitleOffset(1.5)
gr2.Draw()

gr.SetMarkerColor(2)
gr.SetLineColor(2)
gr.Draw("SAME")

meanfunc = r.TF1("meanfunc",str(sum_mean),0,100)
meanfunc.SetLineStyle(4)
meanfunc.Draw("SAME")

leg = r.TLegend(0.6,0.84,0.9,0.9)
leg.AddEntry(gr,"With Window Function","pl")
leg.AddEntry(gr2,"Without Window Function","pl")
leg.AddEntry(meanfunc,"Frequency found by fitting sum of all transforms","l")
leg.Draw()


c.Draw()

# %%
print(meanlist_noWindow)
import matplotlib.pyplot as plt
plt.plot(meanlist_noWindow)
plt.plot(meanlist_window)
plt.ylabel('some numbers')
plt.show()
# Out:
# [0.23048437524477794, 0.23064131832187737, 0.23068205033436856, 0.23055337791504, 0.23026320350191692, 0.22990577275852728, 0.22956232154068293, 0.22929759326330743, 0.22913503464288262, 0.22908344009622109, 0.22913913044094583, 0.22927466615758454, 0.22947821957618023, 0.22972056549775705, 0.22999277400796964, 0.2302729794652836, 0.23051275908353783, 0.23066080850278628, 0.23067764868708057, 0.23054881314696304, 0.2302705825006845, 0.22988529661218857, 0.2295282305715366, 0.2292638130432576, 0.22912030788184518, 0.22908294532281884, 0.2291454719323645, 0.22928283003206232, 0.2294922928986148, 0.22975203188087734, 0.23003289955527007, 0.23030409030918103, 0.23053665638866247, 0.23067511717178255, 0.23068053542228656, 0.2305122146446972, 0.2302064226732389, 0.22983459187337946, 0.22950458882641764, 0.2292618464424269, 0.2291246869908082, 0.22910045243168561, 0.2291743663721639, 0.22932975863751362, 0.2295466894950747, 0.2298083646129933, 0.23008895313786967, 0.23035919986452397]

# %%
func2 = r.TF1("func2", peak_fit_bw, 0,.15,4)
func2.SetParNames('A','Mean','#gamma','+ C')
func2.SetParameters(.0001,.001,.1,0)
func2.SetParLimits(1,-0.1,0.1)
func2.SetLineColor(2)
func2.SetNpx(1000)

func3 = r.TF1("func3","expo",.4,.5)

c = r.TCanvas()
c.SetLogy()
h3 = h.DrawClone()
h3.Draw("HIST P0 L")
h3.Fit("func2","REMB")

h3.Fit("func3","REMB")

func2.Draw("SAME")
func.Draw("SAME")
func3.Draw("SAME")
c.Draw()
# Out:
#  FCN=2.4077 FROM MIGRAD    STATUS=CALL LIMIT   1489 CALLS        1490 TOTAL
#                      EDM=0.000161386    STRATEGY= 1  ERROR MATRIX UNCERTAINTY  14.8 per cent
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            6.72436e-03   1.54504e-02   1.43902e-04  -2.72677e+01
#    2  Mean        -9.11716e-03   1.28903e-03   5.55817e-05  -1.91068e+00
#    3  #gamma       9.29920e-04   2.20523e-03  -2.11344e-05  -1.90207e+02
#    4  + C          1.69517e-04   3.36039e-05   1.86604e-07   5.50850e+01
#  FCN=0.00171074 FROM MINOS     STATUS=SUCCESSFUL     41 CALLS        1451 TOTAL
#                      EDM=3.34883e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant    -8.73670e+00   3.65043e+00   8.43425e-02   7.74227e-03
#    2  Slope       -2.29083e+00   8.12980e+00   8.12980e+00   4.94180e-03
# Warning in <Fit>: Abnormal termination of minimization.

# %%
h4 = h.DrawClone()
c4 = r.TCanvas()
c4.SetLogy()

for i in range(0,h4.GetNbinsX()-2):
    bincenter = h4.GetBinCenter(i)
    bincontent = h4.GetBinContent(i)
    dong = bincontent - func3.Eval(bincenter)
    h4.SetBinContent(i,dong)

h4.Draw("HIST P0 L")
h4.Fit("func","REMB")
func.Draw("SAME")
c4.Draw()
# Out:
#  FCN=0.168157 FROM MINOS     STATUS=SUCCESSFUL     82 CALLS         640 TOTAL
#                      EDM=1.63377e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A            1.77704e-05   4.48572e-06   1.78735e-07  -5.39309e+02
#    2  Mean         2.29873e-01   9.45539e-04   2.48311e-04  -5.33708e-03
#    3  #gamma       9.19271e-03   3.33691e-03   1.26398e-04  -6.59935e-01
#    4  + C          2.49885e-05   5.23591e-05   5.23591e-05   1.26563e-01

# %%
'''
Double_t fline(Double_t *x, Double_t *par)
{
    if (reject && x[0] > 2.5 && x[0] < 3.5) {
      TF1::RejectPoint();
      return 0;
   }
   return par[0] + par[1]*x[0];
}
'''
h4 = h.DrawClone()

reject = True

def fbackground(x, p):
    if(reject and not((x[0]>0 and x[0]<0.155) or (x[0]>0.30 and x[0]<0.35) or (x[0]>0.4 and x[0]<0.5) or (x[0]>0.6 and x[0]<3))):
        r.TF1.RejectPoint()
        return 0
#    return p[0]*r.TMath.Exp(p[1]*x[0] + r.TMath.Exp(p[2]*x[0])) + p[3]
    return p[0]*r.TMath.Sqrt(p[1]*p[1] + x[0]*x[0]) / (2 * r.TMath.Pi() * r.TMath.Abs(p[1]*p[1] + x[0]*x[0])) + p[2]

def fsignal1(x, p):
    if(reject and not((x[0]>0 and x[0]<0.155) or (x[0]>0.30 and x[0]<0.35) or (x[0]>0.4 and x[0]<0.5) or (x[0]>0.6 and x[0]<3))):
        r.TF1.RejectPoint()
        return 0
#    return p[0]*r.TMath.Exp(p[1]*x[0] + r.TMath.Exp(p[2]*x[0])) + p[3]
    return p[0]*r.TMath.Sqrt(p[1]*p[1] + x[0]*x[0]) / (2 * r.TMath.Pi() * r.TMath.Abs(p[1]*p[1] + x[0]*x[0])) + p[2]

fl = r.TF1("fl",fbackground,0,3,3)
fl.SetParameters(0.03,0,0)
fl.SetParNames("A_{background}","k_{background}","+C_{background}")
h4.Fit(fl,"REMB")

reject = False

#fl.SetParameter(2,-10.5)

c4 = r.TCanvas()
c4.SetLogy()

h4.GetXaxis().SetRangeUser(0,0.5)
#h4.GetYaxis().SetRangeUser(0.0000001,100)


h4.Draw("HIST P0 L")
fl.Draw("SAME")
c4.Draw()
# Out:
#  FCN=0.783925 FROM MINOS     STATUS=SUCCESSFUL     22 CALLS         522 TOTAL
#                      EDM=4.26117e-15    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A_{background}   1.67991e-04   1.10618e-05   6.81577e-08   1.57566e+02
#    2  k_{background}   2.38068e-03   3.68831e-04   3.28157e-06  -3.30934e+00
#    3  +C_{background}  -3.39848e-06   1.26360e-05   1.26360e-05  -7.57831e-03

# %%
h5 = h.DrawClone()
c5 = r.TCanvas()
#c5.SetLogy()

for i in range(0,h5.GetNbinsX()-2):
    bincenter = h5.GetBinCenter(i)
    bincontent = h5.GetBinContent(i)
    dong = bincontent - fl.Eval(bincenter) 
    h5.SetBinContent(i,dong)

h5.GetXaxis().SetRangeUser(0,3)
    
reject = True

def fsignal1(x, p):
    if(reject and (x[0]>0.155 and x[0]<0.30)):
        r.TF1.RejectPoint()
        return 0
    return p[0] * r.TMath.Sqrt(p[1]*p[1] + x[0]*x[0]) / (2 * r.TMath.Pi() * r.TMath.Abs(p[1]*p[1] + x[0]*x[0])) + p[2]

fsig = r.TF1("fsig",fsignal1,0.15,0.3,3)
fsig.SetParameters(.03,0.2,-0.002)
fsig.SetParLimits(0,0,1000)
fsig.SetParLimits(1,0.1,0.3)
fsig.SetParNames("A_{signal}","k_{signal}","+C_{signal}")
h5.Fit(fsig,"REMB")

reject = False
    
fsig.SetParameters(.03,0.2,-0.002)
    
h5.GetXaxis().SetRangeUser(0,3)
h5.GetYaxis().SetRangeUser(-.01,.1)
fsig.SetRange(0,3)
    
h5.Draw("HIST P0 L")
fsig.Draw("SAME")
c5.Draw()
# Out:
#  FCN=0.000483494 FROM MIGRAD    STATUS=CALL LIMIT   1350 CALLS        1351 TOTAL
#                      EDM=3.25003e-05    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A_{signal}   1.71006e-03   9.15715e-03  -5.95833e-06   7.40646e+00
#    2  k_{signal}   2.99887e-01   1.90865e-01  -8.70165e-03   1.45578e-04
#    3  +C_{signal}  -8.09862e-04   3.93626e-03   3.87886e-06   1.09790e+01
# Warning in <Fit>: Abnormal termination of minimization.

# %%
h2 = h.DrawClone()
c2 = r.TCanvas()
h2.Draw("HIST P0 L")
for i in range(0,h2.GetNbinsX()-2):
    ding = h2.GetBinContent(i)
    if ding>0:
        dong = np.log(ding)
    else:
        dong = 0
#    print(ding,dong)
    h2.SetBinContent(i,dong)
h2.DrawCopy()
c2.Draw()

offset = h2.GetBinContent(h2.GetMinimumBin())

c3 = r.TCanvas()
c3.cd()

for i in range(0,h2.GetNbinsX()-2):
    ding = h2.GetBinContent(i) - offset
    if ding>0:
        dong = np.log(ding)
    else:
        dong = 0
#    print(ding,dong)
    h2.SetBinContent(i,dong)

h2.Draw()
c3.Draw()
