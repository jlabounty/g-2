# %%
import ROOT as r
import math
from BlindersPy3 import Blinders
from BlindersPy3 import FitType
r.gStyle.SetOptStat(0)
r.gStyle.SetOptFit(1111)
import matplotlib.pyplot as plt
import csv
import pandas

import seaborn as sns
sns.set(style="ticks", color_codes=True)
import numpy as np
import matplotlib.pyplot as plt
import matplotlib 
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 

# %matplotlib inline
# Out:
# Welcome to JupyROOT 6.12/06

# %%
# blinded instance
getBlinded = Blinders(FitType.Omega_a, 'This is my fight song. Blinding my plot song.')
def blinded_wiggle(x, p):
    norm  = p[0]
    life  = p[1]
    asym  = p[2]
    R     = p[3]
    phi   = p[4]
    
    time  = x[0]
    omega = getBlinded.paramToFreq(R) #blind version
    
    return norm * math.exp(-time/life) * (1 - asym*math.cos(omega*time + phi))
# Out:
#  + ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ +
#  +                                                                      +
#  +           You have chose to blind your fitting according to          +
#  +                omega_ref * (1 + (R +/- deltaR) *10^{-6})             +
#  +                                                                      +
#  + ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ +

# %%
params = [2.097 * 10**5,64.45,0.3857,0,-1.059,0.02,200,2.599,0.00]#-0.07523]
#N, tau, A, R, phi, A1CBO, tauCBO, omegaCBO, phiCBO

np.random.seed(123456789)
wiggleMcVec = []
nPos = 1.4 * 10**4
nPosCalo = int(np.ceil(nPos/24))
for calo in range(1,25):
    for i in range(nPosCalo):
        time = np.random.uniform(0,700)
        ding = blinded_wiggle([time],params[:5])
        wiggleMcVec.append((time,ding,calo))

# %%
timeVec, wiggleVec, caloVec = zip(*wiggleMcVec)
data = pandas.DataFrame({'time':timeVec, 'wiggle':wiggleVec, 'calo':caloVec})

# %%
data.describe()
# Out:
#                time         wiggle          calo
# count  14016.000000   14016.000000  14016.000000
# mean     350.407626   19251.930465     12.500000
# std      202.609618   42360.690551      6.922434
# min        0.009385       2.505819      1.000000
# 25%      173.395287      58.564824      6.750000
# 50%      350.820172     865.930309     12.500000
# 75%      523.661108   13770.010268     18.250000
# max      699.922430  277770.240274     24.000000

# %%
fig, ax = plt.subplots(figsize=(15, 5))
plt.scatter(x=data['time'].loc[data['calo']==1],y=data['wiggle'].loc[data['calo']==1],s=2)
plt.xlabel('Time ($\mu s$)')
plt.ylabel('Some Units')
plt.title('5-Parameter Monte Carlo')
plt.show()

fig, ax = plt.subplots(figsize=(15, 5))
plt.scatter(x=data['time'].loc[data['calo']==1],y=data['wiggle'].loc[data['calo']==1],s=2)
plt.xlim(30,70)
plt.show()

# %%
def blinded_wiggle_cbo(x, p):
    norm     = p[0]
    life     = p[1]
    asym     = p[2]
    R        = p[3]
    phi      = p[4]
    A1       = p[5]
    lifeCBO  = p[6]
    omegaCBO = p[7]
    phiCBO1  = p[8]
    
    time  = x[0]
    omega = getBlinded.paramToFreq(R)
    
    cCBO = 1 - math.exp(-time/lifeCBO)*A1*math.cos(omegaCBO*time + phiCBO1)
    
    return norm * math.exp(-time/life) * (1 - asym*math.cos(omega*time + phi)) * cCBO

# %%
np.random.seed(123456789)
wiggleMcVecCBO = []
params8init = 0
for calo in range(1,25):
    params[8] = params8init+(np.deg2rad(15))*(calo-1)
    for i in range(nPosCalo):
        time = np.random.uniform(0,700)
        ding = blinded_wiggle_cbo([time],params)
        wiggleMcVecCBO.append((time,ding,calo))

# %%
timeVecCBO, wiggleVecCBO, caloVecCBO = zip(*wiggleMcVecCBO)
dataCBO = pandas.DataFrame({'time':timeVecCBO, 'wiggle':wiggleVecCBO, 'calo':caloVecCBO})
dataCBO.head()
# Out:
#          time       wiggle  calo
# 0  372.983117   690.694992     1
# 1  373.895621   879.509762     1
# 2  356.687125  1137.259195     1
# 3  499.494822    93.453128     1
# 4  179.899268  8161.570535     1

# %%
fig, ax = plt.subplots(figsize=(15, 5))
plt.scatter(x=dataCBO['time'].loc[dataCBO['calo']==1],y=dataCBO['wiggle'].loc[dataCBO['calo']==1],s=2)
plt.xlabel('Time ($\mu s$)')
plt.ylabel('Some Units')
plt.title('9-Parameter Monte Carlo')
plt.show()

fig, ax = plt.subplots(figsize=(15, 5))
plt.scatter(x=dataCBO['time'].loc[dataCBO['calo']==1],y=dataCBO['wiggle'].loc[dataCBO['calo']==1],s=2)
plt.xlim(30,70)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 5))
plt.scatter(x=data['time'].loc[data['calo']==1],y=data['wiggle'].loc[data['calo']==1],s=2,label='5 parameter')
plt.scatter(x=dataCBO['time'].loc[dataCBO['calo']==1],y=dataCBO['wiggle'].loc[dataCBO['calo']==1],s=2,label='9 parameter')
plt.yscale('log')
plt.legend()
plt.show()

fig, ax = plt.subplots(figsize=(15, 5))
plt.scatter(x=data['time'].loc[data['calo']==1],y=data['wiggle'].loc[data['calo']==1],s=2,label='5 parameter')
plt.scatter(x=dataCBO['time'].loc[dataCBO['calo']==1],y=dataCBO['wiggle'].loc[dataCBO['calo']==1],s=2,label='9 parameter')
plt.xlim(30,35)
plt.ylim(100000,200000)
plt.yscale('log')
plt.legend()
plt.show()

# %%
'''fig, ax = plt.subplots(figsize=(15, 5))
for calo in range(1,25):
for calo in range(1,5):
    plt.scatter(x=dataCBO['time'].loc[dataCBO['calo']==calo],y=dataCBO['wiggle'].loc[dataCBO['calo']==calo]
                ,s=2,label='9 parameter (calo'+str(calo)+')')
plt.xlim(30,35)
plt.ylim(100000,200000)
plt.yscale('log')
plt.legend()
plt.show()'''
# Out:
# "fig, ax = plt.subplots(figsize=(15, 5))\nfor calo in range(1,25):\nfor calo in range(1,5):\n    plt.scatter(x=dataCBO['time'].loc[dataCBO['calo']==calo],y=dataCBO['wiggle'].loc[dataCBO['calo']==calo]\n                ,s=2,label='9 parameter (calo'+str(calo)+')')\nplt.xlim(30,35)\nplt.ylim(100000,200000)\nplt.yscale('log')\nplt.legend()\nplt.show()"

# %%
func = r.TF1("func", blinded_wiggle_cbo, 30,350,9)
func.SetParNames('N','#tau','A','R','#phi','A_{CBO}','#tau_{CBO}','#omega_{CBO}','#phi_{CBO}')
func.SetParameters(2.097 * 10**5,64.45,0.3857,0,-1.059,0.02,200,2.599,0)#-0.07523)
func.SetParLimits(5,0,1)
func.SetParLimits(6,190,210)
func.SetParLimits(8,-0.001,2*math.pi)
func.SetLineColor(2)
func.SetNpx(1000)

# %%
paramVec = []
paramErrVec = []
for calo in range(1,25):
    print("Starting Calo",calo)
    tempdf  = dataCBO.loc[dataCBO['calo'] == calo]
    timeVecCBO = tempdf['time'].values
    wiggleVecCBO = tempdf['wiggle'].values
    c = r.TCanvas()
    print("    Drawing")
    gr = r.TGraph(len(timeVecCBO), timeVecCBO, wiggleVecCBO)
    gr.SetTitle("Calo"+str(calo))
    gr.Draw("ap")
    gr.GetXaxis().SetRangeUser(30,300)
        
    print("    Fitting")
    gr.Fit('func','R')
    func.Draw("same")
    
    ding = func.GetParameters()
    ding2 = func.GetParErrors()
    paramsFit = []
    paramsErrFit = []
    for i in range(len(params)):
        paramsFit.append(ding[i])
        paramsErrFit.append(ding2[i])
    print(paramsFit,paramsErrFit)
    paramVec.append(paramsFit)
    paramErrVec.append(paramsErrFit)
    
    c.SetLogy()
#    c.Print("./images/CBO/CBO_Sim_Calo"+str(calo).zfill(2)+".png")
    c.Draw()
# Out:
# Starting Calo 1
#     Drawing
#     Fitting
# [209700.0, 64.45, 0.3857, 0.0, -1.059, 0.020000000000000018, 200.0, 2.599, 4.336808689942018e-17] [1.1137232767582747e-12, 2.4133747356815756e-16, 3.3133420043635604e-18, 1.829054667773747e-13, 2.6480240509937492e-17, 9.085914102277739e-18, 2.612369087963003e-13, 7.550096611875815e-18, 5.398952395951053e-16]
# Starting Calo 2
#     Drawing
#     Fitting
# [209700.00000041907, 64.45000000192316, 0.3856999999638746, 1.7784647058906528e-07, -1.0589999999909003, 0.02000000009111369, 199.99999641304527, 2.5990000000745757, 0.2617993825274384] [1.8984231442862957e-06, 4.831875246885591e-10, 5.357362965602438e-12, 2.833116665859849e-07, 3.1303764892137205e-11, 2.0912845081736734e-11, 6.128436709197551e-07, 1.3713718179678162e-11, 8.745197665967095e-10]
# Starting Calo 3
#     Drawing
#     Fitting
# [209700.00012606732, 64.45000002374987, 0.3856999995073912, -1.3921863842716398e-05, -1.0589999984759955, 0.02000000108755523, 199.9999440953113, 2.5990000014096664, 0.5235987153785633] [3.116107542283414e-05, 8.903191293895478e-09, 1.088211809653085e-10, 5.865587123521175e-06, 5.851032398524074e-10, 3.2182904725934934e-10, 1.1014980938646607e-05, 2.767496363351901e-10, 1.624733746318394e-08]
# Starting Calo 4
#     Drawing
#     Fitting
# [209700.00000004517, 64.45000000001136, 0.3857000000003651, -9.519828404966628e-08, -1.0589999999920474, 0.02000000000713975, 199.9999997007396, 2.598999999956176, 0.7853981658484366] [3.287159667682233e-07, 9.325217653177534e-11, 1.0157576442743256e-12, 5.388507183983026e-08, 5.340887384100795e-12, 3.2451206746149238e-12, 1.1370166721347956e-07, 2.7521106357456412e-12, 1.641244753244923e-10]
# Starting Calo 5
#     Drawing
#     Fitting
# [209700.00000088266, 64.44999999989139, 0.38570000000080756, 1.4452080818964236e-07, -1.059000000018296, 0.020000000013867314, 199.9999988186367, 2.5989999999980906, 1.0471975512541178] [4.0947708097737833e-07, 1.0736892085921853e-10, 1.33080107420656e-12, 6.927849771240005e-08, 7.510836528361713e-12, 5.27896011713177e-12, 1.5888183174359702e-07, 2.92123864619874e-12, 1.6721284588117528e-10]
	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =   1.2904e-09
# NDf                       =          255
# Edm                       =  1.36879e-09
# NCalls                    =          502
# N                         =       209700   +/-   1.89842e-06
# #tau                      =        64.45   +/-   4.83188e-10
# A                         =       0.3857   +/-   5.35736e-12
# R                         =  1.77846e-07   +/-   2.83312e-07
# #phi                      =       -1.059   +/-   3.13038e-11
# A_{CBO}                   =         0.02   +/-   2.09128e-11  	 (limited)
# #tau_{CBO}                =          200   +/-   6.12844e-07  	 (limited)
# #omega_{CBO}              =        2.599   +/-   1.37137e-11
# #phi_{CBO}                =     0.261799   +/-   8.7452e-10   	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =   6.5613e-07
# NDf                       =          261
# Edm                       =   1.3129e-06
# NCalls                    =          447
# N                         =       209700   +/-   3.11611e-05
# #tau                      =        64.45   +/-   8.90319e-09
# A                         =       0.3857   +/-   1.08821e-10
# R                         = -1.39219e-05   +/-   5.86559e-06
# #phi                      =       -1.059   +/-   5.85103e-10
# A_{CBO}                   =         0.02   +/-   3.21829e-10  	 (limited)
# #tau_{CBO}                =          200   +/-   1.1015e-05   	 (limited)
# #omega_{CBO}              =        2.599   +/-   2.7675e-10
# #phi_{CBO}                =     0.523599   +/-   1.62473e-08  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =  5.83106e-11
# NDf                       =          264
# Edm                       =  2.86083e-12
# NCalls                    =          324
# N                         =       209700   +/-   3.28716e-07
# #tau                      =        64.45   +/-   9.32522e-11
# A                         =       0.3857   +/-   1.01576e-12
# R                         = -9.51983e-08   +/-   5.38851e-08
# #phi                      =       -1.059   +/-   5.34089e-12
# A_{CBO}                   =         0.02   +/-   3.24512e-12  	 (limited)
# #tau_{CBO}                =          200   +/-   1.13702e-07  	 (limited)
# #omega_{CBO}              =        2.599   +/-   2.75211e-12
# #phi_{CBO}                =     0.785398   +/-   1.64124e-10  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =  6.96041e-11
# NDf                       =          252
# Edm                       =  7.36893e-11
# NCalls                    =          372
# N                         =       209700   +/-   4.09477e-07
# #tau                      =        64.45   +/-   1.07369e-10
# A                         =       0.3857   +/-   1.3308e-12
# R                         =  1.44521e-07   +/-   6.92785e-08
# #phi                      =       -1.059   +/-   7.51084e-12
# A_{CBO}                   =         0.02   +/-   5.27896e-12  	 (limited)
# #tau_{CBO}                =          200   +/-   1.58882e-07  	 (limited)
# #omega_{CBO}              =        2.599   +/-   2.92124e-12
# #phi_{CBO}                =       1.0472   +/-   1.67213e-10  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =  3.94426e-09
# NDf                       =          255
# Edm                       =  4.07802e-09
# NCalls                    =          556
# N                         =       209700   +/-   2.65018e-06
# #tau                      =        64.45   +/-   7.27747e-10
# A                         =       0.3857   +/-   9.57677e-12
# R                         = -7.42824e-07   +/-   4.75453e-07
# #phi                      =       -1.059   +/-   5.02849e-11
# A_{CBO}                   =         0.02   +/-   3.01033e-11  	 (limited)
# #tau_{CBO}                =          200   +/-   9.68501e-07  	 (limited)
# #omega_{CBO}              =        2.599   +/-   2.09629e-11
# #phi_{CBO}                =        1.309   +/-   1.15757e-09  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =  1.93675e-07
# NDf                       =          258
# Edm                       =  2.20734e-07
# NCalls                    =          372
# N                         =       209700   +/-   1.87156e-05
# #tau                      =        64.45   +/-   4.98803e-09
# A                         =       0.3857   +/-   5.77322e-11
# R                         =  9.61435e-06   +/-   3.35285e-06
# #phi                      =       -1.059   +/-   3.70558e-10
# A_{CBO}                   =         0.02   +/-   1.79918e-10  	 (limited)
# #tau_{CBO}                =          200   +/-   5.71028e-06  	 (limited)
# #omega_{CBO}              =        2.599   +/-   1.52021e-10
# #phi_{CBO}                =       1.5708   +/-   9.01603e-09  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =   1.7668e-08
# NDf                       =          262
# Edm                       =  1.92475e-08
# NCalls                    =          373
# N                         =       209700   +/-   5.50319e-06
# #tau                      =        64.45   +/-   1.49933e-09
# A                         =       0.3857   +/-   1.71788e-11
# R                         = -4.06553e-06   +/-   1.04233e-06
# #phi                      =       -1.059   +/-   1.12883e-10
# A_{CBO}                   =         0.02   +/-   4.8937e-11   	 (limited)
# #tau_{CBO}                =          200   +/-   1.67325e-06  	 (limited)
# #omega_{CBO}              =        2.599   +/-   5.26712e-11
# #phi_{CBO}                =       1.8326   +/-   3.59835e-09  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =  6.65554e-09
# NDf                       =          256
# Edm                       =  7.98956e-09
# NCalls                    =          423
# N                         =       209700   +/-   3.29513e-06
# #tau                      =        64.45   +/-   9.08845e-10
# A                         =       0.3857   +/-   1.04864e-11
# R                         = -2.57961e-06   +/-   6.16216e-07
# #phi                      =       -1.059   +/-   6.21567e-11
# A_{CBO}                   =         0.02   +/-   3.15435e-11  	 (limited)
# #tau_{CBO}                =          200   +/-   1.10365e-06  	 (limited)
# #omega_{CBO}              =        2.599   +/-   2.61386e-11
# #phi_{CBO}                =       2.0944   +/-   1.57302e-09  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =  7.68368e-09
# NDf                       =          255
# Edm                       =  7.99418e-09
# NCalls                    =          415
# N                         =       209700   +/-   4.46693e-06
# #tau                      =        64.45   +/-   1.15081e-09
# A                         =       0.3857   +/-   1.36548e-11
# R                         = -3.50962e-06   +/-   6.54234e-07
# #phi                      =       -1.059   +/-   5.98516e-11
# A_{CBO}                   =         0.02   +/-   5.09238e-11  	 (limited)
# #tau_{CBO}                =          200   +/-   1.5214e-06   	 (limited)
# #omega_{CBO}              =        2.599   +/-   3.00942e-11
# #phi_{CBO}                =      2.35619   +/-   1.8398e-09   	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =  4.39937e-09
# NDf                       =          247
# Edm                       =  4.77612e-09
# NCalls                    =          349
# N                         =       209700   +/-   3.58346e-06
# #tau                      =        64.45   +/-   9.1312e-10
# A                         =       0.3857   +/-   1.183e-11
# R                         =  1.65377e-07   +/-   5.37677e-07
# #phi                      =       -1.059   +/-   5.84592e-11
# A_{CBO}                   =         0.02   +/-   3.65292e-11  	 (limited)
# #tau_{CBO}                =          200   +/-   1.13372e-06  	 (limited)
# #omega_{CBO}              =        2.599   +/-   2.52672e-11
# #phi_{CBO}                =      2.61799   +/-   1.76356e-09  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =  4.34636e-10
# NDf                       =          250
# Edm                       =  3.53263e-10
# NCalls                    =          329
# N                         =       209700   +/-   1.00134e-06
# #tau                      =        64.45   +/-   2.62885e-10
# A                         =       0.3857   +/-   3.22209e-12
# R                         = -1.06413e-07   +/-   1.64887e-07
# #phi                      =       -1.059   +/-   1.72492e-11
# A_{CBO}                   =         0.02   +/-   9.82572e-12  	 (limited)
# #tau_{CBO}                =          200   +/-   3.16867e-07  	 (limited)
# #omega_{CBO}              =        2.599   +/-   7.91104e-12
# #phi_{CBO}                =      2.87979   +/-   5.15945e-10  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =  2.80043e-08
# NDf                       =          251
# Edm                       =  2.77998e-08
# NCalls                    =          374
# N                         =       209700   +/-   6.81133e-06
# #tau                      =        64.45   +/-   1.98412e-09
# A                         =       0.3857   +/-   2.11523e-11
# R                         = -1.78862e-05   +/-   1.21741e-06
# #phi                      =       -1.059   +/-   1.17801e-10
# A_{CBO}                   =         0.02   +/-   6.90399e-11  	 (limited)
# #tau_{CBO}                =          200   +/-   2.45121e-06  	 (limited)
# #omega_{CBO}              =        2.599   +/-   5.85068e-11
# #phi_{CBO}                =      3.14159   +/-   3.33979e-09  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =  1.02554e-08
# NDf                       =          240
# Edm                       =  9.93941e-09
# NCalls                    =          351
# N                         =       209700   +/-   5.70146e-06
# #tau                      =        64.45   +/-   1.4336e-09
# A                         =       0.3857   +/-   1.87506e-11
# R                         = -6.85183e-07   +/-   8.89619e-07
# #phi                      =       -1.059   +/-   1.04857e-10
# A_{CBO}                   =         0.02   +/-   6.71409e-11  	 (limited)
# #tau_{CBO}                =          200   +/-   1.83168e-06  	 (limited)
# #omega_{CBO}              =        2.599   +/-   4.76425e-11
# #phi_{CBO}                =      3.40339   +/-   3.23426e-09  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =  1.11269e-10
# NDf                       =          253
# Edm                       =   1.1908e-10
# NCalls                    =          347
# N                         =       209700   +/-   4.88149e-07
# #tau                      =        64.45   +/-   1.32209e-10
# A                         =       0.3857   +/-   1.5078e-12
# R                         =  8.75442e-07   +/-   8.18873e-08
# #phi                      =       -1.059   +/-   8.77256e-12
# A_{CBO}                   =         0.02   +/-   5.42053e-12  	 (limited)
# #tau_{CBO}                =          200   +/-   1.70944e-07  	 (limited)
# #omega_{CBO}              =        2.599   +/-   3.99775e-12
# #phi_{CBO}                =      3.66519   +/-   2.51444e-10  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =   4.4761e-11
# NDf                       =          245
# Edm                       =   3.9823e-11
# NCalls                    =          348
# N                         =       209700   +/-   2.88201e-07
# #tau                      =        64.45   +/-   7.83827e-11
# A                         =       0.3857   +/-   1.0105e-12
# R                         =  -3.8086e-09   +/-   4.92692e-08
# #phi                      =       -1.059   +/-   5.07973e-12
# A_{CBO}                   =         0.02   +/-   2.95802e-12  	 (limited)
# #tau_{CBO}                =          200   +/-   9.95322e-08  	 (limited)
# #omega_{CBO}              =        2.599   +/-   2.35655e-12
# #phi_{CBO}                =      3.92699   +/-   1.42587e-10  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =  6.62621e-08
# NDf                       =          266
# Edm                       =  7.26053e-08
# NCalls                    =          356
# N                         =       209700   +/-   9.87215e-06
# #tau                      =        64.45   +/-   2.85377e-09
# A                         =       0.3857   +/-   3.59036e-11
# R                         = -3.67918e-06   +/-   1.73231e-06
# #phi                      =       -1.059   +/-   1.64104e-10
# A_{CBO}                   =         0.02   +/-   9.90728e-11  	 (limited)
# #tau_{CBO}                =          200   +/-   3.47174e-06  	 (limited)
# #omega_{CBO}              =        2.599   +/-   8.5227e-11
# #phi_{CBO}                =      4.18879   +/-   4.84221e-09  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =  2.55275e-07
# NDf                       =          260
# Edm                       =  2.63271e-07
# NCalls                    =          396
# N                         =       209700   +/-   1.90748e-05
# #tau                      =        64.45   +/-   5.38524e-09
# A                         =       0.3857   +/-   6.67226e-11
# R                         =  3.00517e-06   +/-   3.36531e-06
# #phi                      =       -1.059   +/-   3.33313e-10
# A_{CBO}                   =         0.02   +/-   1.9307e-10   	 (limited)
# #tau_{CBO}                =          200   +/-   6.32357e-06  	 (limited)
# #omega_{CBO}              =        2.599   +/-   1.70958e-10
# #phi_{CBO}                =      4.45059   +/-   9.48579e-09  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =   1.2321e-07
# NDf                       =          253
# Edm                       =  2.47177e-07
# NCalls                    =          424
# N                         =       209700   +/-   1.47918e-05
# #tau                      =        64.45   +/-   4.17611e-09
# A                         =       0.3857   +/-   5.01113e-11
# R                         = -9.81561e-07   +/-   2.58895e-06
# #phi                      =       -1.059   +/-   2.44672e-10
# A_{CBO}                   =         0.02   +/-   1.71924e-10  	 (limited)
# #tau_{CBO}                =          200   +/-   5.47333e-06  	 (limited)
# #omega_{CBO}              =        2.599   +/-   1.12256e-10
# #phi_{CBO}                =      4.71239   +/-   6.53754e-09  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =  1.42918e-09
# NDf                       =          270
# Edm                       =  2.85663e-09
# NCalls                    =          476
# N                         =       209700   +/-   1.7735e-06
# #tau                      =        64.45   +/-   4.42973e-10
# A                         =       0.3857   +/-   5.49923e-12
# R                         = -1.62467e-06   +/-   2.84061e-07
# #phi                      =       -1.059   +/-   3.24207e-11
# A_{CBO}                   =         0.02   +/-   2.28577e-11  	 (limited)
# #tau_{CBO}                =          200   +/-   6.02662e-07  	 (limited)
# #omega_{CBO}              =        2.599   +/-   1.28668e-11
# #phi_{CBO}                =      4.97419   +/-   8.44964e-10  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =  1.72158e-08
# NDf                       =          264
# Edm                       =   1.8041e-08
# NCalls                    =          397
# N                         =       209700   +/-   5.76165e-06
# #tau                      =        64.45   +/-   1.54027e-09
# A                         =       0.3857   +/-   1.93985e-11
# R                         = -4.71201e-07   +/-   9.26153e-07
# #phi                      =       -1.059   +/-   9.89426e-11
# A_{CBO}                   =         0.02   +/-   5.6776e-11   	 (limited)
# #tau_{CBO}                =          200   +/-   1.72661e-06  	 (limited)
# #omega_{CBO}              =        2.599   +/-   4.67975e-11
# #phi_{CBO}                =      5.23599   +/-   2.80273e-09  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =  2.61558e-08
# NDf                       =          270
# Edm                       =  2.64648e-08
# NCalls                    =          444
# N                         =       209700   +/-   5.89366e-06
# #tau                      =        64.45   +/-   1.72706e-09
# A                         =       0.3857   +/-   1.85229e-11
# R                         =  -1.9974e-07   +/-   1.07767e-06
# #phi                      =       -1.059   +/-   9.8285e-11
# A_{CBO}                   =         0.02   +/-   6.02183e-11  	 (limited)
# #tau_{CBO}                =          200   +/-   2.13492e-06  	 (limited)
# #omega_{CBO}              =        2.599   +/-   5.26939e-11
# #phi_{CBO}                =      5.49779   +/-   3.07887e-09  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =  3.64269e-09
# NDf                       =          256
# Edm                       =  4.09808e-09
# NCalls                    =          418
# N                         =       209700   +/-   3.03534e-06
# #tau                      =        64.45   +/-   7.79676e-10
# A                         =       0.3857   +/-   8.24757e-12
# R                         =  -5.1363e-06   +/-   4.565e-07
# #phi                      =       -1.059   +/-   5.07355e-11
# A_{CBO}                   =         0.02   +/-   2.78406e-11  	 (limited)
# #tau_{CBO}                =          200   +/-   8.86691e-07  	 (limited)
# #omega_{CBO}              =        2.599   +/-   2.40719e-11
# #phi_{CBO}                =      5.75959   +/-   1.64883e-09  	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =   1.7827e-10
# NDf                       =          248
# Edm                       =  1.67063e-10
# NCalls                    =          394
# N                         =       209700   +/-   5.00685e-07
# #tau                      =        64.45   +/-   1.51448e-10
# A                         =       0.3857   +/-   1.89093e-12
# R                         = -1.68581e-07   +/-   9.72224e-08
# #phi                      =       -1.059   +/-   9.38445e-12
# A_{CBO}                   =         0.02   +/-   5.60007e-12  	 (limited)
# #tau_{CBO}                =          200   +/-   1.95146e-07  	 (limited)
# #omega_{CBO}              =        2.599   +/-   4.89891e-12
# #phi_{CBO}                =      6.02139   +/-   2.40275e-10  	 (limited)

# %%
print(paramVec)
print(paramErrVec)
print(paramVec[0][8],paramVec[1][8])
# Out:
# [[209700.0, 64.45, 0.3857, 0.0, -1.059, 0.020000000000000018, 200.0, 2.599, 4.336808689942018e-17], [209700.00000041907, 64.45000000192316, 0.3856999999638746, 1.7784647058906528e-07, -1.0589999999909003, 0.02000000009111369, 199.99999641304527, 2.5990000000745757, 0.2617993825274384], [209700.00012606732, 64.45000002374987, 0.3856999995073912, -1.3921863842716398e-05, -1.0589999984759955, 0.02000000108755523, 199.9999440953113, 2.5990000014096664, 0.5235987153785633], [209700.00000004517, 64.45000000001136, 0.3857000000003651, -9.519828404966628e-08, -1.0589999999920474, 0.02000000000713975, 199.9999997007396, 2.598999999956176, 0.7853981658484366], [209700.00000088266, 64.44999999989139, 0.38570000000080756, 1.4452080818964236e-07, -1.059000000018296, 0.020000000013867314, 199.9999988186367, 2.5989999999980906, 1.0471975512541178], [209700.00002104187, 64.44999999626334, 0.38569999993235987, -7.42823588745413e-07, -1.0589999997675514, 0.019999999890948583, 200.0000005288849, 2.599000000003074, 1.3089969359785016], [209699.99991192075, 64.45000001488201, 0.385699999847277, 9.614353630119131e-06, -1.059000001348041, 0.01999999942824343, 200.0000380462612, 2.5989999998656135, 1.5707963541183503], [209699.9999874033, 64.45000000629278, 0.38570000001638505, -4.065532016731812e-06, -1.058999999641714, 0.020000000115418304, 199.99999982047956, 2.5990000002711353, 1.8325956860520407], [209699.9999967609, 64.45000000175628, 0.38569999999018567, -2.5796146252675682e-06, -1.0590000000112134, 0.02000000009185865, 199.99999525507727, 2.599000000189615, 2.094395098288841], [209700.0000025888, 64.45000000360491, 0.38569999998552185, -3.509622925739592e-06, -1.0589999996381454, 0.019999999363013332, 200.00001599814448, 
# 4.336808689942018e-17 0.2617993825274384

# %%
gr.Draw("ap")
gr.GetXaxis().SetRangeUser(30,35)
c.Draw()

# %%
grCBO = r.TGraph()
cboSUM = 0
for calo in range(1,25):
    cboCaloi = paramVec[calo-1][8]
    cboSUM = cboSUM + cboCaloi
    print(calo, cboSUM % 2*math.pi, cboSUM, cboCaloi)
    grCBO.SetPoint(calo-1,calo,cboCaloi)
c=r.TCanvas() 
grCBO.SetTitle("FItted CBO Frequency for Each of the Calorimeters [SIM]")
grCBO.GetXaxis().SetTitle("Calo Number")
grCBO.GetYaxis().SetTitle("Phase [rad]")
grCBO.SetMarkerStyle(20)
grCBO.SetMarkerSize(.5)
grCBO.Draw("ap")
c.Draw()
# Out:
# 1 1.3624486320346218e-16 4.336808689942018e-17 4.336808689942018e-17
# 2 0.8224670168625446 0.26179938252743845 0.2617993825274384
# 3 2.4674008945248924 0.7853980979060018 0.5235987153785633
# 4 4.934802002497238 1.5707962637544384 0.7853981658484366
# 5 1.941484829194809 2.617993815008556 1.0471975512541178
# 6 6.053819986836418 3.9269907509870574 1.3089969359785016
# 7 4.705436966040672 5.497787105105408 1.5707963541183503
# 8 4.179520803162523 7.330382791157448 1.8325956860520407
# 9 4.476071750481634 9.42477788944629 2.094395098288841
# 10 5.595089710091926 11.78097236880746 2.3561944793611693
# 11 1.2533893907323643 14.39896623430799 2.6179938655005306
# 12 4.017341466080976 17.278759504829658 2.879793270521667
# 13 1.3205752874917012 20.42035216945861 3.1415926646289507
# 14 5.729461371013666 23.823744196901785 3.403392027443177
# 15 4.677629220725809 27.488935624859206 3.665191427957421
# 16 4.448264105070782 31.415926441000522 3.9269908161413167
# 17 5.041366007173517 35.60471663995423 4.188790198953708
# 18 0.17374943158699838 40.055306161792956 4.450589521838725
# 19 2.411785243741951 44.767695086435246 4.7123889246422905
# 20 5.472288246646525 49.74188344895495 4.974188362519702
# 21 3.0720730880333873 54.977871235000194 5.235987786045243
# 22 1.4943248700449656 60.47565837930562 5.497787144305429
# 23 0.7390436807619608 66.23524490990819 5.759586530602572
# 24 0.8062295286218 72.25663082949362 6.021385919585433

# %%
print((cboSUM ))
print((cboSUM % 2*math.pi),"mod 2 pi")
print((cboSUM % 2*math.pi)/math.pi,"pi")
# Out:
# 72.25663082949362
# 0.8062295286218 mod 2 pi
# 0.2566308294936164 pi

# %%
print("Starting All Calos")
tempdf  = dataCBO
timeVecCBO = tempdf['time'].values
wiggleVecCBO = tempdf['wiggle'].values
c = r.TCanvas()
print("    Drawing")
gr = r.TGraph(len(timeVecCBO), timeVecCBO, wiggleVecCBO)
gr.SetTitle("All Calos")
gr.Draw("ap")
gr.GetXaxis().SetRangeUser(30,300)

print("    Fitting")
gr.Fit('func','REM')
func.Draw("same")

ding = func.GetParameters()
ding2 = func.GetParErrors()
paramsFit = []
paramsErrFit = []
for i in range(len(params)):
    paramsFit.append(ding[i])
    paramsErrFit.append(ding2[i])
print(paramsFit,paramsErrFit)

c.SetLogy()
c.Print("./images/CBO/CBO_Sim_Calo_All.png")
c.Draw()
# Out:
# Starting All Calos
#     Drawing
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#
# ****************************************
# Minimizer is Minuit / MigradImproved
# Chi2                      =  1.25257e+09
# NDf                       =         6369
# Edm                       =   0.00296657
# NCalls                    =          863
# N                         =       209456   +/-   59.1145
# #tau                      =      64.4769   +/-   0.0165084
# A                         =      0.38558   +/-   0.000197768
# R                         =     -9.93955   +/-   10.3948
# #phi                      =     -1.05838   +/-   0.00104673
# A_{CBO}                   =   0.00110811   +/-   0.000251176  	 (limited)
# #tau_{CBO}                =          190   +/-   0.433696     	 (limited)
# #omega_{CBO}              =      2.59827   +/-   0.00419157
# #phi_{CBO}                =      6.28319   +/-   0.0005022    	 (limited)
# Info in <TCanvas::Print>: png file ./images/CBO/CBO_Sim_Calo_All.png has been created

# %%
print((paramsFit[8] ))
print((paramsFit[8] % (2*math.pi)),"mod 2 pi")
print((paramsFit[8] % (2*math.pi))/math.pi,"pi")

# %% [markdown]
# Now lets try creating/fittinghistograms instead of the tgraphs, because I'm out of ideas

# %%
paramVec = []
paramErrVec = []
histVec = []

for calo in range(1,25):
    print("Starting Calo",calo)
    tempdf  = dataCBO.loc[dataCBO['calo'] == calo]
    timeVecCBO = tempdf['time'].values
    wiggleVecCBO = tempdf['wiggle'].values
    c = r.TCanvas()
    print("    Filling")
    #create/fill a TH2 and then project onto the x-axis
    h1 = r.TH2D("h1","h"+str(calo),700000,0,700,3000,0,1000000)
    for i in range(len(timeVecCBO)):
        h1.Fill(timeVecCBO[i], wiggleVecCBO[i])

    print("    Projecting (all of my issues)")
    h2 = h1.ProfileX()
    h2.GetXaxis().SetRangeUser(0,150)
    
    print("    Fitting")
    h2.Fit('func','R')
    h2.Draw()
    func.Draw("SAME")
    
    ding = func.GetParameters()
    ding2 = func.GetParErrors()
    paramsFit = []
    paramsErrFit = []
    for i in range(len(params)):
        paramsFit.append(ding[i])
        paramsErrFit.append(ding2[i])
    print(paramsFit,paramsErrFit)
    paramVec.append(paramsFit)
    paramErrVec.append(paramsErrFit)
    
    print("    Drawing")
    c.Draw()
    
    histVec.append( h2.Clone("h"+str(calo)) )
    
    h1.Delete()
    h2.Delete()
    
#    c.Print("./images/CBO/CBO_Sim_Calo"+str(calo).zfill(2)+".png")
# Out:
# Starting Calo 1
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 2
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 3
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 4
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 5
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 6
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 7
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 8
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 9
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 10
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 11
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 12
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 13
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 14
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 15
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 16
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 17
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 18
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 19
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 20
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 21
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 22
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 23
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Starting Calo 24
#     Filling
#     Projecting (all of my issues)
#     Fitting
# [209456.1556676449, 64.4768653050332, 0.3855802314815778, -9.939549832394851, -1.0583815540260788, 0.001108106104458273, 190.00000000015376, 2.59827064680424, 6.283185307143918] [59.11450332032382, 0.016508430692092735, 0.00019776825422123225, 10.394803867117314, 0.0010467253765659205, 0.0002511756020852636, 0.433695944527288, 0.004191573095214234, 0.0005022003128541185]
#     Drawing
# Warning in <Fit>: Fit data is empty
# Warning in <TROOT::Append>: Replacing existing TH1: h1 (Potential memory leak).
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty

# %%
print(histVec)
c2 = r.TCanvas()
c2.Divide(1,2)
c2.cd(1)
histVec[0].Draw()
c2.cd(2)
histVec[23].Draw()
c2.Draw()
# Out:
# [<ROOT.TProfile object ("h1") at 0x7fffcae7a250>, <ROOT.TProfile object ("h2") at 0x7fffcae64cb0>, <ROOT.TProfile object ("h3") at 0x7fffcac880f0>, <ROOT.TProfile object ("h4") at 0x7fffcae6aee0>, <ROOT.TProfile object ("h5") at 0x7fffcaec77b0>, <ROOT.TProfile object ("h6") at 0x7fffcaecc590>, <ROOT.TProfile object ("h7") at 0x7fffca6e75b0>, <ROOT.TProfile object ("h8") at 0x7fffcaebf090>, <ROOT.TProfile object ("h9") at 0x7fffcae6f530>, <ROOT.TProfile object ("h10") at 0x7fffcaeb2d00>, <ROOT.TProfile object ("h11") at 0x7fffcaee71f0>, <ROOT.TProfile object ("h12") at 0x7fffcaec9240>, <ROOT.TProfile object ("h13") at 0x7fffcae96410>, <ROOT.TProfile object ("h14") at 0x7fffcaeadf10>, <ROOT.TProfile object ("h15") at 0x7fffca6e6d00>, <ROOT.TProfile object ("h16") at 0x7fffcae87260>, <ROOT.TProfile object ("h17") at 0x7fffcae77050>, <ROOT.TProfile object ("h18") at 0x7fffcaed6790>, <ROOT.TProfile object ("h19") at 0x7fffcaeca410>, <ROOT.TProfile object ("h20") at 0x7fffcaeca860>, <ROOT.TProfile object ("h21") at 0x7fffcae654c0>, <ROOT.TProfile object ("h22") at 0x7fffcae65910>, <ROOT.TProfile object ("h23") at 0x7fffcaee1b70>, <ROOT.TProfile object ("h24") at 0x7fffca8e7f40>]

# %%
hTotal = histVec[0].Clone("hTotal")
(hTotal.GetFunction("func")).Delete()
hTotal.SetTitle("hTotal")

for i,hist in enumerate(histVec):
    if i > 0:
        hTotal.Add(hist,1)
        
c3 = r.TCanvas()
hTotal.Draw()
c3.Draw()
# Out:
# ---------------------------------------------------------------------------
# ReferenceError                            Traceback (most recent call last)
# <ipython-input-23-e43ea12d58fc> in <module>()
#       1 hTotal = histVec[0].Clone("hTotal")
# ----> 2 (hTotal.GetFunction("func")).Delete()
#       3 hTotal.SetTitle("hTotal")
#       4
#       5 for i,hist in enumerate(histVec):
#
# ReferenceError: attempt to access a null-pointer

# %%
c3 = r.TCanvas()
hTotal.Draw()
func.SetParameter(8,0)
hTotal.Fit("func","REMB V")
func.Draw("SAME")
c3.Draw()

# %%
import csv

out = open('CBO_hist_byCalo_fitParams_2.csv','w')
csv_out = csv.writer(out)
func.SetParNames()
csv_out.writerow(['N','tau','A','R','phi','ACBO','tauCBO','omegaCBO','phiCBO'])
for i in range(len(paramVec)):
    csv_out.writerow(paramVec[i])
out.close()

# %%
import csv

out = open('CBO_hist_byCalo_fitParams_err_2.csv','w')
csv_out = csv.writer(out)
func.SetParNames()
csv_out.writerow(['N','tau','A','R','phi','ACBO','tauCBO','omegaCBO','phiCBO'])
for i in range(len(paramErrVec)):
    csv_out.writerow(paramErrVec[i])
out.close()

# %%
print("hi")
