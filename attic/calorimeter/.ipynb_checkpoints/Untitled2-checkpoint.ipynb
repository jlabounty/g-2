# %%
import ROOT as r
import math
from BlindersPy3 import Blinders
from BlindersPy3 import FitType
r.gStyle.SetOptStat(0)
r.gStyle.SetOptFit(1111)
import matplotlib.pyplot as plt
import csv
import pandas

import seaborn as sns
sns.set(style="ticks", color_codes=True)
import numpy as np
import matplotlib.pyplot as plt
import matplotlib 
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 

from scipy import stats

# %matplotlib inline
# Out:
# Welcome to JupyROOT 6.12/06

# %%
calovec = [2,14,18,20]
measvec = [(11.6,11.5,11.6),(12,11.8,11.9),(11.7,11.5,11.5),(11.5,11.6,11.5)]

# %%
meanvec = []
stdvec = []
for i in measvec:
    meanvec.append(np.mean(i))
    stdvec.append(np.std(i))
    
print(stdvec)
# Out:
# [0.047140452079103, 0.08164965809277232, 0.094280904158206, 0.047140452079103]

# %%
plt.errorbar(calovec,meanvec,0,stdvec)
# Out:
# <ErrorbarContainer object of 3 artists>
