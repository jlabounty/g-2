# %%
from python_fit import *
import ROOT as r
import matplotlib.pyplot as plt
from standardInclude import *
# Out:
# Welcome to JupyROOT 6.20/04
# Not a jupyter notebook. Not enabling notebook functions.
# For interactive plots, run: setint()
# To return to non-interactive plots (default state), run: noint()

# %% [raw]
# ding=fitVector(input_file="./ding.root")

# %% [raw]
# ding.draw()
# plt.show()

# %% [raw]
# ding.confidenceIntervals

# %% [raw]
# ding.x

# %% [raw]
# import matplotlib.pyplot as plt
# fig, ax = plt.subplots()
# ding.drawFitResult(plt)
# plt.show()

# %% [raw]
# import matplotlib.pyplot as plt
# ding.draw()
# plt.show()

# %% [raw]
# import ROOT as r
# c = r.TCanvas()
# ding.f.Draw()
# c.Draw()

# %%
x = [1,2,3,4,5,6]
y = [2,4,6.2,9,10,13]
yerr = [1,1,1,2,1,1]
xerr = [0 for i in range(len(x))]

# %%
import ROOT as r
f1 = r.TF1("f1","pol1",1,5.5,2)
ding = fitVector(x,y, f1, xerr, yerr)
print(ding)
ding.draw()
plt.show()

# %%
ding.computeConfidenceIntervals(0.95,[-1,10],100)

# %%
print(ding.confidenceIntervals)

# %% [raw]
# ding.save("./ding.root")

# %% [raw]
# import ROOT as r
# f = r.TFile("./ding.root")
# f.ls()
# t = f.Get("t")
# t.Print()

# %% [raw]
# c = r.TCanvas()
# t.Draw("yerr")
# c.Draw()

# %% [raw]
# c = r.TCanvas()
# f.Get("f").Draw()
# c.Draw()

# %% [raw]
# [x.GetName() for x in f.GetListOfKeys()]

# %% [raw]
# [x for x in t.GetListOfBranches()]

# %% [raw]
# keys = [x.GetName() for x in t.GetListOfBranches()]
# extractedVecs = [None for i in keys]
# for j, entry in enumerate(t): #should only be 1
#     print(entry)
#     for i, key in enumerate(keys):
#         entries = entry.Draw(key,"","goff")
#         content = [entry.GetVal(0)[x] for x in range(entries)]
#         print(content)
#         if(len(content) is 1):
#             content = content[0]
#         try:
#             content = list(content)
#         except:
#             pass
#         print(content)
#         extractedVecs[i] = content
#     break
# print(extractedVecs)

# %% [markdown]
# ---
#
# ### Now lets test the histogram fitting

# %% [raw]
# h = r.TH1D("h","Example Fit", 1000,0,100)
# func = r.TF1("func","gaus",0,100)
# func.SetParameters(23,30,5,4)
# h.FillRandom("func",10000000)
#
# c = r.TCanvas()
# h.Draw()
# c.Draw()

# %% [raw]
# ding = fitHist(h,func)

# %% [raw]
# fig,ax = ding.draw()
# ax[0].set_ylim(0.1,1000)
# ax[0].set_yscale("log")
# plt.show()

# %% [raw]
# xs = np.random.normal(size=100000)
# print(xs)
#
# ding = plt.hist(xs,bins=320, range=(-5,5))

# %% [raw]
# print(ding)
# print(type(ding))
# print([type(x) for x in ding])

# %% [raw]
# for i, x in enumerate(ding):
#     print(i,x, len(x))

# %% [raw]
# func = r.TF1("func","gaus",-100,100)
# dong = fitHist(ding,func,binErrors=True)

# %% [raw]
# fig,ax = dong.draw()
# ax[0].set_ylim(0.1,1500)
# plt.show()
