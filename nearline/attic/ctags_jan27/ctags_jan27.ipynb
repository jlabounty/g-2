# %%
from standardInclude import *
r.gStyle.SetOptStat(11111)
# Out:
# Welcome to JupyROOT 6.12/06
# For interactive plots, run: setint()
# To return to non-interactive plots (default state), run: noint()

# %%
ch = r.TChain("nearlineHistTree/eventTree")
ch.Add("./data/gm2nearline_hists_run32775_00*.root")
#ch.Print()
# Out:
# 25

# %%
ch2 = r.TChain("nearlineHistTree/eventTree")
ch2.Add("./data/*run32996_*.root")
#ch2.Add("./data/nearline_run32996_00030.root")
#ch.Print()
# Out:
# 56

# %%
ch3 = r.TChain("nearlineHistTree/eventTree")
ch3.Add("./data/*run33148_*.root")
#ch2.Add("./data/nearline_run32996_00030.root")
#ch.Print()
# Out:
# 46

# %%
c = r.TCanvas("c","c",1200,600)
c.Divide(1,3)

c.cd(1)
h = r.TH1D("h","CTAGs in Run 32775 (25 Subruns)",200,0,1000)
ch.Draw("ctag>>h")
h.GetXaxis().SetRangeUser(200,700)
print( h.GetMean() )
h.Draw()

c.cd(2)
h2 = r.TH1D("h2","CTAGs in Run 32996 (56 Subruns)",200,0,1000)
ch2.Draw("ctag>>h2")
h2.GetXaxis().SetRangeUser(200,700)

h2.Draw()

c.cd(3)
h3 = r.TH1D("h3","CTAGs in Run 33148 (46 Subruns)",200,0,1000)
ch3.Draw("ctag>>h3")
h3.GetXaxis().SetRangeUser(200,700)

h3.Draw()

c.Draw()
# Out:
# 471.7015278283012
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Warning in <TROOT::Append>: Replacing existing TH1: h (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3 (Potential memory leak).

# %%
c = r.TCanvas("c","c",1200,600)
c.Divide(1,3)

whatToDraw = "energy"
cut = "energy < 6000"
drawstring = "colz"

c.cd(1)
ch.Draw(whatToDraw,cut,drawstring)
r.gPad.SetLogy()

c.cd(2)
ch2.Draw(whatToDraw,cut, drawstring)
r.gPad.SetLogy()

c.cd(3)
ch3.Draw(whatToDraw,cut, drawstring)
r.gPad.SetLogy()

c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
