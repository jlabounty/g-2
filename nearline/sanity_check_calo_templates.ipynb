# %%
#General imports.
import ROOT as r
import math
from BlindersPy3 import Blinders
from BlindersPy3 import FitType
r.gStyle.SetOptStat(0)
r.gStyle.SetOptFit(1111)
import matplotlib.pyplot as plt
import csv
import pandas

import seaborn as sns
sns.set(style="ticks", color_codes=True)
import numpy as np
import matplotlib.pyplot as plt
import matplotlib 
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
import os
import scipy

import uproot # https://indico.cern.ch/event/686641/contributions/2894906/attachments/1606247/2548596/pivarski-uproot.pdf
from awkward import JaggedArray
from root_pandas import read_root # https://github.com/scikit-hep/root_pandas

import warnings
warnings.filterwarnings('once')

# %matplotlib inline
plt.rcParams['figure.facecolor'] = 'white'
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed',)).History will not be written to the database.
# Welcome to JupyROOT 6.12/06

# %%
fo = r.TFile("./hist_oldtemplates.root")
fc = r.TFile("./hist_calotemplates.root")
# Out:
# Warning in <TClass::Init>: no dictionary for class gm2aux::IBMSRawArtRecord is available

# %%
fo.cd("nearlineHistTree")
fo.ls()
# Out:
# TFile**		./hist_oldtemplates.root
#  TFile*		./hist_oldtemplates.root
#   TDirectoryFile*		nearlineHistTree	nearlineHistTree (CaloNearlineHistograms) folder
#    KEY: TDirectoryFile	calo1;1	calo1
#    KEY: TDirectoryFile	calo2;1	calo2
#    KEY: TDirectoryFile	calo3;1	calo3
#    KEY: TDirectoryFile	calo4;1	calo4
#    KEY: TDirectoryFile	calo5;1	calo5
#    KEY: TDirectoryFile	calo6;1	calo6
#    KEY: TDirectoryFile	calo7;1	calo7
#    KEY: TDirectoryFile	calo8;1	calo8
#    KEY: TDirectoryFile	calo9;1	calo9
#    KEY: TDirectoryFile	calo10;1	calo10
#    KEY: TDirectoryFile	calo11;1	calo11
#    KEY: TDirectoryFile	calo12;1	calo12
#    KEY: TDirectoryFile	calo13;1	calo13
#    KEY: TDirectoryFile	calo14;1	calo14
#    KEY: TDirectoryFile	calo15;1	calo15
#    KEY: TDirectoryFile	calo16;1	calo16
#    KEY: TDirectoryFile	calo17;1	calo17
#    KEY: TDirectoryFile	calo18;1	calo18
#    KEY: TDirectoryFile	calo19;1	calo19
#    KEY: TDirectoryFile	calo20;1	calo20
# ...

# %%
to = fo.Get("nearlineHistTree").Get("eventTree")
to.SetLineColor(4)
tc = fc.Get("nearlineHistTree").Get("eventTree")
tc.SetLineColor(2)

# %%
c = r.TCanvas()
to.Draw("x")
tc.Draw("x","","SAME")
c.Draw()

# %%
c = r.TCanvas()
to.Draw("y")
tc.Draw("y","","SAME")
c.Draw()

# %%
c = r.TCanvas()
to.Draw("time")
tc.Draw("time","","SAME")
c.SetLogy()
c.Draw()

# %%
c = r.TCanvas()
to.Draw("energy","energy<20000")
tc.Draw("energy","energy<20000","SAME")
c.SetLogy()
c.Draw()

# %%
c = r.TCanvas("c","c",1100,500)
c.Divide(2)
c.cd(1)
to.Draw("energy:time*1.25/1000>>ho(700,0,700,500,0,5000)","energy<20000","colz")
r.gPad.SetLogz()
c.cd(2)
tc.Draw("energy:time*1.25/1000>>hc(700,0,700,500,0,5000)","energy<20000","colz")
r.gPad.SetLogz()
c.Draw()

# %%
c = r.TCanvas("c","c",1100,500)
c.Divide(2)
c.cd(1)
to.Draw("energy:time*1.25/1000>>ho(700,0,700,500,0,5000)","energy<20000","colz")
r.gPad.SetLogz()
c.cd(2)
tc.Draw("energy:time*1.25/1000>>hc(700,0,700,500,0,5000)","energy<20000","colz")
r.gPad.SetLogz()
c.Draw()
