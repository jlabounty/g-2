# %%
from standardInclude import *
# Out:
# Welcome to JupyROOT 6.12/06
# For interactive plots, run: setint()
# To return to non-interactive plots (default state), run: noint()

# %%
f = r.TFile("./data/gm2nearline_hists_run27530_00041.root")
# Out:
# Warning in <TClass::Init>: no dictionary for class gm2aux::IBMSRawArtRecord is available

# %%
t = f.Get("nearlineHistTree").Get("eventTree")

# %%
#h = f.Get("nearlineHistTree").Get("calo1").Get("wiggle").Clone()
h = f.Get("nearlineHistTree").Get("allCaloWiggle").Clone()

# %%
c = r.TCanvas("c","c",1200,600)
h.Draw()
c.SetLogy()
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
nLaser = t.Draw("eventNum:time","energy > 40000 && caloNum == 1","goff")

# %%
ifgs = []
for i in range(nLaser):
    ifgs.append(t.GetV2()[i])

# %%
lines = []
for ti in ifgs:
    if(ti > 0 and ti < 500000):
        li = r.TLine(ti, 0, ti, 200)
        lines.append(li)

# %%
c = r.TCanvas("c","c",1200,600)
h.Draw()
h.GetXaxis().SetRangeUser(40000,80000)
for li in lines:
    li.Draw("SAME")
c.SetLogy()
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
