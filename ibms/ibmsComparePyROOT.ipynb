# %%
import ROOT as r
# Out:
# Welcome to JupyROOT 6.12/06

# %%
fbaseline = r.TFile("./gm2offline_ibms_baseline.root")
tbaseline = fbaseline.Get("ibmsAnalyzer").Get("t_ibms")
f = r.TFile("./gm2offline_ibms.root")
t = f.Get("ibmsAnalyzer").Get("t_ibms")
# Out:
# Warning in <TClass::Init>: no dictionary for class gm2aux::IBMSRawArtRecord is available
# Warning in <TClass::Init>: no dictionary for class gm2aux::IBMSBeamProfileArtRecord is available

# %%
#r.enableJSVis()
cbase = r.TCanvas()
cbase.Divide(2,2)
title = r.TPaveLabel(.4,.95,.6,.99,"Baseline","brndc")
title.Draw()
cbase.cd(1)
fbaseline.Draw("ibms1XIntegral")
cbase.cd(2)
fbaseline.Draw("ibms1YIntegral")
cbase.cd(3)
fbaseline.Draw("ibms2XIntegral")
cbase.cd(4)
fbaseline.Draw("ibms2YIntegral")
cbase.Draw()

# %%
c = r.TCanvas()
c.Divide(2,2)
title2 = r.TPaveLabel(.4,.95,.6,.99,"New Processor","brndc")
title2.Draw()
c.cd(1)
f.Draw("ibms1XIntegral")
c.cd(2)
f.Draw("ibms1YIntegral")
c.cd(3)
f.Draw("ibms2XIntegral")
c.cd(4)
f.Draw("ibms2YIntegral")
c.Draw()
