# %%
from standardInclude import *
# Out:
# Welcome to JupyROOT 6.12/06
# For interactive plots, run: setint()
# To return to non-interactive plots (default state), run: noint()

# %%
f = r.TFile("./data/post_disk/syncPulseEnergiesRun23609TQBankFitsCalibrated.root")
f.ls()
# Out:
# TFile**		./data/post_disk/syncPulseEnergiesRun23609TQBankFitsCalibrated.root
#  TFile*		./data/post_disk/syncPulseEnergiesRun23609TQBankFitsCalibrated.root
#   KEY: TDirectoryFile	syncPulseEnergies;1	syncPulseEnergies (SyncPulseEnergyExtraction) folder

# %%
calo = 22
c = r.TCanvas("c","c",3000,1500)
c.Divide(9,6)
for xtal in range(54):
    c.cd(54-xtal)
    hi = f.Get("syncPulseEnergies/calo"+str(calo)+"/calo"+str(calo)+"xtal"+str(xtal))
    hi.SetFillColorAlpha(38,0.2)
    if(hi.Integral(0,hi.GetXaxis().FindBin(500)) > 100 ):
        hi.SetFillColorAlpha(45,0.2)
    r.gPad.SetLogy()
    hi.DrawCopy("hist")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
