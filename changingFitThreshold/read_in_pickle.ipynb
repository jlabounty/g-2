# %%
from standardInclude import *
from pickle_util import *
# Out:
# Welcome to JupyROOT 6.12/06
# For interactive plots, run: setint()
# To return to non-interactive plots (default state), run: noint()

# %%
filename = "./pileup.pickle"

# %%
file = open(filename,"rb")

content = file.read()

file.close()
# Out:
# /home/jlab/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: ResourceWarning: unclosed file <_io.BufferedReader name='./pileup.pickle'>
#   """Entry point for launching an IPython kernel.

# %%
ding = pickle_load(content)
# Out:
# <module 'python_pileup' from '/home/jlab/g-2/fitting/python_pileup.py'>
# PythonPileup is the class which contains:
# Initializing empty function...
# deltat 2
# You will need to initialize this function
# You will need to initialize this function
# You will need to initialize this function
# You will need to initialize this function
# verbosity -1

# %%
ding

# %%
ding.rhoDouble.contents
# Out:
# array([[3.20573800e+15, 6.48335468e+17, 1.23371388e+17, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [3.40350418e+15, 1.02364159e+18, 1.80581404e+17, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.67630567e+15, 7.37540132e+17, 1.24512116e+17, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [2.93382014e+13, 5.67188066e+16, 3.18779065e+14, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.27668370e+13, 4.87392642e+16, 2.09255456e+14, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.90808709e+13, 4.29027927e+16, 1.47995253e+14, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
drawTH2(ding.hpy)
plt.show()

# %%
drawTH2(ding.rhoDouble)
plt.show()

# %%
drawTH2(ding.doublePileup)
plt.show()

# %%
drawTH2(ding.triplePileup)
plt.show()
