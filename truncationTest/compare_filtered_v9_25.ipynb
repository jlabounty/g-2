# %%
from standardInclude import *
# Out:
# Welcome to JupyROOT 6.12/06
# For interactive plots, run: setint()
# To return to non-interactive plots (default state), run: noint()

# %%
f_filter = r.TFile("./data/filterTest/gm2offline_ana.root")

# %%
f_filter.ls()
# Out:
# TFile**		./data/filterTest/gm2offline_ana.root
#  TFile*		./data/filterTest/gm2offline_ana.root
#   KEY: TDirectoryFile	farline;1	farline (CaloFarlineHistograms) folder
#   KEY: TDirectoryFile	farlineFilter;1	farlineFilter (CaloFarlineHistograms) folder

# %%
t_filter = f_filter.Get("farlineFilter").Get("eventTree")
t_filter.SetMarkerSize(0.5)
t_filter.SetMarkerColor(4)
t_filter.SetMarkerStyle(8)

#t_full = f_full.Get("farline").Get("eventTree")
#t_full.SetLineColor(2)
#t_full.SetMarkerColor(2)
#t_full.SetMarkerStyle(8)
#t_full.SetMarkerSize(0.5)

t_trunc = f_filter.Get("farline").Get("eventTree")
t_trunc.SetLineColor(3)
t_trunc.SetMarkerColor(3)
t_trunc.SetMarkerStyle(8)
t_trunc.SetMarkerSize(0.5)

# %%
c = r.TCanvas()
t_filter.Draw("eventNum>>hist(300,0,300)","","colz")
c.Draw()

# %%
c = r.TCanvas()
t_trunc.Draw("eventNum>>hist(300,0,300)","ctag > 0","colz")
c.Draw()

# %%
c = r.TCanvas("c","c",1600,600)
c.Divide(2)
c.cd(1)
h = r.TH2D("h","Filtered Truncated Banks; Calo Number; Event Number",25,0,25,250,0,250)
t_filter.Draw("eventNum:caloNum>>h","","goff")
h.Draw("colz")

c.cd(2)
h2 = r.TH2D("h2","Filtered Truncated Banks; Calo Number; Event Number",25,0,25,250,0,250)
h2.Reset()
h2.SetTitle("All Truncated Banks")
t_trunc.Draw("eventNum:caloNum>>h2","","goff")
h2.Draw("colz")

c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Warning in <TFile::Append>: Replacing existing TH1: h (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h2 (Potential memory leak).
