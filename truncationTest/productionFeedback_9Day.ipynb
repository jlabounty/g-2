# %%
from standardInclude import *
# Out:
# Welcome to JupyROOT 6.12/06
# For interactive plots, run: setint()
# To return to non-interactive plots (default state), run: noint()

# %% [markdown]
# Using hadd.sh, we merged all of these files together into one output, which we will run through now:

# %%
f = r.TFile("./data/results_10MissingOutputFiles_9day_histOnly.root ") #processed output of hadd.sh

#check if the directory where we will be saving the images exists
prodString="9day_Full"
directory = os.path.dirname("./images/"+prodString+"/")
if not os.path.exists(directory):
    print("Creating Image Directory:", directory)
    os.makedirs(directory)
else:
    print("Image Directory", directory,"exists. Continuing.")
# Out:
# Creating Image Directory: ./images/9day_Full

# %%
f.cd("farline/calo1")
#f.ls()
# Out:
# True

# %% [markdown]
# Print all of the embedded histograms.

# %%
c = r.TCanvas("c","c",1800,1000)
c.Divide(2,2)
c.cd(1)
allCaloEnergies = f.Get("farline").Get("allCaloEnergies").Clone()
allCaloEnergies.Draw()
c.Draw()

c.cd(2)
allCaloWiggle = f.Get("farline").Get("allCaloWiggle").Clone()
allCaloWiggle.Draw()
allCaloWiggle.GetXaxis().SetRange(30,350)

c.cd(3)
allCaloTimes = f.Get("farline").Get("allCaloTimes").Clone()
allCaloTimes.GetXaxis().SetRange(30,350)
allCaloTimes.Draw()

c.cd(4)
farlineCtag = f.Get("farline").Get("farlineCTag").Clone()
farlineCtag.Draw()

c.Draw()
c.Print("./images/"+prodString+"/"+prodString+"_farlineHistograms.png")
c.Print("./images/"+prodString+"/"+prodString+"_farlineHistograms.root")

print("{:,}".format(int(allCaloEnergies.GetEntries())), "Entries in these histograms")
print("{:,}".format(int(allCaloWiggle.GetEntries())), "Entries in these histograms")
print("{:,}".format(int(allCaloTimes.GetEntries())), "Entries in these histograms")
print("{:,}".format(int(farlineCtag.GetEntries())), "Entries in these histograms")
# Out:
# 14,971,965,714 Entries in these histograms
# 3,083,263,403 Entries in these histograms
# 14,971,965,714 Entries in these histograms
# 1,088,726,511 Entries in these histograms
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_farlineHistograms.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_farlineHistograms.root has been created

# %% [markdown]
# # Now lets make a wiggle plot of all of the calos

# %%
# blinded instance
getBlinded = Blinders(FitType.Omega_a, 'This is my fight song. Blinding my plot song.')
def blinded_wiggle(x, p):
    norm  = p[0]
    life  = p[1]
    asym  = p[2]
    R     = p[3]
    phi   = p[4]
    
    time  = x[0]
    omega = getBlinded.paramToFreq(R)
#    omega = myBlinder.paramToFreq(R) unblind version
    
    return norm * math.exp(-time/life) * (1 - asym*math.cos(omega*time + phi))
# Out:
#  + ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ +
#  +                                                                      +
#  +           You have chose to blind your fitting according to          +
#  +                omega_ref * (1 + (R +/- deltaR) *10^{-6})             +
#  +                                                                      +
#  + ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ +

# %%
func = r.TF1("func", blinded_wiggle, 30,600,5)
func.SetParNames('N','#tau','A','R','#phi')
func.SetParameters(700000,64.4,0.4,0,0)
func.SetParLimits(4,-0.001 - 2*math.pi,2*math.pi+0.001)
func.SetLineColor(2)
func.SetNpx(2000)

# %% [markdown]
# ### Five parameter fit

# %%
c2 = r.TCanvas("c2","c2",1200,800)
c2.Divide(2,1)
c2.cd(1)
r.gPad.SetLogy()

r.gStyle.SetOptFit(111)
allCaloWiggle = f.Get("farline").Get("allCaloWiggle").Clone()

print(allCaloWiggle.GetXaxis().GetXmin(),allCaloWiggle.GetXaxis().GetXmax())
allCaloWiggle.GetXaxis().SetLimits(allCaloWiggle.GetXaxis().GetXmin() / 1000 * 1.25,allCaloWiggle.GetXaxis().GetXmax() / 1000 * 1.25)
print(allCaloWiggle.GetXaxis().GetXmin(),allCaloWiggle.GetXaxis().GetXmax())
allCaloWiggle.GetXaxis().SetTitle("Time [#mus]")

residuals = allCaloWiggle.Clone() # this will be filled with the fit residuals later

for fit in range(2):
    print("Sarting fit:", fit+1)
    allCaloWiggle.Fit("func","REM")

    
chiSqAll = ( ( func.GetNDF(),
              func.GetChisquare(),
              func.GetProb() ) )
    
allCaloWiggle.Draw()

c2.cd(2)
ding =  allCaloWiggle.Clone()
ding.GetXaxis().SetRangeUser(100,125)
ding.Draw()

r.gPad.SetLogy()
c2.Draw()
# Out:
# 0.0 560000.0
# 0.0 700.0
# Sarting fit: 1
# Sarting fit: 2
#  FCN=4084.35 FROM MINOS     STATUS=SUCCESSFUL     36 CALLS         509 TOTAL
#                      EDM=1.075e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  N            5.38814e+04   2.52584e+01  -2.54438e-03  -1.35212e-09
#    2  #tau         6.41850e+01   1.69622e-02  -1.07671e-06  -2.90405e-06
#    3  A            4.01663e-01   3.46860e-04  -1.45390e-07   5.12936e-05
#    4  R           -1.33136e+01   9.73724e+00  -9.34344e-05  -3.97912e-08
#    5  #phi        -1.06640e+00   1.59494e-03   1.59494e-03   7.43621e-03
#  FCN=4084.35 FROM MINOS     STATUS=SUCCESSFUL     36 CALLS         284 TOTAL
#                      EDM=1.52301e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  N            5.38814e+04   2.52573e+01  -2.26877e-03  -1.25686e-09
#    2  #tau         6.41850e+01   1.69614e-02  -1.41647e-06  -1.16606e-06
#    3  A            4.01663e-01   3.46860e-04  -1.40549e-07   4.76387e-05
#    4  R           -1.33136e+01   9.73724e+00  -2.27675e-05  -4.16243e-08
#    5  #phi        -1.06640e+00   1.59494e-03   1.59494e-03   7.37247e-03

# %%
#The class calculates the  difference between the histogram and the fit function at each point 
#    and divides it by the uncertainty.
c3 = r.TCanvas("c","c",1600,600)
allCaloWiggle.Draw()
c3.SetLogy()
c3.Draw()

rp1 = r.TRatioPlot(allCaloWiggle)
rp1.Draw()
rp1.GetLowerRefYaxis().SetTitle("Residual")
rp1.GetLowerRefYaxis().SetRangeUser(-7,7)

allCaloWiggle.GetXaxis().SetRangeUser(30,150)

c3.Update()
c3.Draw()
c3.Print("./images/"+prodString+"/"+prodString+"_TmethodWiggleFitAllCalos.png")
c3.Print("./images/"+prodString+"/"+prodString+"_TmethodWiggleFitAllCalos.root")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_TmethodWiggleFitAllCalos.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_TmethodWiggleFitAllCalos.root has been created

# %% [markdown]
# ### Fourier transform of the 5-parameter residuals.

# %%
c3 = r.TCanvas()
residuals5param = residuals.Clone() # this will hold the residials from the 5-parameter fit
nBins = residuals5param.GetSize() - 2 #total number of bins excluding over/underflow
print(nBins)
residVec = []
for i in range(nBins):
    binCenterX = allCaloWiggle.GetXaxis().GetBinCenter(i)
    if (binCenterX > 30 and binCenterX < 600):
        residVec.append( (binCenterX, allCaloWiggle.GetBinContent(i) - func.Eval(binCenterX) ) )
        residuals5param.SetBinContent(i, allCaloWiggle.GetBinContent(i) - func.Eval(binCenterX))
    else:
        residuals5param.SetBinContent(i, 0)

print(len(residVec),[residVec[i] for i in range(5)])
centers, bins = zip(*residVec)
htest = r.TH1D("htest","htest",len(residVec),centers[0],centers[len(residVec)-1])
for i,ding in enumerate(bins):
    htest.SetBinContent(i, ding)
    
residuals5param.Delete()
residuals5param = htest
nBins = residuals5param.GetSize() - 2 #total number of bins excluding over/underflow

#apply a windows function to try to get rid of the imaginary peaks
welchVec = []
for i in range(nBins):
    unwindowed = residuals5param.GetBinContent(i)
    welch = 1 #- ( ( i - (nBins - 1) / 2) / ((nBins - 1) / 2) )**2
    welchVec.append(welch)
    residuals5param.SetBinContent(i, unwindowed *  welch)
    
residuals5param.Draw()
residuals5param.GetXaxis().SetRangeUser(30,700)
residuals5param.SetTitle("(Windowed) Residuals of the 5-parameter Fit")
c3.Draw()    
    
hxform = r.TH1D()
hxform = 0
r.TVirtualFFT.SetTransform(0)
hxform = residuals5param.FFT(hxform,"MAG P")
hxform.SetTitle("Magnitude of the First Transform (5-Parameter Residuals)")
#NOTE: for "real" frequencies you have to divide the x-axes range with the range of your function
#    y-axes has to be rescaled by a factor of 1/SQRT(n) to be right: this is not done automatically!
normXform = hxform.GetEntries()
hxform.Scale(1/normXform)
c2 = r.TCanvas()
c2.cd()
#c2.SetLogy()
hxform.GetXaxis().SetTitle("Frequency (MHz)")
hxform.GetYaxis().SetTitle("Arb. Units")
hxform.Draw("HIST P0 L")
c2.Draw()

Npart = residuals5param.GetSize() - 2
minBinCenter = residuals5param.GetXaxis().GetBinCenter(0)
maxBinCenter = residuals5param.GetXaxis().GetBinCenter(Npart)

capT = maxBinCenter - minBinCenter
print(Npart, capT, minBinCenter, maxBinCenter)
deltaT = capT/Npart #microseconds
deltaF = 1/capT
print(deltaT, deltaF)

deltaTns = deltaT*1000 #nanoseconds
limmaxHz = (1/(deltaTns*math.pow(10.0,-9)))
limmaxMHz = limmaxHz / math.pow(10.0,6)

limmax = 2*deltaF*Npart #400-25
print(limmax,limmaxMHz)
#hxform.GetXaxis().SetLimits(0,limmax)
nbins = residuals5param.GetSize() - 2
hxform.SetBins(Npart,0,limmaxMHz)
hxform.GetXaxis().SetRangeUser(0,limmaxMHz/2)
#hxform.GetXaxis().SetRangeUser(0,1.4)

residuals5paramXform = hxform.Clone()

#c2.SetLogy()
c2.Draw()
c2.Print("./images/"+prodString+"/"+prodString+"_5ParamResiduals.png")
c2.Print("./images/"+prodString+"/"+prodString+"_5ParamResiduals.root")
# Out:
# 4700
# 3828 [(30.010638297872337, 410.61681395114283), (30.159574468085104, 168.27303710691922), (30.30851063829787, 574.7448753342796), (30.457446808510635, 99.99942906461365), (30.606382978723403, 126.41359910701794)]
# 3828 569.9787234042552 29.93618966628871 599.9149130705439
# 0.1488972631672558 0.0017544514539549819
# 13.43208033147934 6.71604016573967
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_5ParamResiduals.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_5ParamResiduals.root has been created

# %% [markdown]
# Lets fit some of these peaks, see if we can isolate the exact frequencies

# %% [raw]
# def peak_fit_bw(x, p):
#     return p[0]*r.TMath.BreitWigner(x[0],p[1],p[2]) + p[3]
#
# func1 = r.TF1("peak1", peak_fit_bw, .39,.45,4)
# func1.SetParNames('A','Mean','#gamma','+ C')
# func1.SetParameters(1,.4,.1,0)
# func1.SetParLimits(1,.4,.45)
# func1.SetLineColor(2)
# func1.SetNpx(1000)
#
# func2 = r.TF1("peak2", peak_fit_bw, 0.6,0.67,4)
# func2.SetParNames('A','Mean','#gamma','+ C')
# func2.SetParameters(.3,0.64,-1)
# func2.SetParLimits(1,0.63,0.67)
#
# func3 = r.TF1("peak3", peak_fit_bw, 0.15,0.21,4)
# func3.SetParNames('A','Mean','#gamma','+ C')
# func3.SetParameters(.3,0.18,-1)
#
# func4 = r.TF1("peak4", peak_fit_bw,2,2.2,4)
# func4.SetParNames('A','Mean','#gamma','+ C')
# func4.SetParameters(.3,2.1,-1)
# func4.SetParLimits(1,2.0,2.2)
#
# func5 = r.TF1("peak5", peak_fit_bw,2.5,2.55,4)
# func5.SetParNames('A','Mean','#gamma','+ C')
# func5.SetParameters(.3,2.5,-1)
# func5.SetParLimits(1,2.5,2.54)
#
# func6 = r.TF1("peak6", peak_fit_bw,.20,.25,4)
# func6.SetParNames('A','Mean','#gamma','+ C')
# func6.SetParameters(.3,.22,-1)
# func6.SetParLimits(1,.22,.24)

# %% [raw]
# c = r.TCanvas("c","c",1200,400)
# hxform.GetXaxis().SetRangeUser(0,limmaxMHz/2)
# hxform.Draw("HIST P0 L")
#
# for i in range(3):
#     hxform.Fit("peak1","REMBQ")
#     hxform.Fit("peak2","REMBQ")
#     hxform.Fit("peak3","REMBQ")
#     hxform.Fit("peak4","REMBQ")
#     hxform.Fit("peak5","REMBQ")
#     hxform.Fit("peak6","REMBQ")
#
# func1.Draw("SAME")
# func2.Draw("SAME")
# func3.Draw("SAME")
# func4.Draw("SAME")
# func5.Draw("SAME")
# func6.Draw("SAME")
#
# print("Peaks Located at: ")
# print("    ",func3.GetParameter(1), "+/-", func3.GetParError(1),"MHz")
# print("    ",func6.GetParameter(1), "+/-", func6.GetParError(1),"MHz")
# print("    ",func1.GetParameter(1), "+/-", func1.GetParError(1),"MHz")
# print("    ",func2.GetParameter(1), "+/-", func2.GetParError(1),"MHz")
# print("    ",func4.GetParameter(1), "+/-", func4.GetParError(1),"MHz")
# print("    ",func5.GetParameter(1), "+/-", func5.GetParError(1),"MHz")
#
# pt = r.TPaveText(2.0,50,3.7,96)
# pt.AddText("Peaks Located at: ")
# pt.AddText("    "+str(func3.GetParameter(1))+" +/- "+str(func3.GetParError(1))+" MHz")
# pt.AddText("    "+str(func6.GetParameter(1))+" +/- "+str(func6.GetParError(1))+" MHz")
# pt.AddText("    "+str(func1.GetParameter(1))+" +/- "+str(func1.GetParError(1))+" MHz")
# pt.AddText("    "+str(func2.GetParameter(1))+" +/- "+str(func2.GetParError(1))+" MHz")
# pt.AddText("    "+str(func4.GetParameter(1))+" +/- "+str(func4.GetParError(1))+" MHz")
# pt.AddText("    "+str(func5.GetParameter(1))+" +/- "+str(func5.GetParError(1))+" MHz")
# pt.Draw()
#
# c.Draw()
# c.SetGrid()
# c.Print("./images/"+prodString+"/"+prodString+"_5ParamResiduals_WithFits.png")
# c.Print("./images/"+prodString+"/"+prodString+"_5ParamResiduals_WithFits.root")

# %% [markdown]
# double check the root fft result with the python fft module

# %%
fig, ax = plt.subplots(figsize=(12, 5))
plt.plot([0]+welchVec+[0],label='Square (No Window)')
plt.title("Plot of the Window Function used")
plt.xlabel("Entries")
plt.legend()
plt.show()

ding = np.fft.fft(np.array(bins))

n = len(bins)
d = (centers[1] - centers[0])*math.pow(10.0,-6)

freq = np.fft.fftfreq(n, d)


fig, ax = plt.subplots(figsize=(12, 5))
plt.plot([x/(10**6) for x in freq],np.abs(ding),'.:',label='FFT 5-param')
plt.title("FFT Using Python")
plt.xlabel("Frequency [MHz]")
plt.xlim(0,6.7157787731503555 / 2)# *10.**6)
plt.legend()
plt.show()

# %%
print(len(residVec),[residVec[i] for i in range(5)])
centers, bins = zip(*residVec)
htest = r.TH1D("htest","htest",len(residVec),centers[0],centers[len(residVec)-1])
for i,ding in enumerate(bins):
    htest.SetBinContent(i, ding)
    
c = r.TCanvas()
htest.Draw()
c.Draw()
c.Print("hi.root")
# Out:
# 3828 [(30.010638297872337, 410.61681395114283), (30.159574468085104, 168.27303710691922), (30.30851063829787, 574.7448753342796), (30.457446808510635, 99.99942906461365), (30.606382978723403, 126.41359910701794)]
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: htest (Potential memory leak).
# Info in <TCanvas::SaveAs>: ROOT file hi.root has been created

# %% [markdown]
# ### 13 parameter fit

# %%
def blinded_wiggle_cbo(x, p):
    norm     = p[0]
    life     = p[1]
    asym     = p[2]
    R        = p[3]
    phi      = p[4]
    A1       = p[5]
    A2       = p[6]
    A3       = p[7]
    lifeCBO  = p[8]
    omegaCBO = p[9]
    phiCBO1  = p[10]
    phiCBO2  = p[11]
    phiCBO3  = p[12]
    
    time  = x[0]
    omega = getBlinded.paramToFreq(R)
    
    cCBO = 1-math.exp(-time/lifeCBO)*A1*math.cos(omegaCBO*time + phiCBO1)
    ACBO = asym * (1 - math.exp(-time/lifeCBO) * A2 * math.cos(omegaCBO*time + phiCBO2))
    phiCBO = phi + math.exp(-time/lifeCBO)*A3*math.cos(omegaCBO*time + phiCBO3)
    
    return norm * math.exp(-time/life) * cCBO * (1 - ACBO*math.cos(omega*time + phiCBO))

# %%
func13 = r.TF1("func13", blinded_wiggle_cbo, 30,500,13)
func13.SetParNames('N','#tau','A',
                   'R','#phi','A_{1}',
                   'A_{2}','A_{3}','#tau_{CBO}',
                   '#omega_{CBO}','#phi_{CBO - 1}')
func13.SetParName(11,'#phi_{CBO - 2}')
func13.SetParName(12,'#phi_{CBO - 3}')
#func13.SetParLimits(4,-6.3,6.3) #Phases should be restricted to +/- 2Pi
#func13.SetParLimits(8,100,500) #Avoid divide by 0 error
func13.SetParLimits(8,0.0000001,100000000) #Avoid divide by 0 error
#func13.SetParLimits(10,-6.3,6.3) 
#func13.SetParLimits(11,-6.3,6.3)
#func13.SetParLimits(12,-6.3,6.3)

#initial guesses, then updated with the first round of fit results
#func13.SetParameters(1500,64.4,0.4,0,0,1,1,1,.01,.01,0)
#func13.SetParameter(11,0)
#func13.SetParameter(12,0)
func13.SetParameters(100000, 64.32689658986958, -0.41149191856871803, 
                     -11.31981267111425, -4.201648334505292, -0.666502391530784, 
                     0.6927259503578, -0.38908021438317, 220, 
                     4.1, 0.4745581246420292)
func13.SetParameter(11, 6.299934663288357)
func13.SetParameter(12, 0.28579778778899545)
for i in range(4):
    func13.SetParameter(i, func.GetParameter(i))
#func13.FixParameter(12,0) #currently this parameter is fixed, as it doesn't behave well if left to wander on its own


func13.SetLineColor(2)
func13.SetNpx(2000)

# %%
c2 = r.TCanvas("c2","c2",1200,800)
c2.Divide(2,1)
c2.cd(1)
r.gPad.SetLogy()

r.gStyle.SetOptFit(111)
allCaloWiggle13 = f.Get("farline").Get("allCaloWiggle").Clone()

allCaloWiggle13.GetXaxis().SetLimits(allCaloWiggle13.GetXaxis().GetXmin() / 1000 * 1.25,
                                     allCaloWiggle13.GetXaxis().GetXmax() / 1000 * 1.25)
allCaloWiggle13.GetXaxis().SetTitle("Time [#mus]")

residuals13 = allCaloWiggle13.Clone() # this will be filled with the fit residuals later

for i in range(2): #the fit won't converge the first time. Don't look at me like that!
    print("Starting Fit:",i+1)
    allCaloWiggle13.Fit("func13","REMB")

allCaloWiggle13.Draw()

c2.cd(2)
ding13 =  allCaloWiggle13.Clone()
ding13.GetXaxis().SetRangeUser(100,125)
ding13.Draw()

r.gPad.SetLogy()
c2.Draw()
# Out:
# Starting Fit: 1
# Starting Fit: 2
#  FUNCTION MUST BE MINIMIZED BEFORE CALLING MINOs
#  NEW MINIMUM FOUND.  GO BACK TO MINIMIZATION STEP.
#  =================================================
#                                                   V
#                                                   V
#                                                   V
#                                                VVVVVVV
#                                                 VVVVV
#                                                  VVV
#                                                   V
#
#  NEW MINIMUM FOUND.  GO BACK TO MINIMIZATION STEP.
#  =================================================
#                                                   V
#                                                   V
#                                                   V
#                                                VVVVVVV
#                                                 VVVVV
#                                                  VVV
#                                                   V
#
#  FUNCTION MUST BE MINIMIZED BEFORE CALLING MINOs
#  NEW MINIMUM FOUND.  GO BACK TO MINIMIZATION STEP.
#  =================================================
#                                                   V
#                                                   V
#                                                   V
#                                                VVVVVVV
#                                                 VVVVV
#                                                  VVV
#                                                   V
#
#  FUNCTION MUST BE MINIMIZED BEFORE CALLING MINOs
#  FUNCTION MUST BE MINIMIZED BEFORE CALLING MINOs
#  FUNCTION MUST BE MINIMIZED BEFORE CALLING MINOs
#  FCN=3.55534e+08 FROM MINOS     STATUS=PROBLEMS        0 CALLS       23270 TOTAL
#                      EDM=8.43142e+19    STRATEGY= 1  ERROR MATRIX UNCERTAINTY 100.0 per cent
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  N            3.81541e+03   1.10382e+00   1.01627e+01  -5.11212e+01
#    2  #tau        -1.60347e+35   4.00000e+00  -0.00000e+00   0.00000e+00
#    3  A            3.79184e-04   1.01105e-05  -0.00000e+00   3.50544e+07
#    4  R            1.09036e+32   1.41421e+00  -0.00000e+00   4.30290e-23
#    5  #phi         2.01927e+36   1.41421e+00  -0.00000e+00   5.87276e-28
#    6  A_{1}        2.43560e-02   4.07000e-04   0.00000e+00  -2.14247e+06
#    7  A_{2}        5.69894e+01   1.51835e+00  -0.00000e+00   2.30575e+02
#    8  A_{3}       -1.13138e+35   1.41421e+00  -0.00000e+00   1.00615e-25
#    9  #tau_{CBO}   4.51423e+05   6.76001e+07   0.00000e+00  -6.49285e+09
#   10  #omega_{CBO}  -4.40463e+40   8.91863e+31  -0.00000e+00   3.87484e-31
#   11  #phi_{CBO - 1}  -1.68895e+36   3.73039e+27  -0.00000e+00   3.66819e-26
#   12  #phi_{CBO - 2}   2.93288e+36   1.41421e+00  -0.00000e+00   8.58388e-27
#   13  #phi_{CBO - 3}   8.27661e+40   1.41421e+00   1.41421e+00   1.05176e-31
#  FCN=2.27335e+07 FROM MIGRAD    STATUS=CALL LIMIT   3149 CALLS        3150 TOTAL
#                      EDM=147.237    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  N            1.24443e+06   3.31008e+00   1.88090e+01  -4.13455e+00
#    2  #tau         6.50571e+01   2.00533e-03   2.36290e-03   1.44101e+03
#    3  A            3.94275e-02   5.68305e-05   2.71119e-04   2.37010e+06
#    4  R            2.32643e+02   4.11063e+00  -7.36507e+00  -1.82115e+00
#    5  #phi        -7.40343e+00   6.77945e-04   6.86117e-04  -8.87163e+03
#    6  A_{1}        5.77060e-03   7.47681e-05   8.41062e-04  -7.89654e+03
#    7  A_{2}        7.67259e+00   1.15067e-02  -5.95952e-04   3.04385e+03
#    8  A_{3}        4.56976e+01   1.21649e-03  -1.44597e-03   2.16183e+03
#    9  #tau_{CBO}   2.05657e+04   5.18794e+01   1.83705e-04  -2.71229e+06
#   10  #omega_{CBO}   3.92437e+00   1.49509e-07   1.22173e-07   3.81583e+07
#   11  #phi_{CBO - 1}  -8.63926e+00   1.11629e-02   6.67360e-02  -1.21154e+03
#   12  #phi_{CBO - 2}  -9.71006e-01   3.64542e-04   6.49550e-04   3.01901e+04
#   13  #phi_{CBO - 3}  -5.66103e+00   1.62236e-05  -1.18941e-05   4.46424e+05
# Warning in <Fit>: Abnormal termination of minimization.

# %%
#The class calculates the  difference between the histogram and the fit function at each point 
#    and divides it by the uncertainty.
c3 = r.TCanvas("c","c",1600,600)
allCaloWiggle13.Draw()
c3.SetLogy()
c3.Draw()

rp13 = r.TRatioPlot(allCaloWiggle13)
rp13.Draw()
rp13.GetLowerRefYaxis().SetTitle("Residual")
rp13.GetLowerRefYaxis().SetRangeUser(-5,5)

allCaloWiggle13.GetXaxis().SetRangeUser(30,150)

c3.Update()
c3.Draw()
c3.Print("./images/"+prodString+"/"+prodString+"_TmethodWiggleFitAllCalos_13Parameter.png")
c3.Print("./images/"+prodString+"/"+prodString+"_TmethodWiggleFitAllCalos_13Parameter.root")

# %% [markdown]
# ### Fourier xform of the residuals from the 13 parameter fit

# %%
c3 = r.TCanvas()
residuals13param = residuals13.Clone() # this will hold the residials from the 5-parameter fit
nBins = residuals13param.GetSize() - 2 #total number of bins excluding over/underflow
print(nBins)
for i in range(nBins):
    binCenterX = allCaloWiggle13.GetXaxis().GetBinCenter(i)
    if (binCenterX > 30):
        residuals13param.SetBinContent(i, allCaloWiggle13.GetBinContent(i) - func13.Eval(binCenterX))
    else:
        residuals13param.SetBinContent(i, 0)

residuals13param.Draw()
residuals13param.GetXaxis().SetRangeUser(30,350)
residuals13param.SetTitle("Residuals of the 13-parameter Fit")
c3.Draw()

print(residuals13param.GetBinWidth(2), "wide")

hxform = r.TH1D()
hxform = 0
r.TVirtualFFT.SetTransform(0)
hxform = residuals13param.FFT(hxform,"MAG P")
hxform.SetTitle("Magnitude of the First Transform (13 Parameter Residuals)")
#NOTE: for "real" frequencies you have to divide the x-axes range with the range of your function
#    y-axes has to be rescaled by a factor of 1/SQRT(n) to be right: this is not done automatically!
normXform = hxform.GetEntries()
hxform.Scale(1/normXform)
c2 = r.TCanvas()
c2.cd()
#c2.SetLogy()
hxform.GetXaxis().SetTitle("Frequency (MHz)")
hxform.GetYaxis().SetTitle("Arb. Units")
hxform.Draw("HIST P0 L")
c2.Draw()

Npart = residuals13param.GetSize() - 2
minBinCenter = residuals13param.GetXaxis().GetBinCenter(0)
maxBinCenter = residuals13param.GetXaxis().GetBinCenter(Npart)

capT = maxBinCenter - minBinCenter
print(Npart, capT, minBinCenter, maxBinCenter)
deltaT = capT/Npart #microseconds
deltaF = 1/capT
print(deltaT, deltaF)

deltaTns = deltaT*1000 #nanoseconds
limmaxHz = (1/(deltaTns*math.pow(10.0,-9)))
limmaxMHz = limmaxHz / math.pow(10,6)

limmax = 2*deltaF*Npart #400-25
print(limmax,limmaxMHz)
nbins = residuals13param.GetSize() - 2
hxform.SetBins(Npart,0,limmaxMHz)
hxform.GetXaxis().SetRangeUser(0,limmaxMHz/2)

c2.Draw()
c2.Print("./images/"+prodString+"/"+prodString+"_13ParamResiduals.png")
c2.Print("./images/"+prodString+"/"+prodString+"_13ParamResiduals.root")

# %% [markdown]
# ### Comaprison of the 5 and 13 parameter fit residual FFT's

# %%
c5 = r.TCanvas("c5","c5",1200,800)
c5.Divide(1,2)
c5.cd(1)
#r.gPad.SetLogy()
r.gPad.SetGrid()

residuals5paramXform.SetLineColor(9)
residuals5paramXform.SetMarkerColor(9)
residuals5paramXform.Draw("HIST P0 L")
residuals5paramXform.GetYaxis().SetRangeUser(0.1,75)
c5.cd(2)
#r.gPad.SetLogy()
r.gPad.SetGrid()
hxform.Draw("HIST P0 L")
hxform.GetYaxis().SetRangeUser(0.1,75)

residuals13paramXform = hxform.Clone()

c5.Draw()

c6 = r.TCanvas("c6","c6",1200,400)
residuals5paramXform.Draw("HIST P0 L")
hxform.SetLineColor(2)
hxform.SetMarkerColor(2)
hxform.Draw("HIST P0 L SAME")
leg = r.TLegend(0.65,0.8,0.9,0.9)
leg.AddEntry(residuals5paramXform ,"5-Parameter Residuals FFT", "l")
leg.AddEntry(hxform ,"13-Parameter Residuals FFT", "l")
leg.Draw()
c6.SetGrid()
c6.Draw()

c6.Print("./images/"+prodString+"/"+prodString+"_ResidualComparison5_13.png")
c6.Print("./images/"+prodString+"/"+prodString+"_ResidualComparison5_13.root")

# %%
parameters13 = []
for i in range(13):
    parameters13.append( (func13.GetParameter(i) , func13.GetParError(i)) )
#print(parameters13)
par13,parErr13 = zip(*parameters13)
print(par13)

# %% [markdown]
# ---
#
# ### Now lets add in the veritcal waist term

# %%
def blinded_wiggle_cbo_vw(x, p):
    norm     = p[0]
    life     = p[1]
    asym     = p[2]
    R        = p[3]
    phi      = p[4]
    A1       = p[5]
    A2       = p[6]
    A3       = p[7]
    lifeCBO  = p[8]
    omegaCBO = p[9]
    phiCBO1  = p[10]
    phiCBO2  = p[11]
    phiCBO3  = p[12]
    Avw      = p[13]
    lifeVW   = p[14]
    omegaVW  = p[15]
    phiVW    = p[16]
    
    time  = x[0]
    omega = getBlinded.paramToFreq(R)
    
    cCBO = 1-math.exp(-time/lifeCBO)*A1*math.cos(omegaCBO*time + phiCBO1)
    ACBO = asym * (1 - math.exp(-time/lifeCBO) * A2 * math.cos(omegaCBO*time + phiCBO2))
    phiCBO = phi + math.exp(-time/lifeCBO)*A3*math.cos(omegaCBO*time + phiCBO3)
    cVW = 1 - Avw*math.exp(-time/lifeVW)*math.cos(omegaVW*time + phiVW)
    
    return norm * math.exp(-time/life) * cCBO * cVW * (1 - ACBO*math.cos(omega*time + phiCBO))

# %%
func17 = r.TF1("func17", blinded_wiggle_cbo_vw, 30,650,17)
func17.SetParNames('N','#tau','A',
                   'R','#phi','A_{1}',
                   'A_{2}','A_{3}','#tau_{CBO}',
                   '#omega_{CBO}','#phi_{CBO - 1}')
func17.SetParName(11,'#phi_{CBO - 2}')
func17.SetParName(12,'#phi_{CBO - 3}')
func17.SetParName(13,'A_{VW}')
func17.SetParName(14,'#tau_{VW}')
func17.SetParName(15,'#omega_{VW}')
func17.SetParName(16,'#phi_{VW}')
func17.SetParLimits(8,0.0000001,100000000) #Avoid divide by 0 error
func17.SetParLimits(14,0.0000001,100000000) #Avoid divide by 0 error
#func17.SetParLimits(10,-6.3,6.3) 
#func17.SetParLimits(11,-6.3,6.3)
#func17.SetParLimits(12,-6.3,6.3)

#initial guesses, then updated with the first round of fit results
for i in range(13):
    func17.SetParameter(i, func13.GetParameter(i))
func17.SetParameter(13, 1)
func17.SetParameter(14, 24)
func17.SetParameter(15, 14.41)
func17.SetParameter(16, 0)

func17.SetParameter(9, 2.307 ) #omega_cbo


func17.SetLineColor(4)
func17.SetNpx(2000)

# %%
c2 = r.TCanvas("c2","c2",1200,800)
c2.Divide(2,1)
c2.cd(1)
r.gPad.SetLogy()

r.gStyle.SetOptFit(111)
allCaloWiggle17 = f.Get("farline").Get("allCaloWiggle").Clone()

allCaloWiggle17.GetXaxis().SetLimits(allCaloWiggle17.GetXaxis().GetXmin() / 1000 * 1.25,
                                     allCaloWiggle17.GetXaxis().GetXmax() / 1000 * 1.25)
allCaloWiggle17.GetXaxis().SetTitle("Time [#mus]")

residuals17 = allCaloWiggle17.Clone() # this will be filled with the fit residuals later

for i in range(2): #the fit won't converge the first time. Don't look at me like that!
    print("Starting Fit:",i+1)
    allCaloWiggle17.Fit("func17","REMB")
    

allCaloWiggle17.Draw()

c2.cd(2)
ding17 =  allCaloWiggle17.Clone()
ding17.GetXaxis().SetRangeUser(100,125)
ding17.Draw()

r.gPad.SetLogy()
c2.Draw()

# %%
#The class calculates the  difference between the histogram and the fit function at each point 
#    and divides it by the uncertainty.
c3 = r.TCanvas("c","c",1600,600)
allCaloWiggle17.Draw()
c3.SetLogy()
c3.Draw()

rp17 = r.TRatioPlot(allCaloWiggle17)
rp17.Draw()
rp17.GetLowerRefYaxis().SetTitle("Residual")
rp17.GetLowerRefYaxis().SetRangeUser(-5,5)

allCaloWiggle17.GetXaxis().SetRangeUser(30,150)

c3.Update()
c3.Draw()
c3.Print("./images/"+prodString+"/"+prodString+"_TmethodWiggleFitAllCalos_17Parameter.png")
c3.Print("./images/"+prodString+"/"+prodString+"_TmethodWiggleFitAllCalos_17Parameter.root")

# %%
for i in range(17):
    print(func17.GetParName(i), " = ", func17.GetParameter(i), "+/-", func17.GetParError(i))

# %% [markdown]
# ### Fourier xform of the residuals from the 17 parameter fit

# %%
c3 = r.TCanvas()
residuals17param = residuals17.Clone() # this will hold the residials from the 5-parameter fit
nBins = residuals17param.GetSize() - 2 #total number of bins excluding over/underflow
print(nBins)
for i in range(nBins):
    binCenterX = allCaloWiggle17.GetXaxis().GetBinCenter(i)
    if (binCenterX > 30):
        residuals17param.SetBinContent(i, allCaloWiggle17.GetBinContent(i) - func17.Eval(binCenterX))
    else:
        residuals17param.SetBinContent(i, 0)

residuals17param.Draw()
residuals17param.GetXaxis().SetRangeUser(30,350)
residuals17param.SetTitle("Residuals of the 17-parameter Fit")
c3.Draw()

print(residuals17param.GetBinWidth(2), "wide")

hxform = r.TH1D()
hxform = 0
r.TVirtualFFT.SetTransform(0)
hxform = residuals17param.FFT(hxform,"MAG P")
hxform.SetTitle("Magnitude of the First Transform (17 Parameter Residuals)")
#NOTE: for "real" frequencies you have to divide the x-axes range with the range of your function
#    y-axes has to be rescaled by a factor of 1/SQRT(n) to be right: this is not done automatically!
normXform = hxform.GetEntries()
hxform.Scale(1/normXform)
c2 = r.TCanvas()
c2.cd()
#c2.SetLogy()
hxform.GetXaxis().SetTitle("Frequency (MHz)")
hxform.GetYaxis().SetTitle("Arb. Units")
hxform.Draw("HIST P0 L")
c2.Draw()

Npart = residuals17param.GetSize() - 2
minBinCenter = residuals17param.GetXaxis().GetBinCenter(0)
maxBinCenter = residuals17param.GetXaxis().GetBinCenter(Npart)

capT = maxBinCenter - minBinCenter
print(Npart, capT, minBinCenter, maxBinCenter)
deltaT = capT/Npart #microseconds
deltaF = 1/capT
print(deltaT, deltaF)

deltaTns = deltaT*1000 #nanoseconds
limmaxHz = (1/(deltaTns*math.pow(10.0,-9)))
limmaxMHz = limmaxHz / math.pow(10,6)

limmax = 2*deltaF*Npart #400-25
print(limmax,limmaxMHz)
nbins = residuals17param.GetSize() - 2
hxform.SetBins(Npart,0,limmaxMHz)
hxform.GetXaxis().SetRangeUser(0,limmaxMHz/2)
residuals17paramXform = hxform.Clone()

c2.Draw()
c2.Print("./images/"+prodString+"/"+prodString+"_17ParamResiduals.png")
c2.Print("./images/"+prodString+"/"+prodString+"_17ParamResiduals.root")

# %%
c6 = r.TCanvas("c6","c6",1200,400)
residuals5paramXform.Draw("HIST P0 L")

residuals13paramXform.SetLineColor(2)
residuals13paramXform.SetMarkerColor(2)
residuals13paramXform.Draw("HIST P0 L SAME")

residuals17paramXform.SetLineColor(3)
residuals17paramXform.Draw("HIST P0 L SAME")
leg = r.TLegend(0.65,0.7,0.9,0.9)
leg.AddEntry(residuals5paramXform ,"5-Parameter Residuals FFT", "l")
leg.AddEntry(residuals13paramXform ,"13-Parameter Residuals (CBO Only) FFT", "l")
leg.AddEntry(residuals17paramXform ,"17-Parameter Residuals (CBO+VW) FFT", "l")
leg.Draw()
c6.SetGrid()
c6.Draw()

c6.Print("./images/"+prodString+"/"+prodString+"_ResidualComparison5_13_17.png")
c6.Print("./images/"+prodString+"/"+prodString+"_ResidualComparison5_13_17.root")

# %% [markdown]
# ___
#
# # Now lets make some plots from the individual calorimeters.

# %%
caloNum = 1

wiggleFitParamVec = []
caloiWiggleVec = []
wiggleFitChiSquareVec = []

for caloNum in range(1,25):
    print("Starting Calo", caloNum)
    
    c4 = r.TCanvas("c4","c4",2400,800)
    c4.Divide(4,2)

    c4.cd(1)
    caloiEnergy = f.Get("farline").Get("calo"+str(caloNum)).Get("energy").Clone()
    caloiEnergy.Draw()
    c4.Draw()

    c4.cd(2)
    caloiXtalHits = f.Get("farline").Get("calo"+str(caloNum)).Get("hitPositions").Clone()
    caloiXtalHits.Draw("colz")
    r.gPad.SetLogz()

    c4.cd(3)
    caloiWiggle = f.Get("farline").Get("calo"+str(caloNum)).Get("wiggle").Clone()
    caloiWiggle.GetXaxis().SetRangeUser(30000,300000)
    caloiWiggle.Draw()
    r.gPad.SetLogy()

    caloiWiggle.GetXaxis().SetLimits(caloiWiggle.GetXaxis().GetXmin() / 1000 * 1.25,caloiWiggle.GetXaxis().GetXmax() / 1000 * 1.25)
    caloiWiggle.GetXaxis().SetTitle("Time [#mus]")
    
    for i in range(2):
        caloiWiggle.Fit("func","REMQ")
    
    wiggleFitParamVec.append( ( func.GetParameter(3) , func.GetParError(3) ) )
    wiggleFitChiSquareVec.append( ( func.GetNDF(),
                                  func.GetChisquare(),
                                  func.GetProb() ) )
    caloiWiggleVec.append( caloiWiggle.Clone("calo"+str(caloNum).zfill(2)+" Wiggle Plot") )

    c4.cd(4)
    caloiTimes = f.Get("farline").Get("calo"+str(caloNum)).Get("times").Clone()
    caloiTimes.GetXaxis().SetRangeUser(0,60000)
    caloiTimes.Draw()

    c4.cd(5)
    caloiXtal35Energy = f.Get("farline").Get("calo"+str(caloNum)).Get("xtal35Energy").Clone()
    caloiXtal35Energy.Draw()

    c4.cd(6)
    caloiXtal31Energy = f.Get("farline").Get("calo"+str(caloNum)).Get("xtal31Energy").Clone()
    caloiXtal31Energy.Draw()

    c4.cd(7)
    caloiXtal0Energy = f.Get("farline").Get("calo"+str(caloNum)).Get("xtal0Energy").Clone()
    caloiXtal0Energy.Draw()

    c4.cd(8)
    caloiXtal53Energy = f.Get("farline").Get("calo"+str(caloNum)).Get("xtal53Energy").Clone()
    caloiXtal53Energy.Draw()

    c4.Draw()
    c4.Print("./images/"+prodString+"/"+prodString+"_calo"+str(caloNum).zfill(2)+"_FullSet.png")
    c4.Print("./images/"+prodString+"/"+prodString+"_calo"+str(caloNum).zfill(2)+"_FullSet.root")
# Out:
# Starting Calo 1
# Starting Calo 2
# Starting Calo 3
# Starting Calo 4
# Starting Calo 5
# Starting Calo 6
# Starting Calo 7
# Starting Calo 8
# Starting Calo 9
# Starting Calo 10
# Starting Calo 11
# Starting Calo 12
# Starting Calo 13
# Starting Calo 14
# Starting Calo 15
# Starting Calo 16
# Starting Calo 17
# Starting Calo 18
# Starting Calo 19
# Starting Calo 20
# Starting Calo 21
# Starting Calo 22
# Starting Calo 23
# Starting Calo 24
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo01_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo01_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo02_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo02_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo03_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo03_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo04_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo04_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo05_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo05_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo06_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo06_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo07_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo07_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo08_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo08_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo09_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo09_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo10_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo10_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo11_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo11_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo12_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo12_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo13_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo13_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo14_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo14_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo15_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo15_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo16_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo16_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo17_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo17_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo18_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo18_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo19_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo19_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo20_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo20_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo21_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo21_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo22_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo22_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo23_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo23_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_calo24_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_calo24_FullSet.root has been created

# %%
pars, parErrs = zip(*wiggleFitParamVec)
calos = [x for x in range(1,25)]
plt.errorbar(x=calos,y=pars,yerr=parErrs,ls='none',capsize=3,capthick=1,marker='o',markersize=5)
plt.title(prodString+"\nVariation of R parameter vs. Calo Number for 5-Parameter Fit")
plt.xlabel("Calo Number")
plt.ylabel("R")
plt.show()

# %% [raw]
# This is some pretty worrying variation in the R value, but not entirely unexpected.
#
# We can also look at the rediced chi square for each of the calos.

# %%
ndfs, chisqs, probs = zip(*wiggleFitChiSquareVec)
plt.plot(calos,[x / ndfs[i] for i,x in enumerate(chisqs)],'o:',label='Individual Calos')

ding = [chiSqAll[1]/chiSqAll[0] for i in range(24)]
plt.plot(calos, ding, '-',label="All Calos")

plt.ylabel("$\chi^2$ / NDF")
plt.xlabel("Calorimeter Number")
plt.title(prodString+"\nReduced $\chi^2$ for Individual Calo Wiggle Plots")
plt.legend()
plt.show()
# Out:
# <>:7: DeprecationWarning: invalid escape sequence \c

# %% [raw]
# Now lets implement some of Kim's suggestions, starting with:
#     "FFT of raw wiggle plot, FFT of residual of 5-par-fit, for each calo"
#
# Why? Because it's easiest.

# %%
print(caloiWiggleVec)
caloiResidVec = []

for i in range(24):
    caloNum = i+1
    c = r.TCanvas()
    caloiWiggleVec[i].Draw("goff")
    funci = caloiWiggleVec[i].GetFunction("func")
    #c.Draw()
    
#    print("tau = ",funci.GetParameter(1), "for calo", caloNum)
    residuals5paramCaloi = caloiWiggleVec[i].Clone()
    nBins = residuals5paramCaloi.GetSize() - 2
#    print("    ", nbins , "bins" )
    for bini in range(int(nBins) ):
        binCenterX = caloiWiggleVec[i].GetXaxis().GetBinCenter(bini)
        if (binCenterX > 30):
            residuals5paramCaloi.SetBinContent(bini, caloiWiggleVec[i].GetBinContent(bini) - funci.Eval(binCenterX))
        else:
            residuals5paramCaloi.SetBinContent(bini, 0)
            
    residuals5paramCaloi.Draw("HIST P0 L")
#    c.Draw()
    
    hxformRaw = r.TH1D()
    hxformRaw = 0
    r.TVirtualFFT.SetTransform(0)
    hxformRaw = caloiWiggleVec[i].FFT(hxform,"MAG P")
    hxformRaw.SetTitle("Magnitude of the First Transform (Raw Wiggle) for Calo "+str(caloNum))
    #NOTE: for "real" frequencies you have to divide the x-axes range with the range of your function
    #    y-axes has to be rescaled by a factor of 1/SQRT(n) to be right: this is not done automatically!
    normXform = hxformRaw.GetEntries()
    hxformRaw.Scale(1/normXform)
    c2 = r.TCanvas()
    c2.cd()
    #c2.SetLogy()
    hxformRaw.GetXaxis().SetTitle("Frequency (MHz)")
    hxformRaw.GetYaxis().SetTitle("Arb. Units")
    hxformRaw.Draw("HIST P0 L")
#    c2.Draw()
    
    hxform = r.TH1D()
    hxform = 0
    r.TVirtualFFT.SetTransform(0)
    hxform = residuals5paramCaloi.FFT(hxform,"MAG P")
    hxform.SetTitle("Magnitude of the First Transform (5 Parameter Residuals) for Calo "+str(caloNum))
    #NOTE: for "real" frequencies you have to divide the x-axes range with the range of your function
    #    y-axes has to be rescaled by a factor of 1/SQRT(n) to be right: this is not done automatically!
    normXform = hxform.GetEntries()
    hxform.Scale(1/normXform)
    c2 = r.TCanvas()
    c2.cd()
    #c2.SetLogy()
    hxform.GetXaxis().SetTitle("Frequency (MHz)")
    hxform.GetYaxis().SetTitle("Arb. Units")
    hxform.Draw("HIST P0 L")
#    c2.Draw()

    Npart = residuals5paramCaloi.GetSize() - 2
    minBinCenter = residuals5paramCaloi.GetXaxis().GetBinCenter(0)
    maxBinCenter = residuals5paramCaloi.GetXaxis().GetBinCenter(Npart)

    capT = maxBinCenter - minBinCenter
#    print(Npart, capT, minBinCenter, maxBinCenter)
    deltaT = capT/Npart #microseconds
    deltaF = 1/capT
#    print(deltaT, deltaF)

    deltaTns = deltaT*1000 #nanoseconds
    limmaxHz = (1/(deltaTns*math.pow(10.0,-9)))
    limmaxMHz = limmaxHz / math.pow(10,6)

    limmax = 2*deltaF*Npart #400-25
#    print(limmax,limmaxMHz)
    nbins = residuals5paramCaloi.GetSize() - 2
    hxform.SetBins(Npart,0,limmaxMHz)
    hxform.GetXaxis().SetRangeUser(0,limmaxMHz/2)
    caloiResidVec.append( hxform.Clone() )
    
    hxformRaw.SetBins(Npart,0,limmaxMHz)
    hxformRaw.GetXaxis().SetRangeUser(0,limmaxMHz/2)
    
    caloiWiggleVec[i].GetXaxis().SetRangeUser(0,700)
    residuals5paramCaloi.GetXaxis().SetRangeUser(0,700)
    
    c3 = r.TCanvas("c3","c3",1200,1200)
    c3.Divide(2,2)
    c3.cd(1)
    caloiWiggleVec[i].Draw()
    r.gPad.SetLogy()    
    c3.cd(2)
    r.gPad.SetLogy()    
    hxformRaw.Draw("HIST P0 L")
    c3.cd(3)
    residuals5paramCaloi.SetTitle("5 Parameter Residuals Calo"+str(caloNum))
    residuals5paramCaloi.Draw("HIST P0 L")
    c3.cd(4)
    r.gPad.SetLogy()    
    hxform.Draw("HIST P0 L")
    c3.Draw()
    c3.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_Calo"+str(caloNum).zfill(2)+".png")
    c3.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_Calo"+str(caloNum).zfill(2)+".root")
# Out:
# [<ROOT.TH1D object ("calo01 Wiggle Plot") at 0x7ffffd26e180>, <ROOT.TH1D object ("calo02 Wiggle Plot") at 0x7ffffe4e6e00>, <ROOT.TH1D object ("calo03 Wiggle Plot") at 0x7ffffd97a870>, <ROOT.TH1D object ("calo04 Wiggle Plot") at 0x7ffffd956020>, <ROOT.TH1D object ("calo05 Wiggle Plot") at 0x7fbc60451230>, <ROOT.TH1D object ("calo06 Wiggle Plot") at 0x7fbc5347a4c0>, <ROOT.TH1D object ("calo07 Wiggle Plot") at 0x7ffffdbb32e0>, <ROOT.TH1D object ("calo08 Wiggle Plot") at 0x7fbc53ff4860>, <ROOT.TH1D object ("calo09 Wiggle Plot") at 0x7ffffdbb54b0>, <ROOT.TH1D object ("calo10 Wiggle Plot") at 0x7fbc52351fe0>, <ROOT.TH1D object ("calo11 Wiggle Plot") at 0x7ffffdc14d70>, <ROOT.TH1D object ("calo12 Wiggle Plot") at 0x7fbc52bd0610>, <ROOT.TH1D object ("calo13 Wiggle Plot") at 0x7ffffdc0e210>, <ROOT.TH1D object ("calo14 Wiggle Plot") at 0x7fbc517aba50>, <ROOT.TH1D object ("calo15 Wiggle Plot") at 0x7ffffdc53a90>, <ROOT.TH1D object ("calo16 Wiggle Plot") at 0x7ffffdc4eec0>, <ROOT.TH1D object ("calo17 Wiggle Plot") at 0x7fbc5069b010>, <ROOT.TH1D object ("calo18 Wiggle Plot") at 0x7fbc5067f1d0>, <ROOT.TH1D object ("calo19 Wiggle Plot") at 0x7ffffdc99960>, <ROOT.TH1D object ("calo20 Wiggle Plot") at 0x7fbc4fe237b0>, <ROOT.TH1D object ("calo21 Wiggle Plot") at 0x7fbc4fe1bad0>, <ROOT.TH1D object ("calo22 Wiggle Plot") at 0x7ffffdcfa5f0>, <ROOT.TH1D object ("calo23 Wiggle Plot") at 0x7ffffdceb250>, <ROOT.TH1D object ("calo24 Wiggle Plot") at 0x7fbc4e45d470>]
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo01.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo01.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo02.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo02.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo03.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo03.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo04.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo04.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo05.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo05.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo06.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo06.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo07.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo07.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo08.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo08.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo09.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo09.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo10.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo10.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo11.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo11.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo12.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo12.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo13.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo13.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo14.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo14.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo15.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo15.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo16.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo16.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo17.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo17.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo18.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo18.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo19.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo19.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo20.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo20.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo21.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo21.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo22.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo22.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo23.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo23.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo24.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_Calo24.root has been created

# %%
c6 = r.TCanvas("c6","c6",1200,500)
leg = r.TLegend(0.65,0.65,0.9,0.9)
c6.cd()
for i, hist in enumerate(caloiResidVec):
    hist.SetLineColor(i+1)
    if(i>3):
        hist.SetLineColor(i+2)
    if(i>6):
        hist.SetLineStyle(2)
    if(i>7):
        hist.SetLineColor(i+40-12)
    if (i < 0.9):
        hist.SetTitle("Magnitude of the First Transform (5-Parameter Residuals) for Calos 1 - 24")
        hist.Draw("HIST P0 L")
    else:
        hist.Draw("HIST P0 L SAME")
    leg.AddEntry(hist ,"Calo "+str(i+1)+" FFT", "l")

leg.SetNColumns(3)
leg.Draw()
c6.Draw()
c6.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_all.root")
c6.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_all.png")

c7 = r.TCanvas("c7","c7",1200,500)
hsum = caloiResidVec[0].Clone()
for i in range(1,24):
    hsum.Add(caloiResidVec[i])
hsum.SetTitle("Sum of the Magnitude of the First Transform (5-Parameter Residuals) for Calos 1 - 24")
hsum.Draw("HIST P0 L")
c7.Draw()
c7.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_allSum.root")
c7.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_allSum.png")
# Out:
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_all.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_all.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_allSum.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_allSum.png has been created

# %% [markdown]
# Now lets compare the 5-parameter residuals from the 24 calos to those from the total.

# %%
c = r.TCanvas("c","c",1200,500)
leg = r.TLegend(0.65,0.8,0.9,0.9)

hsum.Draw("HIST P0 L")
hsum.GetYaxis().SetRangeUser(0.1,1000)
residuals5paramXform.SetLineColor(2)
residuals5paramXform.SetMarkerColor(2)
residuals5paramXform.Draw("HIST P0 L SAME")

leg.AddEntry(hsum,"Sum of the 24 Calorimeter FFT's",'l')
leg.AddEntry(residuals5paramXform,"FFT of the Total Wiggle Residuals",'l')
leg.Draw()
c.SetLogy()
c.Draw()
c.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_allSum_Comparison.root")
c.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_allSum_Comparison.png")
# Out:
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_allSum_Comparison.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_23_Endgame/v9_23_Endgame_Residual5Param_allSum_Comparison.png has been created

# %% [raw]
# Now we generate the plots which used to be part of f2, but now have been migrated into part of the original file to save time

# %% [raw]
# 1) normalized energy spectrum for different times like what Jason showed in his talk
#     (to catch noise pulses, every 10 T_a ~ 43.7 us will do) (edited)

# %%
for calo in range(1,25): 
    print("Starting calo", calo)
    c3 = r.TCanvas("c3","c3",4500,4500)
    c3.Divide(4,4)

    nDivs = 16
    for div in range(nDivs):
        c3.cd(div+1)
        r.gROOT.SetSelectedPad(r.gPad)
        
        #hi = f2.Get("energySpectrum_calo"+str(calo).zfill(2)+"_div"+str(div))
        hi = f.Get("farline").Get("calo"+str(calo)).Get("calo"+str(calo)+"TimeCut"+str(div)+"Energy")
        int2000_3000 = hi.Integral( hi.FindBin(2000), hi.FindBin(3000) )
        intTotal = hi.Integral()
        if(np.abs(int2000_3000) > 0):
            hi.Scale(1/int2000_3000)
            #hi.Scale(1/intTotal)
            
        hi.GetXaxis().SetRangeUser(0,4000)
        hi.GetYaxis().SetRangeUser(0.001,1)
        hi.SetFillColorAlpha(38,0.5)
        hi.Draw("HIST P0 L")

        r.gPad.SetLogy()
        
    c3.Draw()

    c3.Print("./images/"+prodString+"/"+prodString+"_energySpectrum_calo"+str(calo).zfill(2)+".png")
    c3.Print("./images/"+prodString+"/"+prodString+"_energySpectrum_calo"+str(calo).zfill(2)+".root")
# Out:
# Starting calo 1
# Starting calo 2
# Starting calo 3
# Starting calo 4
# Starting calo 5
# Starting calo 6
# Starting calo 7
# Starting calo 8
# Starting calo 9
# Starting calo 10
# Starting calo 11
# Starting calo 12
# Starting calo 13
# Starting calo 14
# Starting calo 15
# Starting calo 16
# Starting calo 17
# Starting calo 18
# Starting calo 19
# Starting calo 20
# Starting calo 21
# Starting calo 22
# Starting calo 23
# Starting calo 24
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo01.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo01.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo02.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo02.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo03.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo03.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo04.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo04.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo05.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo05.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo06.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo06.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo07.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo07.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo08.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo08.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo09.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo09.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo10.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo10.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo11.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo11.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo12.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo12.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo13.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo13.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo14.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo14.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo15.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo15.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo16.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo16.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo17.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo17.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo18.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo18.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo19.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo19.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo20.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo20.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo21.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo21.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo22.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo22.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo23.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo23.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_energySpectrum_calo24.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_energySpectrum_calo24.root has been created

# %% [raw]
# 2) energy histogram for sync laser pulse cluster for each calo
#     (use time cut, like between 4000-6000 c.t. and energy cut, like > 40 GeV)

# %%
caloStdVec = []

for calo in range(1,25): 
    print("Starting calo", calo)
    c3 = r.TCanvas()

    #hi = f2.Get("laserEnergyPulse_calo"+str(calo).zfill(2))
    hi = f.Get("farline").Get("calo"+str(calo)).Get("laserSyncEnergies")
    hi.GetXaxis().SetTitle("Energy [MeV]")
    hi.Draw("HIST P0 L")
    
    #print("    Mean: ", hi.GetMean(), "and stdev: ", hi.GetStdDev())
    caloStdVec.append((calo, hi.GetMean(), hi.GetStdDev()))
        
    c3.SetLogy()
    c3.Draw()

    c3.Print("./images/"+prodString+"/"+prodString+"_laserEnergyPulse_calo"+str(calo).zfill(2)+".png")
    c3.Print("./images/"+prodString+"/"+prodString+"_laserEnergyPulse_calo"+str(calo).zfill(2)+".root")
    
print(caloStdVec)
# Out:
# Starting calo 1
# Starting calo 2
# Starting calo 3
# Starting calo 4
# Starting calo 5
# Starting calo 6
# Starting calo 7
# Starting calo 8
# Starting calo 9
# Starting calo 10
# Starting calo 11
# Starting calo 12
# Starting calo 13
# Starting calo 14
# Starting calo 15
# Starting calo 16
# Starting calo 17
# Starting calo 18
# Starting calo 19
# Starting calo 20
# Starting calo 21
# Starting calo 22
# Starting calo 23
# Starting calo 24
# [(1, 88423.15132527563, 447.9886411020883), (2, 89715.68026955894, 513.0227283997624), (3, 91596.97411652324, 481.78836133402024), (4, 89473.44521170367, 470.7118210162591), (5, 89913.97146599123, 422.11424296451133), (6, 95348.45950284935, 430.6903576421866), (7, 90614.16520111538, 442.99658011500645), (8, 85786.47075393549, 415.52578446938634), (9, 103454.45284619485, 459.3890830609932), (10, 112720.46849098057, 479.0651513789613), (11, 94043.53713076397, 418.5144342123199), (12, 84495.0180011073, 379.1226256787026), (13, 89733.66122732662, 427.37106147261187), (14, 79751.78738339475, 412.7513052031908), (15, 95780.20212154939, 517.2794991752065), (16, 70878.25048364962, 468.1133023021549), (17, 71334.8893488553, 355.92060402949255), (18, 78187.76495768859, 371.60599319990894), (19, 79059.35761929474, 363.96442876965625), (20, 80430.89816625752, 381.0847998875246), (21, 89170.61598324394, 416.52256312167174), (22, 77209.17298160151, 533.9093870379485), (23, 86674.6506593129, 401.43497781615997), (24, 85268.85822709794, 387.526319903235)]
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo01.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo01.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo02.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo02.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo03.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo03.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo04.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo04.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo05.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo05.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo06.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo06.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo07.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo07.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo08.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo08.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo09.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo09.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo10.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo10.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo11.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo11.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo12.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo12.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo13.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo13.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo14.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo14.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo15.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo15.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo16.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo16.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo17.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo17.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo18.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo18.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo19.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo19.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo20.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo20.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo21.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo21.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo22.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo22.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo23.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo23.root has been created
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_calo24.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_calo24.root has been created

# %%
calos, means, stds = zip(*caloStdVec)

fig, ax = plt.subplots(1,2, figsize=(15,5))
fig.tight_layout()
fig.subplots_adjust(wspace=.25)

ax[1].plot(calos,stds,'o:')
ax[1].set_ylabel("STDEV [MeV]")
ax[1].set_xlabel("Calo Number")
ax[1].set_title("STDEV For Laser Pulses in Various Calorimeters")
ax[1].grid()

ax[0].plot(calos,means,'o:')
ax[0].set_ylabel("Mean [MeV]")
ax[0].set_xlabel("Calo Number")
ax[0].set_title("Mean For Laser Pulses in Various Calorimeters")
ax[0].grid()

plt.savefig("./images/"+prodString+"/"+prodString+"_laserEnergyMeans_allcalo.png", bbox_inches='tight')
plt.show()

# %%
calos, means, stds = zip(*caloStdVec)

fig, ax = plt.subplots(figsize=(7,5))
fig.tight_layout()
#fig.subplots_adjust(wspace=.25)

plt.errorbar(x=calos,y=means,xerr=0,yerr=stds)
plt.ylabel("Mean [MeV]")
plt.xlabel("Calo Number")
plt.title("Mean For Laser Pulses in Various Calorimeters (With Error Bars)")

plt.show()

# %%
c3 = r.TCanvas("c3","c3",1800,1000)
leg = r.TLegend(0.7,0.72,0.9,0.9)
leg.SetNColumns(3)

for calo in range(1,25): 
    print("Starting calo", calo)

    hi.SetLineColor(calo-1)
    hi.SetLineWidth(3)
    if(calo>3):
        hi.SetLineColor(calo+2)
    if(calo>6):
        hi.SetLineStyle(2)
    if(calo>7):
        hi.SetLineColor(calo+40-12)
    
    hi = f.Get("farline").Get("calo"+str(calo)).Get("laserSyncEnergies")
    hi.SetDirectory(0)
    hi.GetXaxis().SetTitle("Energy [MeV]")
    hi.SetTitle("Laser Energy (All Calos)")
    hi.GetXaxis().SetRangeUser(50000,150000)
    if calo < 1.5:
        hi.Draw()
    else:
        hi.Draw("SAME")
        
    leg.AddEntry(hi ,"Calo "+str(calo), "l")

leg.Draw()

c3.SetLogy()
c3.Draw()
c3.Print("./images/"+prodString+"/"+prodString+"_laserEnergyPulse_allcalo.png")
c3.Print("./images/"+prodString+"/"+prodString+"_laserEnergyPulse_allcalo.root")
# Out:
# Starting calo 1
# Starting calo 2
# Starting calo 3
# Starting calo 4
# Starting calo 5
# Starting calo 6
# Starting calo 7
# Starting calo 8
# Starting calo 9
# Starting calo 10
# Starting calo 11
# Starting calo 12
# Starting calo 13
# Starting calo 14
# Starting calo 15
# Starting calo 16
# Starting calo 17
# Starting calo 18
# Starting calo 19
# Starting calo 20
# Starting calo 21
# Starting calo 22
# Starting calo 23
# Starting calo 24
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_laserEnergyPulse_allcalo.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_laserEnergyPulse_allcalo.root has been created

# %%
for calo in range(1,25):
    print("Starting calo", calo)
    c = r.TCanvas("c","c",4500,2000)
    c.Divide(4,2)
    for i in range(8):
        c.cd(i+1)
        hi = f.Get("farline").Get("calo"+str(calo)).Get("calo"+str(calo)+"EnergyCut"+str(i)+"Energy").Clone()
        hi.Rebin2D(1,1)
        hi.GetXaxis().SetTitle("x")
        hi.GetYaxis().SetTitle("y")
        r.gPad.SetLogz()
        r.gPad.SetRightMargin(0.15)
        hi.GetZaxis().SetRangeUser(1,100000)
        hi.Draw("COLZ")
    c.Draw()
    c.Print("./images/"+prodString+"/"+prodString+"_hitDistribution_calo"+str(calo).zfill(2)+".png")
    c.Print("./images/"+prodString+"/"+prodString+"_hitDistribution_calo"+str(calo).zfill(2)+".root")
# Out:
# Starting calo 1
# Starting calo 2
# Starting calo 3
# Starting calo 4
# Starting calo 5
# Starting calo 6
# Starting calo 7
# Starting calo 8
# Starting calo 9
# Starting calo 10
# Starting calo 11
# Starting calo 12
# Starting calo 13
# Starting calo 14
# Starting calo 15
# Starting calo 16
# Starting calo 17
# Starting calo 18
# Starting calo 19
# Starting calo 20
# Starting calo 21
# Starting calo 22
# Starting calo 23
# Starting calo 24
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo01.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo01.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo02.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo02.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo03.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo03.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo04.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo04.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo05.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo05.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo06.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo06.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo07.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo07.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo08.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo08.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo09.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo09.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo10.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo10.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo11.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo11.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo12.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo12.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo13.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo13.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo14.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo14.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo15.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo15.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo16.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo16.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo17.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo17.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo18.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo18.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo19.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo19.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo20.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo20.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo21.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo21.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo22.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo22.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo23.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo23.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/9day_Full/9day_Full_hitDistribution_calo24.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/9day_Full/9day_Full_hitDistribution_calo24.root has been created
