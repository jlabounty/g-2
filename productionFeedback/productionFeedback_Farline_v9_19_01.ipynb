# %%
from standardInclude import *
# Out:
# Welcome to JupyROOT 6.12/06
# For interactive plots, run: setint()
# To return to non-interactive plots (default state), run: noint()

# %% [markdown]
# Using hadd.sh, we merged all of these files together into one output, which we will run through now:

# %%
f = r.TFile("./v9_19_01/results_histOnly_v9_19_01_testDataset.root") #processed output of hadd.sh

#check if the directory where we will be saving the images exists
prodString="v9_19_01"
directory = os.path.dirname("./images/"+prodString+"/")
if not os.path.exists(directory):
    print("Creating Image Directory:", directory)
    os.makedirs(directory)
else:
    print("Image Directory", directory,"exists. Continuing.")
# Out:
# Image Directory ./images/v9_19_01 exists. Continuing.

# %%
f.cd("farline/calo1")
#f.ls()
# Out:
# True

# %% [markdown]
# Print all of the embedded histograms.

# %%
c = r.TCanvas("c","c",1800,1000)
c.Divide(2,2)
c.cd(1)
allCaloEnergies = f.Get("farline").Get("allCaloEnergies").Clone()
allCaloEnergies.Draw()
c.Draw()

c.cd(2)
allCaloWiggle = f.Get("farline").Get("allCaloWiggle").Clone()
allCaloWiggle.Draw()
allCaloWiggle.GetXaxis().SetRange(30,350)

c.cd(3)
allCaloTimes = f.Get("farline").Get("allCaloTimes").Clone()
allCaloTimes.GetXaxis().SetRange(30,350)
allCaloTimes.Draw()

c.cd(4)
farlineCtag = f.Get("farline").Get("farlineCTag").Clone()
farlineCtag.Draw()

c.Draw()
c.Print("./images/"+prodString+"/"+prodString+"_farlineHistograms.png")
c.Print("./images/"+prodString+"/"+prodString+"_farlineHistograms.root")

print("{:,}".format(int(allCaloEnergies.GetEntries())), "Entries in these histograms")
print("{:,}".format(int(allCaloWiggle.GetEntries())), "Entries in these histograms")
print("{:,}".format(int(allCaloTimes.GetEntries())), "Entries in these histograms")
print("{:,}".format(int(farlineCtag.GetEntries())), "Entries in these histograms")
# Out:
# 5,698,086,742 Entries in these histograms
# 1,137,151,501 Entries in these histograms
# 5,698,086,742 Entries in these histograms
# 335,481,397 Entries in these histograms
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_farlineHistograms.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_farlineHistograms.root has been created

# %% [markdown]
# # Now lets make a wiggle plot of all of the calos

# %%
# blinded instance
getBlinded = Blinders(FitType.Omega_a, 'This is my fight song. Blinding my plot song.')
def blinded_wiggle(x, p):
    norm  = p[0]
    life  = p[1]
    asym  = p[2]
    R     = p[3]
    phi   = p[4]
    
    time  = x[0]
    omega = getBlinded.paramToFreq(R)
#    omega = myBlinder.paramToFreq(R) unblind version
    
    return norm * math.exp(-time/life) * (1 - asym*math.cos(omega*time + phi))
# Out:
#  + ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ +
#  +                                                                      +
#  +           You have chose to blind your fitting according to          +
#  +                omega_ref * (1 + (R +/- deltaR) *10^{-6})             +
#  +                                                                      +
#  + ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ +

# %%
func = r.TF1("func", blinded_wiggle, 30,600,5)
func.SetParNames('N','#tau','A','R','#phi')
func.SetParameters(700000,64.4,0.4,0,0)
func.SetParLimits(4,-0.001 - 2*math.pi,2*math.pi+0.001)
func.SetLineColor(2)
func.SetNpx(2000)

# %% [markdown]
# ### Five parameter fit

# %%
c2 = r.TCanvas("c2","c2",1200,800)
c2.Divide(2,1)
c2.cd(1)
r.gPad.SetLogy()

r.gStyle.SetOptFit(111)
allCaloWiggle = f.Get("farline").Get("allCaloWiggle").Clone()

print(allCaloWiggle.GetXaxis().GetXmin(),allCaloWiggle.GetXaxis().GetXmax())
allCaloWiggle.GetXaxis().SetLimits(allCaloWiggle.GetXaxis().GetXmin() / 1000 * 1.25,allCaloWiggle.GetXaxis().GetXmax() / 1000 * 1.25)
print(allCaloWiggle.GetXaxis().GetXmin(),allCaloWiggle.GetXaxis().GetXmax())
allCaloWiggle.GetXaxis().SetTitle("Time [#mus]")

residuals = allCaloWiggle.Clone() # this will be filled with the fit residuals later

for fit in range(2):
    print("Sarting fit:", fit+1)
    allCaloWiggle.Fit("func","REM")

    
chiSqAll = ( ( func.GetNDF(),
              func.GetChisquare(),
              func.GetProb() ) )
    
allCaloWiggle.Draw()

c2.cd(2)
ding =  allCaloWiggle.Clone()
ding.GetXaxis().SetRangeUser(100,125)
ding.Draw()

r.gPad.SetLogy()
c2.Draw()
# Out:
# 0.0 560000.0
# 0.0 700.0
# Sarting fit: 1
# Sarting fit: 2
#  FCN=8510.19 FROM MINOS     STATUS=SUCCESSFUL     36 CALLS         522 TOTAL
#                      EDM=8.60087e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  N            2.05250e+06   1.55972e+02   2.78760e-02   1.45776e-11
#    2  #tau         6.42430e+01   2.75447e-03  -5.31988e-07   4.29665e-06
#    3  A            3.96856e-01   5.62459e-05  -6.22795e-09   5.13373e-05
#    4  R           -1.50917e+01   1.60633e+00   2.25859e-05  -8.70293e-08
#    5  #phi        -1.05098e+00   2.62482e-04   2.62482e-04   3.95317e-03
#  FCN=8510.19 FROM MINOS     STATUS=SUCCESSFUL     36 CALLS         284 TOTAL
#                      EDM=5.1705e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  N            2.05250e+06   1.55971e+02   1.82306e-02   2.15193e-11
#    2  #tau         6.42430e+01   2.75445e-03  -4.59204e-07  -4.97783e-06
#    3  A            3.96856e-01   5.62459e-05  -2.26715e-09   1.54371e-05
#    4  R           -1.50917e+01   1.60633e+00  -3.29632e-05  -7.99687e-08
#    5  #phi        -1.05098e+00   2.62482e-04   2.62482e-04   3.15592e-03
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2

# %%
#The class calculates the  difference between the histogram and the fit function at each point 
#    and divides it by the uncertainty.
c3 = r.TCanvas("c","c",1600,600)
allCaloWiggle.Draw()
c3.SetLogy()
c3.Draw()

rp1 = r.TRatioPlot(allCaloWiggle)
rp1.Draw()
rp1.GetLowerRefYaxis().SetTitle("Residual")
rp1.GetLowerRefYaxis().SetRangeUser(-7,7)

allCaloWiggle.GetXaxis().SetRangeUser(30,150)

c3.Update()
c3.Draw()
c3.Print("./images/"+prodString+"/"+prodString+"_TmethodWiggleFitAllCalos.png")
c3.Print("./images/"+prodString+"/"+prodString+"_TmethodWiggleFitAllCalos.root")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_TmethodWiggleFitAllCalos.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_TmethodWiggleFitAllCalos.root has been created

# %% [markdown]
# ### Fourier transform of the 5-parameter residuals.

# %%
c3 = r.TCanvas()
residuals5param = residuals.Clone() # this will hold the residials from the 5-parameter fit
nBins = residuals5param.GetSize() - 2 #total number of bins excluding over/underflow
print(nBins)
residVec = []
for i in range(nBins):
    binCenterX = allCaloWiggle.GetXaxis().GetBinCenter(i)
    if (binCenterX > 30 and binCenterX < 600):
        residVec.append( (binCenterX, allCaloWiggle.GetBinContent(i) - func.Eval(binCenterX) ) )
        residuals5param.SetBinContent(i, allCaloWiggle.GetBinContent(i) - func.Eval(binCenterX))
    else:
        residuals5param.SetBinContent(i, 0)

print(len(residVec),[residVec[i] for i in range(5)])
centers, bins = zip(*residVec)
htest = r.TH1D("htest","htest",len(residVec),centers[0],centers[len(residVec)-1])
for i,ding in enumerate(bins):
    htest.SetBinContent(i, ding)
    
residuals5param.Delete()
residuals5param = htest
nBins = residuals5param.GetSize() - 2 #total number of bins excluding over/underflow

#apply a windows function to try to get rid of the imaginary peaks
welchVec = []
for i in range(nBins):
    unwindowed = residuals5param.GetBinContent(i)
    welch = 1 #- ( ( i - (nBins - 1) / 2) / ((nBins - 1) / 2) )**2
    welchVec.append(welch)
    residuals5param.SetBinContent(i, unwindowed *  welch)
    
residuals5param.Draw()
residuals5param.GetXaxis().SetRangeUser(30,700)
residuals5param.SetTitle("(Windowed) Residuals of the 5-parameter Fit")
c3.Draw()    
    
hxform = r.TH1D()
hxform = 0
r.TVirtualFFT.SetTransform(0)
hxform = residuals5param.FFT(hxform,"MAG P")
hxform.SetTitle("Magnitude of the First Transform (5-Parameter Residuals)")
#NOTE: for "real" frequencies you have to divide the x-axes range with the range of your function
#    y-axes has to be rescaled by a factor of 1/SQRT(n) to be right: this is not done automatically!
normXform = hxform.GetEntries()
hxform.Scale(1/normXform)
c2 = r.TCanvas()
c2.cd()
#c2.SetLogy()
hxform.GetXaxis().SetTitle("Frequency (MHz)")
hxform.GetYaxis().SetTitle("Arb. Units")
hxform.Draw("HIST P0 L")
c2.Draw()

Npart = residuals5param.GetSize() - 2
minBinCenter = residuals5param.GetXaxis().GetBinCenter(0)
maxBinCenter = residuals5param.GetXaxis().GetBinCenter(Npart)

capT = maxBinCenter - minBinCenter
print(Npart, capT, minBinCenter, maxBinCenter)
deltaT = capT/Npart #microseconds
deltaF = 1/capT
print(deltaT, deltaF)

deltaTns = deltaT*1000 #nanoseconds
limmaxHz = (1/(deltaTns*math.pow(10.0,-9)))
limmaxMHz = limmaxHz / math.pow(10.0,6)

limmax = 2*deltaF*Npart #400-25
print(limmax,limmaxMHz)
#hxform.GetXaxis().SetLimits(0,limmax)
nbins = residuals5param.GetSize() - 2
hxform.SetBins(Npart,0,limmaxMHz)
hxform.GetXaxis().SetRangeUser(0,limmaxMHz/2)
#hxform.GetXaxis().SetRangeUser(0,1.4)

residuals5paramXform = hxform.Clone()

#c2.SetLogy()
c2.Draw()
c2.Print("./images/"+prodString+"/"+prodString+"_5ParamResiduals.png")
c2.Print("./images/"+prodString+"/"+prodString+"_5ParamResiduals.root")
# Out:
# 4700
# 3828 [(30.010638297872337, 10775.347731345799), (30.159574468085104, 5437.6212088267785), (30.30851063829787, 3511.464640905848), (30.457446808510635, 3550.7211409655865), (30.606382978723403, 2762.9034927428)]
# 3828 569.9787234042552 29.93618966628871 599.9149130705439
# 0.1488972631672558 0.0017544514539549819
# 13.43208033147934 6.71604016573967
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: htest (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_5ParamResiduals.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_5ParamResiduals.root has been created

# %% [markdown]
# Lets fit some of these peaks, see if we can isolate the exact frequencies

# %%
def peak_fit_bw(x, p):
    return p[0]*r.TMath.BreitWigner(x[0],p[1],p[2]) + p[3]

func1 = r.TF1("peak1", peak_fit_bw, .39,.45,4)
func1.SetParNames('A','Mean','#gamma','+ C')
func1.SetParameters(1,.4,.1,0)
func1.SetParLimits(1,.4,.45)
func1.SetLineColor(2)
func1.SetNpx(1000)

func2 = r.TF1("peak2", peak_fit_bw, 0.6,0.67,4)
func2.SetParNames('A','Mean','#gamma','+ C')
func2.SetParameters(.3,0.64,-1)
func2.SetParLimits(1,0.63,0.67)

func3 = r.TF1("peak3", peak_fit_bw, 0.15,0.21,4)
func3.SetParNames('A','Mean','#gamma','+ C')
func3.SetParameters(.3,0.18,-1)

func4 = r.TF1("peak4", peak_fit_bw,2,2.2,4)
func4.SetParNames('A','Mean','#gamma','+ C')
func4.SetParameters(.3,2.1,-1)
func4.SetParLimits(1,2.0,2.2)

func5 = r.TF1("peak5", peak_fit_bw,2.5,2.55,4)
func5.SetParNames('A','Mean','#gamma','+ C')
func5.SetParameters(.3,2.5,-1)
func5.SetParLimits(1,2.5,2.54)

func6 = r.TF1("peak6", peak_fit_bw,.20,.25,4)
func6.SetParNames('A','Mean','#gamma','+ C')
func6.SetParameters(.3,.22,-1)
func6.SetParLimits(1,.22,.24)

# %%
c = r.TCanvas("c","c",1200,400)
hxform.GetXaxis().SetRangeUser(0,limmaxMHz/2)
hxform.Draw("HIST P0 L")

for i in range(3):
    hxform.Fit("peak1","REMBQ")
    hxform.Fit("peak2","REMBQ")
    hxform.Fit("peak3","REMBQ")
    hxform.Fit("peak4","REMBQ")
    hxform.Fit("peak5","REMBQ")
    hxform.Fit("peak6","REMBQ")

func1.Draw("SAME")
func2.Draw("SAME")
func3.Draw("SAME")
func4.Draw("SAME")
func5.Draw("SAME")
func6.Draw("SAME")

print("Peaks Located at: ")
print("    ",func3.GetParameter(1), "+/-", func3.GetParError(1),"MHz")
print("    ",func6.GetParameter(1), "+/-", func6.GetParError(1),"MHz")
print("    ",func1.GetParameter(1), "+/-", func1.GetParError(1),"MHz")
print("    ",func2.GetParameter(1), "+/-", func2.GetParError(1),"MHz")
print("    ",func4.GetParameter(1), "+/-", func4.GetParError(1),"MHz")
print("    ",func5.GetParameter(1), "+/-", func5.GetParError(1),"MHz")

pt = r.TPaveText(2.0,50,3.7,96)
pt.AddText("Peaks Located at: ")
pt.AddText("    "+str(func3.GetParameter(1))+" +/- "+str(func3.GetParError(1))+" MHz")
pt.AddText("    "+str(func6.GetParameter(1))+" +/- "+str(func6.GetParError(1))+" MHz")
pt.AddText("    "+str(func1.GetParameter(1))+" +/- "+str(func1.GetParError(1))+" MHz")
pt.AddText("    "+str(func2.GetParameter(1))+" +/- "+str(func2.GetParError(1))+" MHz")
pt.AddText("    "+str(func4.GetParameter(1))+" +/- "+str(func4.GetParError(1))+" MHz")
pt.AddText("    "+str(func5.GetParameter(1))+" +/- "+str(func5.GetParError(1))+" MHz")
pt.Draw()

c.Draw()
c.SetGrid()
c.Print("./images/"+prodString+"/"+prodString+"_5ParamResiduals_WithFits.png")
c.Print("./images/"+prodString+"/"+prodString+"_5ParamResiduals_WithFits.root")
# Out:
# Peaks Located at:
#      0.13628875840757906 +/- 0.0006617301919345743 MHz
#      0.2269037177848323 +/- 7.279471444870955e-05 MHz
#      0.4 +/- 1.485600226724948e-07 MHz
#      0.630000002787069 +/- 1.8116449557181724e-07 MHz
#      2.0000000000000187 +/- 6.430741645635507e-06 MHz
#      2.529795341936054 +/- 3.275890219889277e-05 MHz
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_5ParamResiduals_WithFits.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_5ParamResiduals_WithFits.root has been created

# %% [markdown]
# double check the root fft result with the python fft module

# %%
fig, ax = plt.subplots(figsize=(12, 5))
plt.plot([0]+welchVec+[0],label='Square (No Window)')
plt.title("Plot of the Window Function used")
plt.xlabel("Entries")
plt.legend()
plt.show()

ding = np.fft.fft(np.array(bins))

n = len(bins)
d = (centers[1] - centers[0])*math.pow(10.0,-6)

freq = np.fft.fftfreq(n, d)


fig, ax = plt.subplots(figsize=(12, 5))
plt.plot([x/(10**6) for x in freq],np.abs(ding),'.:',label='FFT 5-param')
plt.title("FFT Using Python")
plt.xlabel("Frequency [MHz]")
plt.xlim(0,6.7157787731503555 / 2)# *10.**6)
plt.legend()
plt.show()

# %%
print(len(residVec),[residVec[i] for i in range(5)])
centers, bins = zip(*residVec)
htest = r.TH1D("htest","htest",len(residVec),centers[0],centers[len(residVec)-1])
for i,ding in enumerate(bins):
    htest.SetBinContent(i, ding)
    
c = r.TCanvas()
htest.Draw()
c.Draw()
c.Print("hi.root")
# Out:
# 3828 [(30.010638297872337, 10775.347731345799), (30.159574468085104, 5437.6212088267785), (30.30851063829787, 3511.464640905848), (30.457446808510635, 3550.7211409655865), (30.606382978723403, 2762.9034927428)]
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: htest (Potential memory leak).
# Info in <TCanvas::SaveAs>: ROOT file hi.root has been created

# %% [markdown]
# ### 13 parameter fit

# %%
def blinded_wiggle_cbo(x, p):
    norm     = p[0]
    life     = p[1]
    asym     = p[2]
    R        = p[3]
    phi      = p[4]
    A1       = p[5]
    A2       = p[6]
    A3       = p[7]
    lifeCBO  = p[8]
    omegaCBO = p[9]
    phiCBO1  = p[10]
    phiCBO2  = p[11]
    phiCBO3  = p[12]
    
    time  = x[0]
    omega = getBlinded.paramToFreq(R)
    
    cCBO = 1-math.exp(-time/lifeCBO)*A1*math.cos(omegaCBO*time + phiCBO1)
    ACBO = asym * (1 - math.exp(-time/lifeCBO) * A2 * math.cos(omegaCBO*time + phiCBO2))
    phiCBO = phi + math.exp(-time/lifeCBO)*A3*math.cos(omegaCBO*time + phiCBO3)
    
    return norm * math.exp(-time/life) * cCBO * (1 - ACBO*math.cos(omega*time + phiCBO))

# %%
func13 = r.TF1("func13", blinded_wiggle_cbo, 30,500,13)
func13.SetParNames('N','#tau','A',
                   'R','#phi','A_{1}',
                   'A_{2}','A_{3}','#tau_{CBO}',
                   '#omega_{CBO}','#phi_{CBO - 1}')
func13.SetParName(11,'#phi_{CBO - 2}')
func13.SetParName(12,'#phi_{CBO - 3}')
#func13.SetParLimits(4,-6.3,6.3) #Phases should be restricted to +/- 2Pi
#func13.SetParLimits(8,100,500) #Avoid divide by 0 error
func13.SetParLimits(8,0.0000001,100000000) #Avoid divide by 0 error
#func13.SetParLimits(10,-6.3,6.3) 
#func13.SetParLimits(11,-6.3,6.3)
#func13.SetParLimits(12,-6.3,6.3)

#initial guesses, then updated with the first round of fit results
#func13.SetParameters(1500,64.4,0.4,0,0,1,1,1,.01,.01,0)
#func13.SetParameter(11,0)
#func13.SetParameter(12,0)
func13.SetParameters(100000, 64.32689658986958, -0.41149191856871803, 
                     -11.31981267111425, -4.201648334505292, -0.666502391530784, 
                     0.6927259503578, -0.38908021438317, 220, 
                     4.1, 0.4745581246420292)
func13.SetParameter(11, 6.299934663288357)
func13.SetParameter(12, 0.28579778778899545)
for i in range(4):
    func13.SetParameter(i, func.GetParameter(i))
#func13.FixParameter(12,0) #currently this parameter is fixed, as it doesn't behave well if left to wander on its own


func13.SetLineColor(2)
func13.SetNpx(2000)

# %%
c2 = r.TCanvas("c2","c2",1200,800)
c2.Divide(2,1)
c2.cd(1)
r.gPad.SetLogy()

r.gStyle.SetOptFit(111)
allCaloWiggle13 = f.Get("farline").Get("allCaloWiggle").Clone()

allCaloWiggle13.GetXaxis().SetLimits(allCaloWiggle13.GetXaxis().GetXmin() / 1000 * 1.25,
                                     allCaloWiggle13.GetXaxis().GetXmax() / 1000 * 1.25)
allCaloWiggle13.GetXaxis().SetTitle("Time [#mus]")

residuals13 = allCaloWiggle13.Clone() # this will be filled with the fit residuals later

for i in range(2): #the fit won't converge the first time. Don't look at me like that!
    print("Starting Fit:",i+1)
    allCaloWiggle13.Fit("func13","REMB")

allCaloWiggle13.Draw()

c2.cd(2)
ding13 =  allCaloWiggle13.Clone()
ding13.GetXaxis().SetRangeUser(100,125)
ding13.Draw()

r.gPad.SetLogy()
c2.Draw()
# Out:
# Starting Fit: 1
# Starting Fit: 2
#  FCN=7146.88 FROM MIGRAD    STATUS=CALL LIMIT   3152 CALLS        3153 TOTAL
#                      EDM=102.62    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   0.0 per cent
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  N            2.05277e+06   1.61435e+02  -4.63115e+00   2.70869e-03
#    2  #tau         6.42383e+01   2.82800e-03   6.25949e-05   5.73190e+01
#    3  A            3.96807e-01   5.71904e-05   2.52630e-06  -8.99942e+03
#    4  R           -1.11727e+01   1.64777e+00  -6.04471e-02  -2.62464e-01
#    5  #phi        -7.33496e+00   2.69840e-04   1.32195e-05  -4.58178e+03
#    6  A_{1}        2.47514e-02   1.02620e-02  -1.18375e-02  -1.10616e+02
#    7  A_{2}        2.15952e-01   2.20228e-02  -8.86326e-02  -1.07408e+02
#    8  A_{3}        1.98536e-01   2.37744e-02  -5.58927e-02  -8.10014e+02
#    9  #tau_{CBO}   1.01965e+01   1.79038e-01  -1.41660e-05** at limit **
#   10  #omega_{CBO}   3.71634e+00   1.52014e-03   9.51385e-04  -8.33052e+02
#   11  #phi_{CBO - 1}   1.62953e+00   1.25212e-01  -2.59501e-02   2.60931e+01
#   12  #phi_{CBO - 2}   7.24092e+00   6.30970e-02  -1.38341e-02   2.20983e+01
#   13  #phi_{CBO - 3}   5.53843e+00   6.87556e-02  -1.03228e-02   1.08876e+01
#  FCN=5316.44 FROM MINOS     STATUS=SUCCESSFUL    100 CALLS        5854 TOTAL
#                      EDM=3.94922e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  N            2.05269e+06   1.57178e+02   3.15119e-03  -8.35168e-08
#    2  #tau         6.42394e+01   2.79036e-03  -2.98680e-07  -1.82876e-03
#    3  A            3.96808e-01   5.62815e-05   3.27081e-08  -1.61388e-01
#    4  R           -1.31291e+01   1.62902e+00  -1.70685e-04   6.29182e-06
#    5  #phi        -7.33451e+00   2.64973e-04   5.52620e-08   7.75934e-02
#    6  A_{1}        8.31655e-04   9.18532e-05   5.76148e-09  -8.44343e-02
#    7  A_{2}        9.44268e-03   4.37379e-04   3.26457e-07  -3.45319e-01
#    8  A_{3}        1.08100e-02   4.80930e-04  -1.17454e-06   3.45294e-01
#    9  #tau_{CBO}   2.22837e+02   2.44015e+01  -2.28374e-07   1.31819e+00
#   10  #omega_{CBO}   3.76839e+00   5.35486e-04  -3.09165e-06  -2.37365e+00
#   11  #phi_{CBO - 1}  -1.14865e+00   1.10466e-01   4.80299e-05  -1.06622e-03
#   12  #phi_{CBO - 2}   4.99570e+00   4.88389e-02   1.30711e-04  -4.47787e-03
#   13  #phi_{CBO - 3}   3.44056e+00   4.67404e-02   4.67404e-02  -7.81386e-03
# Warning in <Fit>: Abnormal termination of minimization.

# %%
#The class calculates the  difference between the histogram and the fit function at each point 
#    and divides it by the uncertainty.
c3 = r.TCanvas("c","c",1600,600)
allCaloWiggle13.Draw()
c3.SetLogy()
c3.Draw()

rp13 = r.TRatioPlot(allCaloWiggle13)
rp13.Draw()
rp13.GetLowerRefYaxis().SetTitle("Residual")
rp13.GetLowerRefYaxis().SetRangeUser(-5,5)

allCaloWiggle13.GetXaxis().SetRangeUser(30,150)

c3.Update()
c3.Draw()
c3.Print("./images/"+prodString+"/"+prodString+"_TmethodWiggleFitAllCalos_13Parameter.png")
c3.Print("./images/"+prodString+"/"+prodString+"_TmethodWiggleFitAllCalos_13Parameter.root")
# Out:
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_TmethodWiggleFitAllCalos_13Parameter.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_TmethodWiggleFitAllCalos_13Parameter.root has been created

# %% [markdown]
# ### Fourier xform of the residuals from the 13 parameter fit

# %%
c3 = r.TCanvas()
residuals13param = residuals13.Clone() # this will hold the residials from the 5-parameter fit
nBins = residuals13param.GetSize() - 2 #total number of bins excluding over/underflow
print(nBins)
for i in range(nBins):
    binCenterX = allCaloWiggle13.GetXaxis().GetBinCenter(i)
    if (binCenterX > 30):
        residuals13param.SetBinContent(i, allCaloWiggle13.GetBinContent(i) - func13.Eval(binCenterX))
    else:
        residuals13param.SetBinContent(i, 0)

residuals13param.Draw()
residuals13param.GetXaxis().SetRangeUser(30,350)
residuals13param.SetTitle("Residuals of the 13-parameter Fit")
c3.Draw()

print(residuals13param.GetBinWidth(2), "wide")

hxform = r.TH1D()
hxform = 0
r.TVirtualFFT.SetTransform(0)
hxform = residuals13param.FFT(hxform,"MAG P")
hxform.SetTitle("Magnitude of the First Transform (13 Parameter Residuals)")
#NOTE: for "real" frequencies you have to divide the x-axes range with the range of your function
#    y-axes has to be rescaled by a factor of 1/SQRT(n) to be right: this is not done automatically!
normXform = hxform.GetEntries()
hxform.Scale(1/normXform)
c2 = r.TCanvas()
c2.cd()
#c2.SetLogy()
hxform.GetXaxis().SetTitle("Frequency (MHz)")
hxform.GetYaxis().SetTitle("Arb. Units")
hxform.Draw("HIST P0 L")
c2.Draw()

Npart = residuals13param.GetSize() - 2
minBinCenter = residuals13param.GetXaxis().GetBinCenter(0)
maxBinCenter = residuals13param.GetXaxis().GetBinCenter(Npart)

capT = maxBinCenter - minBinCenter
print(Npart, capT, minBinCenter, maxBinCenter)
deltaT = capT/Npart #microseconds
deltaF = 1/capT
print(deltaT, deltaF)

deltaTns = deltaT*1000 #nanoseconds
limmaxHz = (1/(deltaTns*math.pow(10.0,-9)))
limmaxMHz = limmaxHz / math.pow(10,6)

limmax = 2*deltaF*Npart #400-25
print(limmax,limmaxMHz)
nbins = residuals13param.GetSize() - 2
hxform.SetBins(Npart,0,limmaxMHz)
hxform.GetXaxis().SetRangeUser(0,limmaxMHz/2)

c2.Draw()
c2.Print("./images/"+prodString+"/"+prodString+"_13ParamResiduals.png")
c2.Print("./images/"+prodString+"/"+prodString+"_13ParamResiduals.root")
# Out:
# 4700
# 0.14893617021276595 wide
# 4700 699.9999999999999 -0.07446808510638298 699.9255319148936
# 0.14893617021276592 0.0014285714285714288
# 13.42857142857143 6.714285714285715
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_13ParamResiduals.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_13ParamResiduals.root has been created

# %% [markdown]
# ### Comaprison of the 5 and 13 parameter fit residual FFT's

# %%
c5 = r.TCanvas("c5","c5",1200,800)
c5.Divide(1,2)
c5.cd(1)
#r.gPad.SetLogy()
r.gPad.SetGrid()

residuals5paramXform.SetLineColor(9)
residuals5paramXform.SetMarkerColor(9)
residuals5paramXform.Draw("HIST P0 L")
residuals5paramXform.GetYaxis().SetRangeUser(0.1,75)
c5.cd(2)
#r.gPad.SetLogy()
r.gPad.SetGrid()
hxform.Draw("HIST P0 L")
hxform.GetYaxis().SetRangeUser(0.1,75)

residuals13paramXform = hxform.Clone()

c5.Draw()

c6 = r.TCanvas("c6","c6",1200,400)
residuals5paramXform.Draw("HIST P0 L")
hxform.SetLineColor(2)
hxform.SetMarkerColor(2)
hxform.Draw("HIST P0 L SAME")
leg = r.TLegend(0.65,0.8,0.9,0.9)
leg.AddEntry(residuals5paramXform ,"5-Parameter Residuals FFT", "l")
leg.AddEntry(hxform ,"13-Parameter Residuals FFT", "l")
leg.Draw()
c6.SetGrid()
c6.Draw()

c6.Print("./images/"+prodString+"/"+prodString+"_ResidualComparison5_13.png")
c6.Print("./images/"+prodString+"/"+prodString+"_ResidualComparison5_13.root")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c5
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c6
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_ResidualComparison5_13.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_ResidualComparison5_13.root has been created

# %%
parameters13 = []
for i in range(13):
    parameters13.append( (func13.GetParameter(i) , func13.GetParError(i)) )
#print(parameters13)
par13,parErr13 = zip(*parameters13)
print(par13)
# Out:
# (2052691.1553692778, 64.23943252883804, 0.39680756139466655, -13.129095900879593, -7.3345113757966125, 0.0008316546485162586, 0.009442680533349358, 0.010809966824167119, 222.83717348034114, 3.768391880260526, -1.1486493371310385, 4.995700519150725, 3.4405575675123763)

# %% [markdown]
# ---
#
# ### Now lets add in the veritcal waist term

# %%
def blinded_wiggle_cbo_vw(x, p):
    norm     = p[0]
    life     = p[1]
    asym     = p[2]
    R        = p[3]
    phi      = p[4]
    A1       = p[5]
    A2       = p[6]
    A3       = p[7]
    lifeCBO  = p[8]
    omegaCBO = p[9]
    phiCBO1  = p[10]
    phiCBO2  = p[11]
    phiCBO3  = p[12]
    Avw      = p[13]
    lifeVW   = p[14]
    omegaVW  = p[15]
    phiVW    = p[16]
    
    time  = x[0]
    omega = getBlinded.paramToFreq(R)
    
    cCBO = 1-math.exp(-time/lifeCBO)*A1*math.cos(omegaCBO*time + phiCBO1)
    ACBO = asym * (1 - math.exp(-time/lifeCBO) * A2 * math.cos(omegaCBO*time + phiCBO2))
    phiCBO = phi + math.exp(-time/lifeCBO)*A3*math.cos(omegaCBO*time + phiCBO3)
    cVW = 1 - Avw*math.exp(-time/lifeVW)*math.cos(omegaVW*time + phiVW)
    
    return norm * math.exp(-time/life) * cCBO * cVW * (1 - ACBO*math.cos(omega*time + phiCBO))

# %%
func17 = r.TF1("func17", blinded_wiggle_cbo_vw, 30,650,17)
func17.SetParNames('N','#tau','A',
                   'R','#phi','A_{1}',
                   'A_{2}','A_{3}','#tau_{CBO}',
                   '#omega_{CBO}','#phi_{CBO - 1}')
func17.SetParName(11,'#phi_{CBO - 2}')
func17.SetParName(12,'#phi_{CBO - 3}')
func17.SetParName(13,'A_{VW}')
func17.SetParName(14,'#tau_{VW}')
func17.SetParName(15,'#omega_{VW}')
func17.SetParName(16,'#phi_{VW}')
func17.SetParLimits(8,0.0000001,100000000) #Avoid divide by 0 error
func17.SetParLimits(14,0.0000001,100000000) #Avoid divide by 0 error
#func17.SetParLimits(10,-6.3,6.3) 
#func17.SetParLimits(11,-6.3,6.3)
#func17.SetParLimits(12,-6.3,6.3)

#initial guesses, then updated with the first round of fit results
for i in range(13):
    func17.SetParameter(i, func13.GetParameter(i))
func17.SetParameter(13, 1)
func17.SetParameter(14, 24)
func17.SetParameter(15, 14.41)
func17.SetParameter(16, 0)

func17.SetParameter(9, 2.307 ) #omega_cbo


func17.SetLineColor(4)
func17.SetNpx(2000)

# %%
c2 = r.TCanvas("c2","c2",1200,800)
c2.Divide(2,1)
c2.cd(1)
r.gPad.SetLogy()

r.gStyle.SetOptFit(111)
allCaloWiggle17 = f.Get("farline").Get("allCaloWiggle").Clone()

allCaloWiggle17.GetXaxis().SetLimits(allCaloWiggle17.GetXaxis().GetXmin() / 1000 * 1.25,
                                     allCaloWiggle17.GetXaxis().GetXmax() / 1000 * 1.25)
allCaloWiggle17.GetXaxis().SetTitle("Time [#mus]")

residuals17 = allCaloWiggle17.Clone() # this will be filled with the fit residuals later

for i in range(2): #the fit won't converge the first time. Don't look at me like that!
    print("Starting Fit:",i+1)
    allCaloWiggle17.Fit("func17","REMB")
    

allCaloWiggle17.Draw()

c2.cd(2)
ding17 =  allCaloWiggle17.Clone()
ding17.GetXaxis().SetRangeUser(100,125)
ding17.Draw()

r.gPad.SetLogy()
c2.Draw()
# Out:
# Starting Fit: 1
# Starting Fit: 2
#  FCN=6108.83 FROM MINOS     STATUS=SUCCESSFUL    401 CALLS       10084 TOTAL
#                      EDM=1.1705e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  N            2.05247e+06   1.55971e+02   1.44232e-02  -1.63534e-07
#    2  #tau         6.42439e+01   2.74959e-03  -1.89508e-07  -2.18503e-03
#    3  A            3.96835e-01   5.63173e-05   2.45144e-09  -1.20835e-01
#    4  R           -1.39783e+01   1.60445e+00   1.35630e-04   5.45854e-06
#    5  #phi        -7.33443e+00   2.62784e-04  -3.12200e-08   1.21989e-01
#    6  A_{1}        4.59759e-03   1.84931e-04   3.91936e-08  -3.50779e-01
#    7  A_{2}       -9.10942e-04   3.01775e-04  -2.94792e-08   4.28052e-02
#    8  A_{3}       -1.09721e-03   3.11679e-04   1.31124e-08  -4.96172e-02
#    9  #tau_{CBO}   2.02127e+02   2.06167e+01   2.40256e-08   1.08878e-01
#   10  #omega_{CBO}   2.32880e+00   5.18002e-04  -4.05856e-09   9.98638e-03
#   11  #phi_{CBO - 1}  -3.35248e+00   4.09898e-02  -2.89041e-07   5.54559e-04
#   12  #phi_{CBO - 2}   6.21825e+00   3.27533e-01  -1.59840e-05   3.79861e-05
#   13  #phi_{CBO - 3}   4.09108e+00   2.85333e-01   3.94783e-05  -1.12946e-04
#   14  A_{VW}       2.79426e-03   9.43469e-04   4.89715e-06  -2.24212e+00
#   15  #tau_{VW}    3.93615e+01   1.10128e+01  -8.05158e-07  -1.43573e+01
#   16  #omega_{VW}   1.44411e+01   6.68151e-03   7.26940e-05  -1.28199e-01
#   17  #phi_{VW}   -3.16564e+00   3.17920e-01   3.17920e-01  -1.35664e-02
#  FCN=6108.83 FROM MINOS     STATUS=SUCCESSFUL    368 CALLS        8230 TOTAL
#                      EDM=5.0546e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  N            2.05247e+06   1.55968e+02   4.42449e-03  -1.84973e-07
#    2  #tau         6.42439e+01   2.74955e-03  -5.28420e-08  -2.88721e-03
#    3  A            3.96835e-01   5.63176e-05   1.15190e-09  -1.14340e-01
#    4  R           -1.39783e+01   1.60444e+00   4.05561e-05   5.32356e-06
#    5  #phi        -7.33443e+00   2.62780e-04  -9.04616e-09   1.27343e-01
#    6  A_{1}        4.59759e-03   1.84543e-04   1.37986e-08  -3.63942e-01
#    7  A_{2}       -9.10935e-04   3.01806e-04  -1.28409e-08   3.73599e-02
#    8  A_{3}       -1.09718e-03   3.11713e-04   6.87825e-09  -7.12803e-03
#    9  #tau_{CBO}   2.02126e+02   2.05756e+01  -7.67338e-09  -1.89671e-01
#   10  #omega_{CBO}   2.32880e+00   5.17971e-04  -5.62317e-09   1.37106e-02
#   11  #phi_{CBO - 1}  -3.35248e+00   4.09873e-02   4.47098e-07   6.00667e-04
#   12  #phi_{CBO - 2}   6.21824e+00   3.27526e-01  -3.47344e-06   2.20092e-05
#   13  #phi_{CBO - 3}   4.09106e+00   2.85341e-01   1.20400e-05  -1.18852e-04
#   14  A_{VW}       2.79426e-03   8.81534e-04   6.39280e-06  -7.86100e+00
#   15  #tau_{VW}    3.93614e+01   1.02877e+01  -1.10312e-06  -4.79327e+01
#   16  #omega_{VW}   1.44411e+01   6.63979e-03   1.08890e-04  -3.34393e-01
#   17  #phi_{VW}   -3.16564e+00   3.16117e-01   3.16117e-01  -2.18322e-03

# %%
#The class calculates the  difference between the histogram and the fit function at each point 
#    and divides it by the uncertainty.
c3 = r.TCanvas("c","c",1600,600)
allCaloWiggle17.Draw()
c3.SetLogy()
c3.Draw()

rp17 = r.TRatioPlot(allCaloWiggle17)
rp17.Draw()
rp17.GetLowerRefYaxis().SetTitle("Residual")
rp17.GetLowerRefYaxis().SetRangeUser(-5,5)

allCaloWiggle17.GetXaxis().SetRangeUser(30,150)

c3.Update()
c3.Draw()
c3.Print("./images/"+prodString+"/"+prodString+"_TmethodWiggleFitAllCalos_17Parameter.png")
c3.Print("./images/"+prodString+"/"+prodString+"_TmethodWiggleFitAllCalos_17Parameter.root")
# Out:
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_TmethodWiggleFitAllCalos_17Parameter.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_TmethodWiggleFitAllCalos_17Parameter.root has been created

# %%
for i in range(17):
    print(func17.GetParName(i), " = ", func17.GetParameter(i), "+/-", func17.GetParError(i))
# Out:
# N  =  2052466.2270270109 +/- 155.9681487807844
# #tau  =  64.24389999818614 +/- 0.002749554015914552
# A  =  0.39683463215917564 +/- 5.631760533802531e-05
# R  =  -13.97827352536023 +/- 1.6044392663647842
# #phi  =  -7.334426513286529 +/- 0.0002627800955868016
# A_{1}  =  0.004597588158422558 +/- 0.00018454308600066184
# A_{2}  =  -0.0009109346155193233 +/- 0.0003018059717399751
# A_{3}  =  -0.0010971813695299863 +/- 0.00031171343921337577
# #tau_{CBO}  =  202.12577450115154 +/- 20.57560356816255
# #omega_{CBO}  =  2.3287996194580893 +/- 0.0005179707400566832
# #phi_{CBO - 1}  =  -3.352482936746047 +/- 0.040987329884767096
# #phi_{CBO - 2}  =  6.218242415387301 +/- 0.3275257758152908
# #phi_{CBO - 3}  =  4.091055930999272 +/- 0.2853405832401841
# A_{VW}  =  0.0027942612155454787 +/- 0.0008815339208567014
# #tau_{VW}  =  39.36142568558227 +/- 10.287659962804332
# #omega_{VW}  =  14.441112574803542 +/- 0.006639791017707355
# #phi_{VW}  =  -3.1656368466235936 +/- 0.31611723876855247

# %% [markdown]
# ### Fourier xform of the residuals from the 17 parameter fit

# %%
c3 = r.TCanvas()
residuals17param = residuals17.Clone() # this will hold the residials from the 5-parameter fit
nBins = residuals17param.GetSize() - 2 #total number of bins excluding over/underflow
print(nBins)
for i in range(nBins):
    binCenterX = allCaloWiggle17.GetXaxis().GetBinCenter(i)
    if (binCenterX > 30):
        residuals17param.SetBinContent(i, allCaloWiggle17.GetBinContent(i) - func17.Eval(binCenterX))
    else:
        residuals17param.SetBinContent(i, 0)

residuals17param.Draw()
residuals17param.GetXaxis().SetRangeUser(30,350)
residuals17param.SetTitle("Residuals of the 17-parameter Fit")
c3.Draw()

print(residuals17param.GetBinWidth(2), "wide")

hxform = r.TH1D()
hxform = 0
r.TVirtualFFT.SetTransform(0)
hxform = residuals17param.FFT(hxform,"MAG P")
hxform.SetTitle("Magnitude of the First Transform (17 Parameter Residuals)")
#NOTE: for "real" frequencies you have to divide the x-axes range with the range of your function
#    y-axes has to be rescaled by a factor of 1/SQRT(n) to be right: this is not done automatically!
normXform = hxform.GetEntries()
hxform.Scale(1/normXform)
c2 = r.TCanvas()
c2.cd()
#c2.SetLogy()
hxform.GetXaxis().SetTitle("Frequency (MHz)")
hxform.GetYaxis().SetTitle("Arb. Units")
hxform.Draw("HIST P0 L")
c2.Draw()

Npart = residuals17param.GetSize() - 2
minBinCenter = residuals17param.GetXaxis().GetBinCenter(0)
maxBinCenter = residuals17param.GetXaxis().GetBinCenter(Npart)

capT = maxBinCenter - minBinCenter
print(Npart, capT, minBinCenter, maxBinCenter)
deltaT = capT/Npart #microseconds
deltaF = 1/capT
print(deltaT, deltaF)

deltaTns = deltaT*1000 #nanoseconds
limmaxHz = (1/(deltaTns*math.pow(10.0,-9)))
limmaxMHz = limmaxHz / math.pow(10,6)

limmax = 2*deltaF*Npart #400-25
print(limmax,limmaxMHz)
nbins = residuals17param.GetSize() - 2
hxform.SetBins(Npart,0,limmaxMHz)
hxform.GetXaxis().SetRangeUser(0,limmaxMHz/2)
residuals17paramXform = hxform.Clone()

c2.Draw()
c2.Print("./images/"+prodString+"/"+prodString+"_17ParamResiduals.png")
c2.Print("./images/"+prodString+"/"+prodString+"_17ParamResiduals.root")
# Out:
# 4700
# 0.14893617021276595 wide
# 4700 699.9999999999999 -0.07446808510638298 699.9255319148936
# 0.14893617021276592 0.0014285714285714288
# 13.42857142857143 6.714285714285715
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_17ParamResiduals.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_17ParamResiduals.root has been created

# %%
c6 = r.TCanvas("c6","c6",1200,400)
residuals5paramXform.Draw("HIST P0 L")

residuals13paramXform.SetLineColor(2)
residuals13paramXform.SetMarkerColor(2)
residuals13paramXform.Draw("HIST P0 L SAME")

residuals17paramXform.SetLineColor(3)
residuals17paramXform.Draw("HIST P0 L SAME")
leg = r.TLegend(0.65,0.7,0.9,0.9)
leg.AddEntry(residuals5paramXform ,"5-Parameter Residuals FFT", "l")
leg.AddEntry(residuals13paramXform ,"13-Parameter Residuals (CBO Only) FFT", "l")
leg.AddEntry(residuals17paramXform ,"17-Parameter Residuals (CBO+VW) FFT", "l")
leg.Draw()
c6.SetGrid()
c6.Draw()

c6.Print("./images/"+prodString+"/"+prodString+"_ResidualComparison5_13_17.png")
c6.Print("./images/"+prodString+"/"+prodString+"_ResidualComparison5_13_17.root")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c6
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_ResidualComparison5_13_17.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_ResidualComparison5_13_17.root has been created

# %% [markdown]
# ___
#
# # Now lets make some plots from the individual calorimeters.

# %%
caloNum = 1

wiggleFitParamVec = []
caloiWiggleVec = []
wiggleFitChiSquareVec = []

for caloNum in range(1,25):
    print("Starting Calo", caloNum)
    
    c4 = r.TCanvas("c4","c4",2400,800)
    c4.Divide(4,2)

    c4.cd(1)
    caloiEnergy = f.Get("farline").Get("calo"+str(caloNum)).Get("energy").Clone()
    caloiEnergy.Draw()
    c4.Draw()

    c4.cd(2)
    caloiXtalHits = f.Get("farline").Get("calo"+str(caloNum)).Get("hitPositions").Clone()
    caloiXtalHits.Draw("colz")
    r.gPad.SetLogz()

    c4.cd(3)
    caloiWiggle = f.Get("farline").Get("calo"+str(caloNum)).Get("wiggle").Clone()
    caloiWiggle.GetXaxis().SetRangeUser(30000,300000)
    caloiWiggle.Draw()
    r.gPad.SetLogy()

    caloiWiggle.GetXaxis().SetLimits(caloiWiggle.GetXaxis().GetXmin() / 1000 * 1.25,caloiWiggle.GetXaxis().GetXmax() / 1000 * 1.25)
    caloiWiggle.GetXaxis().SetTitle("Time [#mus]")
    
    for i in range(2):
        caloiWiggle.Fit("func","REMQ")
    
    wiggleFitParamVec.append( ( func.GetParameter(3) , func.GetParError(3) ) )
    wiggleFitChiSquareVec.append( ( func.GetNDF(),
                                  func.GetChisquare(),
                                  func.GetProb() ) )
    caloiWiggleVec.append( caloiWiggle.Clone("calo"+str(caloNum).zfill(2)+" Wiggle Plot") )

    c4.cd(4)
    caloiTimes = f.Get("farline").Get("calo"+str(caloNum)).Get("times").Clone()
    caloiTimes.GetXaxis().SetRangeUser(0,60000)
    caloiTimes.Draw()

    c4.cd(5)
    caloiXtal35Energy = f.Get("farline").Get("calo"+str(caloNum)).Get("xtal35Energy").Clone()
    caloiXtal35Energy.Draw()

    c4.cd(6)
    caloiXtal31Energy = f.Get("farline").Get("calo"+str(caloNum)).Get("xtal31Energy").Clone()
    caloiXtal31Energy.Draw()

    c4.cd(7)
    caloiXtal0Energy = f.Get("farline").Get("calo"+str(caloNum)).Get("xtal0Energy").Clone()
    caloiXtal0Energy.Draw()

    c4.cd(8)
    caloiXtal53Energy = f.Get("farline").Get("calo"+str(caloNum)).Get("xtal53Energy").Clone()
    caloiXtal53Energy.Draw()

    c4.Draw()
    c4.Print("./images/"+prodString+"/"+prodString+"_calo"+str(caloNum).zfill(2)+"_FullSet.png")
    c4.Print("./images/"+prodString+"/"+prodString+"_calo"+str(caloNum).zfill(2)+"_FullSet.root")
# Out:
# Starting Calo 1
# Starting Calo 2
# Starting Calo 3
# Starting Calo 4
# Starting Calo 5
# Starting Calo 6
# Starting Calo 7
# Starting Calo 8
# Starting Calo 9
# Starting Calo 10
# Starting Calo 11
# Starting Calo 12
# Starting Calo 13
# Starting Calo 14
# Starting Calo 15
# Starting Calo 16
# Starting Calo 17
# Starting Calo 18
# Starting Calo 19
# Starting Calo 20
# Starting Calo 21
# Starting Calo 22
# Starting Calo 23
# Starting Calo 24
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo01_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo01_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo02_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo02_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo03_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo03_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo04_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo04_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo05_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo05_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo06_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo06_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo07_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo07_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo08_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo08_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo09_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo09_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo10_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo10_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo11_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo11_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo12_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo12_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo13_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo13_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo14_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo14_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo15_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo15_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo16_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo16_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo17_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo17_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo18_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo18_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo19_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo19_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo20_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo20_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo21_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo21_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo22_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo22_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo23_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo23_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_calo24_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_calo24_FullSet.root has been created

# %%
pars, parErrs = zip(*wiggleFitParamVec)
calos = [x for x in range(1,25)]
plt.errorbar(x=calos,y=pars,yerr=parErrs,ls='none',capsize=3,capthick=1,marker='o',markersize=5)
plt.title(prodString+"\nVariation of R parameter vs. Calo Number for 5-Parameter Fit")
plt.xlabel("Calo Number")
plt.ylabel("R")
plt.show()

# %% [raw]
# This is some pretty worrying variation in the R value, but not entirely unexpected.
#
# We can also look at the rediced chi square for each of the calos.

# %%
ndfs, chisqs, probs = zip(*wiggleFitChiSquareVec)
plt.plot(calos,[x / ndfs[i] for i,x in enumerate(chisqs)],'o:',label='Individual Calos')

ding = [chiSqAll[1]/chiSqAll[0] for i in range(24)]
plt.plot(calos, ding, '-',label="All Calos")

plt.ylabel("$\chi^2$ / NDF")
plt.xlabel("Calorimeter Number")
plt.title(prodString+"\nReduced $\chi^2$ for Individual Calo Wiggle Plots")
plt.legend()
plt.show()
# Out:
# <input>:7: DeprecationWarning: invalid escape sequence \c
# <ipython-input-29-4786eddd7da4>:7: DeprecationWarning: invalid escape sequence \c
#   plt.ylabel("$\chi^2$ / NDF")

# %% [raw]
# Now lets implement some of Kim's suggestions, starting with:
#     "FFT of raw wiggle plot, FFT of residual of 5-par-fit, for each calo"
#
# Why? Because it's easiest.

# %%
print(caloiWiggleVec)
caloiResidVec = []

for i in range(24):
    caloNum = i+1
    c = r.TCanvas()
    caloiWiggleVec[i].Draw("goff")
    funci = caloiWiggleVec[i].GetFunction("func")
    #c.Draw()
    
#    print("tau = ",funci.GetParameter(1), "for calo", caloNum)
    residuals5paramCaloi = caloiWiggleVec[i].Clone()
    nBins = residuals5paramCaloi.GetSize() - 2
#    print("    ", nbins , "bins" )
    for bini in range(int(nBins) ):
        binCenterX = caloiWiggleVec[i].GetXaxis().GetBinCenter(bini)
        if (binCenterX > 30):
            residuals5paramCaloi.SetBinContent(bini, caloiWiggleVec[i].GetBinContent(bini) - funci.Eval(binCenterX))
        else:
            residuals5paramCaloi.SetBinContent(bini, 0)
            
    residuals5paramCaloi.Draw("HIST P0 L")
#    c.Draw()
    
    hxformRaw = r.TH1D()
    hxformRaw = 0
    r.TVirtualFFT.SetTransform(0)
    hxformRaw = caloiWiggleVec[i].FFT(hxform,"MAG P")
    hxformRaw.SetTitle("Magnitude of the First Transform (Raw Wiggle) for Calo "+str(caloNum))
    #NOTE: for "real" frequencies you have to divide the x-axes range with the range of your function
    #    y-axes has to be rescaled by a factor of 1/SQRT(n) to be right: this is not done automatically!
    normXform = hxformRaw.GetEntries()
    hxformRaw.Scale(1/normXform)
    c2 = r.TCanvas()
    c2.cd()
    #c2.SetLogy()
    hxformRaw.GetXaxis().SetTitle("Frequency (MHz)")
    hxformRaw.GetYaxis().SetTitle("Arb. Units")
    hxformRaw.Draw("HIST P0 L")
#    c2.Draw()
    
    hxform = r.TH1D()
    hxform = 0
    r.TVirtualFFT.SetTransform(0)
    hxform = residuals5paramCaloi.FFT(hxform,"MAG P")
    hxform.SetTitle("Magnitude of the First Transform (5 Parameter Residuals) for Calo "+str(caloNum))
    #NOTE: for "real" frequencies you have to divide the x-axes range with the range of your function
    #    y-axes has to be rescaled by a factor of 1/SQRT(n) to be right: this is not done automatically!
    normXform = hxform.GetEntries()
    hxform.Scale(1/normXform)
    c2 = r.TCanvas()
    c2.cd()
    #c2.SetLogy()
    hxform.GetXaxis().SetTitle("Frequency (MHz)")
    hxform.GetYaxis().SetTitle("Arb. Units")
    hxform.Draw("HIST P0 L")
#    c2.Draw()

    Npart = residuals5paramCaloi.GetSize() - 2
    minBinCenter = residuals5paramCaloi.GetXaxis().GetBinCenter(0)
    maxBinCenter = residuals5paramCaloi.GetXaxis().GetBinCenter(Npart)

    capT = maxBinCenter - minBinCenter
#    print(Npart, capT, minBinCenter, maxBinCenter)
    deltaT = capT/Npart #microseconds
    deltaF = 1/capT
#    print(deltaT, deltaF)

    deltaTns = deltaT*1000 #nanoseconds
    limmaxHz = (1/(deltaTns*math.pow(10.0,-9)))
    limmaxMHz = limmaxHz / math.pow(10,6)

    limmax = 2*deltaF*Npart #400-25
#    print(limmax,limmaxMHz)
    nbins = residuals5paramCaloi.GetSize() - 2
    hxform.SetBins(Npart,0,limmaxMHz)
    hxform.GetXaxis().SetRangeUser(0,limmaxMHz/2)
    caloiResidVec.append( hxform.Clone() )
    
    hxformRaw.SetBins(Npart,0,limmaxMHz)
    hxformRaw.GetXaxis().SetRangeUser(0,limmaxMHz/2)
    
    caloiWiggleVec[i].GetXaxis().SetRangeUser(0,700)
    residuals5paramCaloi.GetXaxis().SetRangeUser(0,700)
    
    c3 = r.TCanvas("c3","c3",1200,1200)
    c3.Divide(2,2)
    c3.cd(1)
    caloiWiggleVec[i].Draw()
    r.gPad.SetLogy()    
    c3.cd(2)
    r.gPad.SetLogy()    
    hxformRaw.Draw("HIST P0 L")
    c3.cd(3)
    residuals5paramCaloi.SetTitle("5 Parameter Residuals Calo"+str(caloNum))
    residuals5paramCaloi.Draw("HIST P0 L")
    c3.cd(4)
    r.gPad.SetLogy()    
    hxform.Draw("HIST P0 L")
    c3.Draw()
    c3.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_Calo"+str(caloNum).zfill(2)+".png")
    c3.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_Calo"+str(caloNum).zfill(2)+".root")
# Out:
# [<ROOT.TH1D object ("calo01 Wiggle Plot") at 0x7ffffc9503d0>, <ROOT.TH1D object ("calo02 Wiggle Plot") at 0x7ffffa29eed0>, <ROOT.TH1D object ("calo03 Wiggle Plot") at 0x7ffffce7f790>, <ROOT.TH1D object ("calo04 Wiggle Plot") at 0x7ffffdc315f0>, <ROOT.TH1D object ("calo05 Wiggle Plot") at 0x7ffffce8ff80>, <ROOT.TH1D object ("calo06 Wiggle Plot") at 0x7ffffcea8dc0>, <ROOT.TH1D object ("calo07 Wiggle Plot") at 0x7f91f7ff9730>, <ROOT.TH1D object ("calo08 Wiggle Plot") at 0x7f91f8021ad0>, <ROOT.TH1D object ("calo09 Wiggle Plot") at 0x7f91f808e5e0>, <ROOT.TH1D object ("calo10 Wiggle Plot") at 0x7f91f8071190>, <ROOT.TH1D object ("calo11 Wiggle Plot") at 0x7f91f8074230>, <ROOT.TH1D object ("calo12 Wiggle Plot") at 0x7f91f771efe0>, <ROOT.TH1D object ("calo13 Wiggle Plot") at 0x7f91f660aeb0>, <ROOT.TH1D object ("calo14 Wiggle Plot") at 0x7f91f6656c30>, <ROOT.TH1D object ("calo15 Wiggle Plot") at 0x7ffffd343410>, <ROOT.TH1D object ("calo16 Wiggle Plot") at 0x7f91f5d94ab0>, <ROOT.TH1D object ("calo17 Wiggle Plot") at 0x7f91f5d96360>, <ROOT.TH1D object ("calo18 Wiggle Plot") at 0x7f91f55300f0>, <ROOT.TH1D object ("calo19 Wiggle Plot") at 0x7f91f55074b0>, <ROOT.TH1D object ("calo20 Wiggle Plot") at 0x7f91f4c83190>, <ROOT.TH1D object ("calo21 Wiggle Plot") at 0x7ffffd3d8670>, <ROOT.TH1D object ("calo22 Wiggle Plot") at 0x7ffffd3ad440>, <ROOT.TH1D object ("calo23 Wiggle Plot") at 0x7f91f44045c0>, <ROOT.TH1D object ("calo24 Wiggle Plot") at 0x7f91f3b5e140>]
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo01.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo01.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo02.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo02.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo03.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo03.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo04.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo04.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo05.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo05.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo06.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo06.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo07.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo07.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo08.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo08.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo09.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo09.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo10.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo10.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo11.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo11.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo12.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo12.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo13.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo13.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo14.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo14.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo15.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo15.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo16.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo16.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo17.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo17.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo18.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo18.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo19.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo19.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo20.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo20.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo21.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo21.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo22.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo22.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo23.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo23.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_Calo24.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_Calo24.root has been created

# %%
c6 = r.TCanvas("c6","c6",1200,500)
leg = r.TLegend(0.65,0.65,0.9,0.9)
c6.cd()
for i, hist in enumerate(caloiResidVec):
    hist.SetLineColor(i+1)
    if(i>3):
        hist.SetLineColor(i+2)
    if(i>6):
        hist.SetLineStyle(2)
    if(i>7):
        hist.SetLineColor(i+40-12)
    if (i < 0.9):
        hist.SetTitle("Magnitude of the First Transform (5-Parameter Residuals) for Calos 1 - 24")
        hist.Draw("HIST P0 L")
    else:
        hist.Draw("HIST P0 L SAME")
    leg.AddEntry(hist ,"Calo "+str(i+1)+" FFT", "l")

leg.SetNColumns(3)
leg.Draw()
c6.Draw()
c6.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_all.root")
c6.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_all.png")

c7 = r.TCanvas("c7","c7",1200,500)
hsum = caloiResidVec[0].Clone()
for i in range(1,24):
    hsum.Add(caloiResidVec[i])
hsum.SetTitle("Sum of the Magnitude of the First Transform (5-Parameter Residuals) for Calos 1 - 24")
hsum.Draw("HIST P0 L")
c7.Draw()
c7.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_allSum.root")
c7.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_allSum.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c6
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_all.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_all.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_allSum.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_allSum.png has been created

# %% [markdown]
# Now lets compare the 5-parameter residuals from the 24 calos to those from the total.

# %%
c = r.TCanvas("c","c",1200,500)
leg = r.TLegend(0.65,0.8,0.9,0.9)

hsum.Draw("HIST P0 L")
hsum.GetYaxis().SetRangeUser(0.1,1000)
residuals5paramXform.SetLineColor(2)
residuals5paramXform.SetMarkerColor(2)
residuals5paramXform.Draw("HIST P0 L SAME")

leg.AddEntry(hsum,"Sum of the 24 Calorimeter FFT's",'l')
leg.AddEntry(residuals5paramXform,"FFT of the Total Wiggle Residuals",'l')
leg.Draw()
c.SetLogy()
c.Draw()
c.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_allSum_Comparison.root")
c.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_allSum_Comparison.png")
# Out:
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_Residual5Param_allSum_Comparison.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_Residual5Param_allSum_Comparison.png has been created

# %% [raw]
# Now we generate the plots which used to be part of f2, but now have been migrated into part of the original file to save time

# %% [raw]
# 1) normalized energy spectrum for different times like what Jason showed in his talk
#     (to catch noise pulses, every 10 T_a ~ 43.7 us will do) (edited)

# %%
for calo in range(1,25): 
    print("Starting calo", calo)
    c3 = r.TCanvas("c3","c3",4500,4500)
    c3.Divide(4,4)

    nDivs = 16
    for div in range(nDivs):
        c3.cd(div+1)
        r.gROOT.SetSelectedPad(r.gPad)
        
        #hi = f2.Get("energySpectrum_calo"+str(calo).zfill(2)+"_div"+str(div))
        hi = f.Get("farline").Get("calo"+str(calo)).Get("calo"+str(calo)+"TimeCut"+str(div)+"Energy")
        int2000_3000 = hi.Integral( hi.FindBin(2000), hi.FindBin(3000) )
        intTotal = hi.Integral()
        if(np.abs(int2000_3000) > 0):
            hi.Scale(1/int2000_3000)
            #hi.Scale(1/intTotal)
            
        hi.GetXaxis().SetRangeUser(0,4000)
        hi.GetYaxis().SetRangeUser(0.001,1)
        hi.SetFillColorAlpha(38,0.5)
        hi.Draw("HIST P0 L")

        r.gPad.SetLogy()
        
    c3.Draw()

    c3.Print("./images/"+prodString+"/"+prodString+"_energySpectrum_calo"+str(calo).zfill(2)+".png")
    c3.Print("./images/"+prodString+"/"+prodString+"_energySpectrum_calo"+str(calo).zfill(2)+".root")
# Out:
# Starting calo 1
# Starting calo 2
# Starting calo 3
# Starting calo 4
# Starting calo 5
# Starting calo 6
# Starting calo 7
# Starting calo 8
# Starting calo 9
# Starting calo 10
# Starting calo 11
# Starting calo 12
# Starting calo 13
# Starting calo 14
# Starting calo 15
# Starting calo 16
# Starting calo 17
# Starting calo 18
# Starting calo 19
# Starting calo 20
# Starting calo 21
# Starting calo 22
# Starting calo 23
# Starting calo 24
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo01.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo01.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo02.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo02.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo03.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo03.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo04.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo04.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo05.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo05.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo06.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo06.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo07.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo07.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo08.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo08.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo09.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo09.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo10.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo10.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo11.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo11.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo12.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo12.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo13.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo13.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo14.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo14.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo15.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo15.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo16.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo16.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo17.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo17.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo18.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo18.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo19.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo19.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo20.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo20.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo21.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo21.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo22.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo22.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo23.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo23.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_energySpectrum_calo24.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_energySpectrum_calo24.root has been created

# %% [raw]
# 2) energy histogram for sync laser pulse cluster for each calo
#     (use time cut, like between 4000-6000 c.t. and energy cut, like > 40 GeV)

# %%
caloStdVec = []

for calo in range(1,25): 
    print("Starting calo", calo)
    c3 = r.TCanvas()

    #hi = f2.Get("laserEnergyPulse_calo"+str(calo).zfill(2))
    hi = f.Get("farline").Get("calo"+str(calo)).Get("laserSyncEnergies")
    hi.GetXaxis().SetTitle("Energy [MeV]")
    hi.Draw("HIST P0 L")
    
    #print("    Mean: ", hi.GetMean(), "and stdev: ", hi.GetStdDev())
    caloStdVec.append((calo, hi.GetMean(), hi.GetStdDev()))
        
    c3.SetLogy()
    c3.Draw()

    c3.Print("./images/"+prodString+"/"+prodString+"_laserEnergyPulse_calo"+str(calo).zfill(2)+".png")
    c3.Print("./images/"+prodString+"/"+prodString+"_laserEnergyPulse_calo"+str(calo).zfill(2)+".root")
    
print(caloStdVec)
# Out:
# Starting calo 1
# Starting calo 2
# Starting calo 3
# Starting calo 4
# Starting calo 5
# Starting calo 6
# Starting calo 7
# Starting calo 8
# Starting calo 9
# Starting calo 10
# Starting calo 11
# Starting calo 12
# Starting calo 13
# Starting calo 14
# Starting calo 15
# Starting calo 16
# Starting calo 17
# Starting calo 18
# Starting calo 19
# Starting calo 20
# Starting calo 21
# Starting calo 22
# Starting calo 23
# Starting calo 24
# [(1, 89923.81419894623, 416.7768836111976), (2, 91233.93758816154, 487.55161379066953), (3, 93156.04741997585, 447.46036623614845), (4, 90988.28640659737, 439.4217719750836), (5, 90993.39988971125, 403.0983164320367), (6, 96498.39966826381, 403.81127126058357), (7, 91710.53085752924, 421.90513501741526), (8, 86820.33731164238, 393.3027129144455), (9, 104554.0796579999, 435.18111920010386), (10, 113900.58783287695, 450.0930281441755), (11, 95025.07903734052, 396.6991058498198), (12, 85383.23296248898, 360.07010200817297), (13, 90557.10615248764, 386.647574514637), (14, 80490.8698874808, 380.37669667151687), (15, 96662.18061772625, 479.8708031727453), (16, 71541.60982484111, 449.56196136102926), (17, 72054.9208774613, 340.00374451847284), (18, 78982.75836953461, 354.0148463732487), (19, 79858.31248128376, 349.2932776040403), (20, 81240.4544779012, 365.35122138033654), (21, 90329.83080255438, 389.7682232477872), (22, 78210.80423256061, 519.4296441795142), (23, 87798.0782745133, 378.02157195667223), (24, 86381.86658855314, 362.34090771138136)]
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo01.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo01.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo02.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo02.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo03.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo03.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo04.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo04.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo05.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo05.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo06.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo06.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo07.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo07.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo08.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo08.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo09.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo09.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo10.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo10.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo11.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo11.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo12.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo12.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo13.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo13.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo14.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo14.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo15.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo15.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo16.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo16.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo17.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo17.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo18.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo18.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo19.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo19.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo20.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo20.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo21.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo21.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo22.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo22.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo23.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo23.root has been created
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo24.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_calo24.root has been created

# %%
calos, means, stds = zip(*caloStdVec)

fig, ax = plt.subplots(1,2, figsize=(15,5))
fig.tight_layout()
fig.subplots_adjust(wspace=.25)

ax[1].plot(calos,stds,'o:')
ax[1].set_ylabel("STDEV [MeV]")
ax[1].set_xlabel("Calo Number")
ax[1].set_title("STDEV For Laser Pulses in Various Calorimeters")
ax[1].grid()

ax[0].plot(calos,means,'o:')
ax[0].set_ylabel("Mean [MeV]")
ax[0].set_xlabel("Calo Number")
ax[0].set_title("Mean For Laser Pulses in Various Calorimeters")
ax[0].grid()

plt.savefig("./images/"+prodString+"/"+prodString+"_laserEnergyMeans_allcalo.png", bbox_inches='tight')
plt.show()

# %%
calos, means, stds = zip(*caloStdVec)

fig, ax = plt.subplots(figsize=(7,5))
fig.tight_layout()
#fig.subplots_adjust(wspace=.25)

plt.errorbar(x=calos,y=means,xerr=0,yerr=stds)
plt.ylabel("Mean [MeV]")
plt.xlabel("Calo Number")
plt.title("Mean For Laser Pulses in Various Calorimeters (With Error Bars)")

plt.show()

# %%
c3 = r.TCanvas("c3","c3",1800,1000)
leg = r.TLegend(0.7,0.72,0.9,0.9)
leg.SetNColumns(3)

for calo in range(1,25): 
    print("Starting calo", calo)

    hi.SetLineColor(calo-1)
    hi.SetLineWidth(3)
    if(calo>3):
        hi.SetLineColor(calo+2)
    if(calo>6):
        hi.SetLineStyle(2)
    if(calo>7):
        hi.SetLineColor(calo+40-12)
    
    hi = f.Get("farline").Get("calo"+str(calo)).Get("laserSyncEnergies")
    hi.SetDirectory(0)
    hi.GetXaxis().SetTitle("Energy [MeV]")
    hi.SetTitle("Laser Energy (All Calos)")
    hi.GetXaxis().SetRangeUser(50000,150000)
    if calo < 1.5:
        hi.Draw()
    else:
        hi.Draw("SAME")
        
    leg.AddEntry(hi ,"Calo "+str(calo), "l")

leg.Draw()

c3.SetLogy()
c3.Draw()
c3.Print("./images/"+prodString+"/"+prodString+"_laserEnergyPulse_allcalo.png")
c3.Print("./images/"+prodString+"/"+prodString+"_laserEnergyPulse_allcalo.root")
# Out:
# Starting calo 1
# Starting calo 2
# Starting calo 3
# Starting calo 4
# Starting calo 5
# Starting calo 6
# Starting calo 7
# Starting calo 8
# Starting calo 9
# Starting calo 10
# Starting calo 11
# Starting calo 12
# Starting calo 13
# Starting calo 14
# Starting calo 15
# Starting calo 16
# Starting calo 17
# Starting calo 18
# Starting calo 19
# Starting calo 20
# Starting calo 21
# Starting calo 22
# Starting calo 23
# Starting calo 24
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_laserEnergyPulse_allcalo.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_laserEnergyPulse_allcalo.root has been created

# %%
for calo in range(1,25):
    print("Starting calo", calo)
    c = r.TCanvas("c","c",4500,2000)
    c.Divide(4,2)
    for i in range(8):
        c.cd(i+1)
        hi = f.Get("farline").Get("calo"+str(calo)).Get("calo"+str(calo)+"EnergyCut"+str(i)+"Energy").Clone()
        hi.Rebin2D(1,1)
        hi.GetXaxis().SetTitle("x")
        hi.GetYaxis().SetTitle("y")
        r.gPad.SetLogz()
        r.gPad.SetRightMargin(0.15)
        hi.GetZaxis().SetRangeUser(1,100000)
        hi.Draw("COLZ")
    c.Draw()
    c.Print("./images/"+prodString+"/"+prodString+"_hitDistribution_calo"+str(calo).zfill(2)+".png")
    c.Print("./images/"+prodString+"/"+prodString+"_hitDistribution_calo"+str(calo).zfill(2)+".root")
# Out:
# Starting calo 1
# Starting calo 2
# Starting calo 3
# Starting calo 4
# Starting calo 5
# Starting calo 6
# Starting calo 7
# Starting calo 8
# Starting calo 9
# Starting calo 10
# Starting calo 11
# Starting calo 12
# Starting calo 13
# Starting calo 14
# Starting calo 15
# Starting calo 16
# Starting calo 17
# Starting calo 18
# Starting calo 19
# Starting calo 20
# Starting calo 21
# Starting calo 22
# Starting calo 23
# Starting calo 24
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo01.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo01.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo02.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo02.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo03.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo03.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo04.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo04.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo05.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo05.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo06.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo06.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo07.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo07.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo08.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo08.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo09.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo09.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo10.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo10.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo11.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo11.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo12.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo12.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo13.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo13.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo14.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo14.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo15.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo15.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo16.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo16.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo17.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo17.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo18.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo18.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo19.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo19.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo20.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo20.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo21.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo21.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo22.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo22.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo23.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo23.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/v9_19_01/v9_19_01_hitDistribution_calo24.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/v9_19_01/v9_19_01_hitDistribution_calo24.root has been created
