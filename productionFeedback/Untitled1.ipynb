# %%
from standardInclude import *
# Out:
# Welcome to JupyROOT 6.12/06
# For interactive plots, run: setint()
# To return to non-interactive plots (default state), run: noint()

# %%
f = r.TFile("./v9_19_01_Endgame/ding.root")

# %%
f.ls()
# Out:
# TFile**		./v9_19_01_Endgame/ding.root
#  TFile*		./v9_19_01_Endgame/ding.root
#   KEY: TCanvas	c1;1	c1

# %%
c1 = f.Get("c1")

# %%
prims = c1.GetListOfPrimitives()
print([x for x in c1.GetListOfPrimitives()])
# Out:
# [<ROOT.TFrame object ("TFrame") at 0x7fffc56968f0>, <ROOT.TH1F object ("htemp") at 0x7fffc56ab7b0>, <ROOT.TPaveText object ("title") at 0x7fffc56dfce0>, <ROOT.TH1F object ("htemp") at 0x7fffc56e0210>]

# %%
h1 = prims[1].Clone("h1")
h2 = prims[3].Clone("h2")

# %%
c = r.TCanvas()
h1.Draw()
h2.Draw("same")
c.Draw()

# %%
h1s = h1.Clone("h1s")
h1s.Scale(1/h1s.GetEntries())

# %%
h2s = h2.Clone("h2s")
h2s.Scale(1/h2s.GetEntries())

# %%
c = r.TCanvas()
h1s.Draw("hist")
h2s.Draw("hist same")
c.SetLogy()
c.Draw()
