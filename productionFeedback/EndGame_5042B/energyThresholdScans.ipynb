# %%
from standardInclude import *

from fit_util import *
from omega_a_fitting import *
from pileup_correction import *
from lost_muon_calculation import *
# Out:
# Welcome to JupyROOT 6.12/06
# For interactive plots, run: setint()
# To return to non-interactive plots (default state), run: noint()

# %%
from energy_threshold_scan import *
# Out:
# /home/jlab/anaconda3/lib/python3.6/site-packages/uncertainties/core.py:537: DeprecationWarning: inspect.getargspec() is deprecated since Python 3.0, use inspect.signature() or inspect.getfullargspec()
#   argspec = inspect.getargspec(f)

# %%
f = r.TFile("./results_EndGame_5042B_Jan14.root")

# %%
energyHists = []
for calo in range(1,25):
    hi = f.Get("farline").Get("calo"+str(calo)).Get("caloEnergyVsTime")
    energyHists.append( hi.Clone("calo"+str(calo)))
    
for i,hi in enumerate(energyHists):
    energyHists[i].Rebin2D(1,2)
    
print(energyHists)
# Out:
# [<ROOT.TH2I object ("calo1") at 0x7f8b15c7c430>, <ROOT.TH2I object ("calo2") at 0x7f8b15d2f230>, <ROOT.TH2I object ("calo3") at 0x7f8b15c8fe20>, <ROOT.TH2I object ("calo4") at 0x7f8b15c90d10>, <ROOT.TH2I object ("calo5") at 0x7f8b15ca5390>, <ROOT.TH2I object ("calo6") at 0x7f8b15ca9b00>, <ROOT.TH2I object ("calo7") at 0x7f8b15c96dd0>, <ROOT.TH2I object ("calo8") at 0x7f8b15ca7230>, <ROOT.TH2I object ("calo9") at 0x7f8b15c94390>, <ROOT.TH2I object ("calo10") at 0x7f8b15caa450>, <ROOT.TH2I object ("calo11") at 0x7f8b15caa860>, <ROOT.TH2I object ("calo12") at 0x7f8b15caac70>, <ROOT.TH2I object ("calo13") at 0x7f8b15c9aa20>, <ROOT.TH2I object ("calo14") at 0x7f8b15c9ae30>, <ROOT.TH2I object ("calo15") at 0x7f8b15c9b240>, <ROOT.TH2I object ("calo16") at 0x7f8b15bfe070>, <ROOT.TH2I object ("calo17") at 0x7f8b15bfe480>, <ROOT.TH2I object ("calo18") at 0x7f8b15bfe890>, <ROOT.TH2I object ("calo19") at 0x7f8b15bfeca0>, <ROOT.TH2I object ("calo20") at 0x7f8b15c7ec70>, <ROOT.TH2I object ("calo21
# ...

# %%
e1_nominal = 1700
deltaE = 200
e2 = 6000
binOrEnergy = "energy"
upperOrLower = "lower"
verbosity = 0

calo = 0

# %%
pars = []
energyScans = []
for calo in range(1,25):
    print("Starting calo", calo)
    ding = EnergyThresholdScan(energyHists[calo-1], e1_nominal, e2, deltaE, binOrEnergy, calo,  upperOrLower, verbosity, 1, 2)
    energyScans.append(ding)
    ding.PlotParameterVsBin(3)
    pars.append( (calo, ding.inflectionPoint) )
# Out:
# Starting calo 1
# Starting calo 2
# Starting calo 3
# Starting calo 4
# Starting calo 5
# Starting calo 6
# Starting calo 7
# Starting calo 8
# Starting calo 9
# Starting calo 10
# Starting calo 11
# Starting calo 12
# Starting calo 13
# Starting calo 14
# Starting calo 15
# Starting calo 16
# Starting calo 17
# Starting calo 18
# Starting calo 19
# Starting calo 20
# Starting calo 21
# Starting calo 22
# Starting calo 23
# Starting calo 24
#  + ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ +
#  +                                                                      +
#  +           You have chose to blind your fitting according to          +
#  +                omega_ref * (1 + (R +/- deltaR) *10^{-6})             +
#  +                                                                      +
#  + ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ +
#  + ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ +
# ...

# %%
print(pars)
# Out:
# [(1, [None, None, None, 1764.8847703062734+/-24.23820129112997, None]), (2, [None, None, None, 1695.113021628926+/-26.171230278021024, None]), (3, [None, None, None, 1671.310361485237+/-27.410735366596878, None]), (4, [None, None, None, 1691.3758409542745+/-28.159163997813998, None]), (5, [None, None, None, 1596.1551116451064+/-48.85779617094438, None]), (6, [None, None, None, 1665.8967700938738+/-26.83322782955444, None]), (7, [None, None, None, 1682.3157947641052+/-31.6695479747207, None]), (8, [None, None, None, 1672.663033705296+/-31.25677554479978, None]), (9, [None, None, None, 1667.2372622730684+/-36.8617882300352, None]), (10, [None, None, None, 1691.1212616401801+/-33.04317832206102, None]), (11, [None, None, None, 1736.5783854695492+/-27.117924004322038, None]), (12, [None, None, None, 1777.991245042601+/-32.80511878662394, None]), (13, [None, None, None, 1768.861306947552+/-23.795877842584613, None]), (14, [None, None, None, 1726.4702445157568+/-27.974033455783122, None]),
# ...

# %%
calos, inflectionPoints = zip(*pars)
plt.plot(calos, [x[3] for x in inflectionPoints])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-e8d3ca2ad1e4> in <module>
#       1 calos, inflectionPoints = zip(*pars)
# ----> 2 plt.plot(calos, [x[3] for x in inflectionPoints])
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...
