# %%
from standardInclude import *
# Out:
# Welcome to JupyROOT 6.12/06
# For interactive plots, run: setint()
# To return to non-interactive plots (default state), run: noint()

# %% [markdown]
# Using hadd.sh, we merged all of these files together into one output, which we will run through now:

# %%
f = r.TFile("./EndGame_5040A/results_EndGame_5040A.root") #processed output of hadd.sh

#check if the directory where we will be saving the images exists
prodString="EndGame_5040A"
directory = os.path.dirname("./images/"+prodString+"/")
if not os.path.exists(directory):
    print("Creating Image Directory:", directory)
    os.makedirs(directory)
else:
    print("Image Directory", directory,"exists. Continuing.")
# Out:
# Image Directory ./images/EndGame_5040A exists. Continuing.

# %%
f.cd("farline/calo1")
#f.ls()
# Out:
# True

# %% [markdown]
# Print all of the embedded histograms.

# %%
c = r.TCanvas("c","c",1800,1000)
c.Divide(2,2)
c.cd(1)
allCaloEnergies = f.Get("farline").Get("allCaloEnergies").Clone()
allCaloEnergies.Draw()
c.Draw()

c.cd(2)
allCaloWiggle = f.Get("farline").Get("allCaloWiggle").Clone()
allCaloWiggle.Draw()
allCaloWiggle.GetXaxis().SetRange(30,350)

c.cd(3)
allCaloTimes = f.Get("farline").Get("allCaloTimes").Clone()
allCaloTimes.GetXaxis().SetRange(30,350)
allCaloTimes.Draw()

c.cd(4)
farlineCtag = f.Get("farline").Get("farlineCTag").Clone()
farlineCtag.Draw()

c.Draw()
c.Print("./images/"+prodString+"/"+prodString+"_farlineHistograms.png")
c.Print("./images/"+prodString+"/"+prodString+"_farlineHistograms.root")

print("{:,}".format(int(allCaloEnergies.GetEntries())), "Entries in these histograms")
print("{:,}".format(int(allCaloWiggle.GetEntries())), "Entries in these histograms")
print("{:,}".format(int(allCaloTimes.GetEntries())), "Entries in these histograms")
print("{:,}".format(int(farlineCtag.GetEntries())), "Entries in these histograms")
# Out:
# 162,368,529 Entries in these histograms
# 32,749,171 Entries in these histograms
# 162,368,529 Entries in these histograms
# 11,318,912 Entries in these histograms
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_farlineHistograms.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_farlineHistograms.root has been created

# %% [markdown]
# # Now lets make a wiggle plot of all of the calos

# %%
# blinded instance
getBlinded = Blinders(FitType.Omega_a, 'This is my fight song. Blinding my plot song.')
def blinded_wiggle(x, p):
    norm  = p[0]
    life  = p[1]
    asym  = p[2]
    R     = p[3]
    phi   = p[4]
    
    time  = x[0]
    omega = getBlinded.paramToFreq(R)
#    omega = myBlinder.paramToFreq(R) unblind version
    
    return norm * math.exp(-time/life) * (1 - asym*math.cos(omega*time + phi))
# Out:
#  + ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ +
#  +                                                                      +
#  +           You have chose to blind your fitting according to          +
#  +                omega_ref * (1 + (R +/- deltaR) *10^{-6})             +
#  +                                                                      +
#  + ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ +

# %%
func = r.TF1("func", blinded_wiggle, 30,600,5)
func.SetParNames('N','#tau','A','R','#phi')
func.SetParameters(700000,64.4,0.4,0,0)
func.SetParLimits(4,-0.001 - 2*math.pi,2*math.pi+0.001)
func.SetLineColor(2)
func.SetNpx(2000)

# %% [markdown]
# ### Five parameter fit

# %%
c2 = r.TCanvas("c2","c2",1200,800)
c2.Divide(2,1)
c2.cd(1)
r.gPad.SetLogy()

r.gStyle.SetOptFit(111)
allCaloWiggle = f.Get("farline").Get("allCaloWiggle").Clone()

print(allCaloWiggle.GetXaxis().GetXmin(),allCaloWiggle.GetXaxis().GetXmax())
allCaloWiggle.GetXaxis().SetLimits(allCaloWiggle.GetXaxis().GetXmin() / 1000 * 1.25,allCaloWiggle.GetXaxis().GetXmax() / 1000 * 1.25)
print(allCaloWiggle.GetXaxis().GetXmin(),allCaloWiggle.GetXaxis().GetXmax())
allCaloWiggle.GetXaxis().SetTitle("Time [#mus]")

residuals = allCaloWiggle.Clone() # this will be filled with the fit residuals later

for fit in range(2):
    print("Sarting fit:", fit+1)
    allCaloWiggle.Fit("func","REM")

    
chiSqAll = ( ( func.GetNDF(),
              func.GetChisquare(),
              func.GetProb() ) )
    
allCaloWiggle.Draw()

c2.cd(2)
ding =  allCaloWiggle.Clone()
ding.GetXaxis().SetRangeUser(100,125)
ding.Draw()

r.gPad.SetLogy()
c2.Draw()
# Out:
# 0.0 560000.0
# 0.0 700.0
# Sarting fit: 1
# Sarting fit: 2
#  FCN=4064.45 FROM MINOS     STATUS=SUCCESSFUL     36 CALLS         492 TOTAL
#                      EDM=4.66378e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  N            6.92797e+04   2.86238e+01  -2.37329e-03  -1.02301e-09
#    2  #tau         6.42011e+01   1.49516e-02  -9.66402e-07   1.05363e-06
#    3  A            4.02115e-01   3.05706e-04  -1.06574e-07   3.78909e-05
#    4  R           -1.14123e+01   8.59265e+00   3.65023e-05  -3.87456e-08
#    5  #phi        -1.06434e+00   1.40566e-03   1.40566e-03   6.70653e-03
#  FCN=4064.45 FROM MINOS     STATUS=SUCCESSFUL     36 CALLS         284 TOTAL
#                      EDM=2.9114e-11    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  N            6.92797e+04   2.86229e+01  -2.11577e-03  -8.75042e-10
#    2  #tau         6.42011e+01   1.49511e-02  -1.15402e-06  -1.09895e-06
#    3  A            4.02115e-01   3.05706e-04  -1.06411e-07   4.17852e-05
#    4  R           -1.14123e+01   8.59265e+00  -2.85208e-05  -3.89369e-08
#    5  #phi        -1.06434e+00   1.40566e-03   1.40566e-03   6.57205e-03

# %%
#The class calculates the  difference between the histogram and the fit function at each point 
#    and divides it by the uncertainty.
c3 = r.TCanvas("c","c",1600,600)
allCaloWiggle.Draw()
c3.SetLogy()
c3.Draw()

rp1 = r.TRatioPlot(allCaloWiggle)
rp1.Draw()
rp1.GetLowerRefYaxis().SetTitle("Residual")
rp1.GetLowerRefYaxis().SetRangeUser(-7,7)

allCaloWiggle.GetXaxis().SetRangeUser(30,150)

c3.Update()
c3.Draw()
c3.Print("./images/"+prodString+"/"+prodString+"_TmethodWiggleFitAllCalos.png")
c3.Print("./images/"+prodString+"/"+prodString+"_TmethodWiggleFitAllCalos.root")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_TmethodWiggleFitAllCalos.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_TmethodWiggleFitAllCalos.root has been created

# %% [markdown]
# ### Fourier transform of the 5-parameter residuals.

# %%
c3 = r.TCanvas()
residuals5param = residuals.Clone() # this will hold the residials from the 5-parameter fit
nBins = residuals5param.GetSize() - 2 #total number of bins excluding over/underflow
print(nBins)
residVec = []
for i in range(nBins):
    binCenterX = allCaloWiggle.GetXaxis().GetBinCenter(i)
    if (binCenterX > 30 and binCenterX < 600):
        residVec.append( (binCenterX, allCaloWiggle.GetBinContent(i) - func.Eval(binCenterX) ) )
        residuals5param.SetBinContent(i, allCaloWiggle.GetBinContent(i) - func.Eval(binCenterX))
    else:
        residuals5param.SetBinContent(i, 0)

print(len(residVec),[residVec[i] for i in range(5)])
centers, bins = zip(*residVec)
htest = r.TH1D("htest","htest",len(residVec),centers[0],centers[len(residVec)-1])
for i,ding in enumerate(bins):
    htest.SetBinContent(i, ding)
    
residuals5param.Delete()
residuals5param = htest
nBins = residuals5param.GetSize() - 2 #total number of bins excluding over/underflow

#apply a windows function to try to get rid of the imaginary peaks
welchVec = []
for i in range(nBins):
    unwindowed = residuals5param.GetBinContent(i)
    welch = 1 #- ( ( i - (nBins - 1) / 2) / ((nBins - 1) / 2) )**2
    welchVec.append(welch)
    residuals5param.SetBinContent(i, unwindowed *  welch)
    
residuals5param.Draw()
residuals5param.GetXaxis().SetRangeUser(30,700)
residuals5param.SetTitle("(Windowed) Residuals of the 5-parameter Fit")
c3.Draw()    
    
hxform = r.TH1D()
hxform = 0
r.TVirtualFFT.SetTransform(0)
hxform = residuals5param.FFT(hxform,"MAG P")
hxform.SetTitle("Magnitude of the First Transform (5-Parameter Residuals)")
#NOTE: for "real" frequencies you have to divide the x-axes range with the range of your function
#    y-axes has to be rescaled by a factor of 1/SQRT(n) to be right: this is not done automatically!
normXform = hxform.GetEntries()
hxform.Scale(1/normXform)
c2 = r.TCanvas()
c2.cd()
#c2.SetLogy()
hxform.GetXaxis().SetTitle("Frequency (MHz)")
hxform.GetYaxis().SetTitle("Arb. Units")
hxform.Draw("HIST P0 L")
c2.Draw()

Npart = residuals5param.GetSize() - 2
minBinCenter = residuals5param.GetXaxis().GetBinCenter(0)
maxBinCenter = residuals5param.GetXaxis().GetBinCenter(Npart)

capT = maxBinCenter - minBinCenter
print(Npart, capT, minBinCenter, maxBinCenter)
deltaT = capT/Npart #microseconds
deltaF = 1/capT
print(deltaT, deltaF)

deltaTns = deltaT*1000 #nanoseconds
limmaxHz = (1/(deltaTns*math.pow(10.0,-9)))
limmaxMHz = limmaxHz / math.pow(10.0,6)

limmax = 2*deltaF*Npart #400-25
print(limmax,limmaxMHz)
#hxform.GetXaxis().SetLimits(0,limmax)
nbins = residuals5param.GetSize() - 2
hxform.SetBins(Npart,0,limmaxMHz)
hxform.GetXaxis().SetRangeUser(0,limmaxMHz/2)
#hxform.GetXaxis().SetRangeUser(0,1.4)

residuals5paramXform = hxform.Clone()

#c2.SetLogy()
c2.Draw()
c2.Print("./images/"+prodString+"/"+prodString+"_5ParamResiduals.png")
c2.Print("./images/"+prodString+"/"+prodString+"_5ParamResiduals.root")
# Out:
# 4700
# 3828 [(30.010638297872337, 63.87321164691093), (30.159574468085104, 400.1742125970268), (30.30851063829787, 69.29663108567911), (30.457446808510635, -23.70929183237604), (30.606382978723403, 167.24733855183877)]
# 3828 569.9787234042552 29.93618966628871 599.9149130705439
# 0.1488972631672558 0.0017544514539549819
# 13.43208033147934 6.71604016573967
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_5ParamResiduals.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_5ParamResiduals.root has been created

# %% [markdown]
# Lets fit some of these peaks, see if we can isolate the exact frequencies

# %% [raw]
# def peak_fit_bw(x, p):
#     return p[0]*r.TMath.BreitWigner(x[0],p[1],p[2]) + p[3]
#
# func1 = r.TF1("peak1", peak_fit_bw, .39,.45,4)
# func1.SetParNames('A','Mean','#gamma','+ C')
# func1.SetParameters(1,.4,.1,0)
# func1.SetParLimits(1,.4,.45)
# func1.SetLineColor(2)
# func1.SetNpx(1000)
#
# func2 = r.TF1("peak2", peak_fit_bw, 0.6,0.67,4)
# func2.SetParNames('A','Mean','#gamma','+ C')
# func2.SetParameters(.3,0.64,-1)
# func2.SetParLimits(1,0.63,0.67)
#
# func3 = r.TF1("peak3", peak_fit_bw, 0.15,0.21,4)
# func3.SetParNames('A','Mean','#gamma','+ C')
# func3.SetParameters(.3,0.18,-1)
#
# func4 = r.TF1("peak4", peak_fit_bw,2,2.2,4)
# func4.SetParNames('A','Mean','#gamma','+ C')
# func4.SetParameters(.3,2.1,-1)
# func4.SetParLimits(1,2.0,2.2)
#
# func5 = r.TF1("peak5", peak_fit_bw,2.5,2.55,4)
# func5.SetParNames('A','Mean','#gamma','+ C')
# func5.SetParameters(.3,2.5,-1)
# func5.SetParLimits(1,2.5,2.54)
#
# func6 = r.TF1("peak6", peak_fit_bw,.20,.25,4)
# func6.SetParNames('A','Mean','#gamma','+ C')
# func6.SetParameters(.3,.22,-1)
# func6.SetParLimits(1,.22,.24)

# %% [raw]
# c = r.TCanvas("c","c",1200,400)
# hxform.GetXaxis().SetRangeUser(0,limmaxMHz/2)
# hxform.Draw("HIST P0 L")
#
# for i in range(3):
#     hxform.Fit("peak1","REMBQ")
#     hxform.Fit("peak2","REMBQ")
#     hxform.Fit("peak3","REMBQ")
#     hxform.Fit("peak4","REMBQ")
#     hxform.Fit("peak5","REMBQ")
#     hxform.Fit("peak6","REMBQ")
#
# func1.Draw("SAME")
# func2.Draw("SAME")
# func3.Draw("SAME")
# func4.Draw("SAME")
# func5.Draw("SAME")
# func6.Draw("SAME")
#
# print("Peaks Located at: ")
# print("    ",func3.GetParameter(1), "+/-", func3.GetParError(1),"MHz")
# print("    ",func6.GetParameter(1), "+/-", func6.GetParError(1),"MHz")
# print("    ",func1.GetParameter(1), "+/-", func1.GetParError(1),"MHz")
# print("    ",func2.GetParameter(1), "+/-", func2.GetParError(1),"MHz")
# print("    ",func4.GetParameter(1), "+/-", func4.GetParError(1),"MHz")
# print("    ",func5.GetParameter(1), "+/-", func5.GetParError(1),"MHz")
#
# pt = r.TPaveText(2.0,50,3.7,96)
# pt.AddText("Peaks Located at: ")
# pt.AddText("    "+str(func3.GetParameter(1))+" +/- "+str(func3.GetParError(1))+" MHz")
# pt.AddText("    "+str(func6.GetParameter(1))+" +/- "+str(func6.GetParError(1))+" MHz")
# pt.AddText("    "+str(func1.GetParameter(1))+" +/- "+str(func1.GetParError(1))+" MHz")
# pt.AddText("    "+str(func2.GetParameter(1))+" +/- "+str(func2.GetParError(1))+" MHz")
# pt.AddText("    "+str(func4.GetParameter(1))+" +/- "+str(func4.GetParError(1))+" MHz")
# pt.AddText("    "+str(func5.GetParameter(1))+" +/- "+str(func5.GetParError(1))+" MHz")
# pt.Draw()
#
# c.Draw()
# c.SetGrid()
# c.Print("./images/"+prodString+"/"+prodString+"_5ParamResiduals_WithFits.png")
# c.Print("./images/"+prodString+"/"+prodString+"_5ParamResiduals_WithFits.root")

# %% [markdown]
# double check the root fft result with the python fft module

# %%
fig, ax = plt.subplots(figsize=(12, 5))
plt.plot([0]+welchVec+[0],label='Square (No Window)')
plt.title("Plot of the Window Function used")
plt.xlabel("Entries")
plt.legend()
plt.show()

ding = np.fft.fft(np.array(bins))

n = len(bins)
d = (centers[1] - centers[0])*math.pow(10.0,-6)

freq = np.fft.fftfreq(n, d)


fig, ax = plt.subplots(figsize=(12, 5))
plt.plot([x/(10**6) for x in freq],np.abs(ding),'.:',label='FFT 5-param')
plt.title("FFT Using Python")
plt.xlabel("Frequency [MHz]")
plt.xlim(0,6.7157787731503555 / 2)# *10.**6)
plt.legend()
plt.show()

# %%
print(len(residVec),[residVec[i] for i in range(5)])
centers, bins = zip(*residVec)
htest = r.TH1D("htest","htest",len(residVec),centers[0],centers[len(residVec)-1])
for i,ding in enumerate(bins):
    htest.SetBinContent(i, ding)
    
c = r.TCanvas()
htest.Draw()
c.Draw()
c.Print("hi.root")
# Out:
# 3828 [(30.010638297872337, 63.87321164691093), (30.159574468085104, 400.1742125970268), (30.30851063829787, 69.29663108567911), (30.457446808510635, -23.70929183237604), (30.606382978723403, 167.24733855183877)]
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: htest (Potential memory leak).
# Info in <TCanvas::SaveAs>: ROOT file hi.root has been created

# %% [raw]
# ### 13 parameter fit

# %% [raw]
# def blinded_wiggle_cbo(x, p):
#     norm     = p[0]
#     life     = p[1]
#     asym     = p[2]
#     R        = p[3]
#     phi      = p[4]
#     A1       = p[5]
#     A2       = p[6]
#     A3       = p[7]
#     lifeCBO  = p[8]
#     omegaCBO = p[9]
#     phiCBO1  = p[10]
#     phiCBO2  = p[11]
#     phiCBO3  = p[12]
#
#     time  = x[0]
#     omega = getBlinded.paramToFreq(R)
#
#     cCBO = 1-math.exp(-time/lifeCBO)*A1*math.cos(omegaCBO*time + phiCBO1)
#     ACBO = asym * (1 - math.exp(-time/lifeCBO) * A2 * math.cos(omegaCBO*time + phiCBO2))
#     phiCBO = phi + math.exp(-time/lifeCBO)*A3*math.cos(omegaCBO*time + phiCBO3)
#
#     return norm * math.exp(-time/life) * cCBO * (1 - ACBO*math.cos(omega*time + phiCBO))

# %% [raw]
# func13 = r.TF1("func13", blinded_wiggle_cbo, 30,500,13)
# func13.SetParNames('N','#tau','A',
#                    'R','#phi','A_{1}',
#                    'A_{2}','A_{3}','#tau_{CBO}',
#                    '#omega_{CBO}','#phi_{CBO - 1}')
# func13.SetParName(11,'#phi_{CBO - 2}')
# func13.SetParName(12,'#phi_{CBO - 3}')
# #func13.SetParLimits(4,-6.3,6.3) #Phases should be restricted to +/- 2Pi
# #func13.SetParLimits(8,100,500) #Avoid divide by 0 error
# func13.SetParLimits(8,0.0000001,100000000) #Avoid divide by 0 error
# #func13.SetParLimits(10,-6.3,6.3)
# #func13.SetParLimits(11,-6.3,6.3)
# #func13.SetParLimits(12,-6.3,6.3)
#
# #initial guesses, then updated with the first round of fit results
# #func13.SetParameters(1500,64.4,0.4,0,0,1,1,1,.01,.01,0)
# #func13.SetParameter(11,0)
# #func13.SetParameter(12,0)
# func13.SetParameters(100000, 64.32689658986958, -0.41149191856871803,
#                      -11.31981267111425, -4.201648334505292, -0.666502391530784,
#                      0.6927259503578, -0.38908021438317, 220,
#                      4.1, 0.4745581246420292)
# func13.SetParameter(11, 6.299934663288357)
# func13.SetParameter(12, 0.28579778778899545)
# for i in range(4):
#     func13.SetParameter(i, func.GetParameter(i))
# #func13.FixParameter(12,0) #currently this parameter is fixed, as it doesn't behave well if left to wander on its own
#
#
# func13.SetLineColor(2)
# func13.SetNpx(2000)

# %% [raw]
# c2 = r.TCanvas("c2","c2",1200,800)
# c2.Divide(2,1)
# c2.cd(1)
# r.gPad.SetLogy()
#
# r.gStyle.SetOptFit(111)
# allCaloWiggle13 = f.Get("farline").Get("allCaloWiggle").Clone()
#
# allCaloWiggle13.GetXaxis().SetLimits(allCaloWiggle13.GetXaxis().GetXmin() / 1000 * 1.25,
#                                      allCaloWiggle13.GetXaxis().GetXmax() / 1000 * 1.25)
# allCaloWiggle13.GetXaxis().SetTitle("Time [#mus]")
#
# residuals13 = allCaloWiggle13.Clone() # this will be filled with the fit residuals later
#
# for i in range(2): #the fit won't converge the first time. Don't look at me like that!
#     print("Starting Fit:",i+1)
#     allCaloWiggle13.Fit("func13","REMB")
#
# allCaloWiggle13.Draw()
#
# c2.cd(2)
# ding13 =  allCaloWiggle13.Clone()
# ding13.GetXaxis().SetRangeUser(100,125)
# ding13.Draw()
#
# r.gPad.SetLogy()
# c2.Draw()

# %% [raw]
# #The class calculates the  difference between the histogram and the fit function at each point
# #    and divides it by the uncertainty.
# c3 = r.TCanvas("c","c",1600,600)
# allCaloWiggle13.Draw()
# c3.SetLogy()
# c3.Draw()
#
# rp13 = r.TRatioPlot(allCaloWiggle13)
# rp13.Draw()
# rp13.GetLowerRefYaxis().SetTitle("Residual")
# rp13.GetLowerRefYaxis().SetRangeUser(-5,5)
#
# allCaloWiggle13.GetXaxis().SetRangeUser(30,150)
#
# c3.Update()
# c3.Draw()
# c3.Print("./images/"+prodString+"/"+prodString+"_TmethodWiggleFitAllCalos_13Parameter.png")
# c3.Print("./images/"+prodString+"/"+prodString+"_TmethodWiggleFitAllCalos_13Parameter.root")

# %% [raw]
# ### Fourier xform of the residuals from the 13 parameter fit

# %% [raw]
# c3 = r.TCanvas()
# residuals13param = residuals13.Clone() # this will hold the residials from the 5-parameter fit
# nBins = residuals13param.GetSize() - 2 #total number of bins excluding over/underflow
# print(nBins)
# for i in range(nBins):
#     binCenterX = allCaloWiggle13.GetXaxis().GetBinCenter(i)
#     if (binCenterX > 30):
#         residuals13param.SetBinContent(i, allCaloWiggle13.GetBinContent(i) - func13.Eval(binCenterX))
#     else:
#         residuals13param.SetBinContent(i, 0)
#
# residuals13param.Draw()
# residuals13param.GetXaxis().SetRangeUser(30,350)
# residuals13param.SetTitle("Residuals of the 13-parameter Fit")
# c3.Draw()
#
# print(residuals13param.GetBinWidth(2), "wide")
#
# hxform = r.TH1D()
# hxform = 0
# r.TVirtualFFT.SetTransform(0)
# hxform = residuals13param.FFT(hxform,"MAG P")
# hxform.SetTitle("Magnitude of the First Transform (13 Parameter Residuals)")
# #NOTE: for "real" frequencies you have to divide the x-axes range with the range of your function
# #    y-axes has to be rescaled by a factor of 1/SQRT(n) to be right: this is not done automatically!
# normXform = hxform.GetEntries()
# hxform.Scale(1/normXform)
# c2 = r.TCanvas()
# c2.cd()
# #c2.SetLogy()
# hxform.GetXaxis().SetTitle("Frequency (MHz)")
# hxform.GetYaxis().SetTitle("Arb. Units")
# hxform.Draw("HIST P0 L")
# c2.Draw()
#
# Npart = residuals13param.GetSize() - 2
# minBinCenter = residuals13param.GetXaxis().GetBinCenter(0)
# maxBinCenter = residuals13param.GetXaxis().GetBinCenter(Npart)
#
# capT = maxBinCenter - minBinCenter
# print(Npart, capT, minBinCenter, maxBinCenter)
# deltaT = capT/Npart #microseconds
# deltaF = 1/capT
# print(deltaT, deltaF)
#
# deltaTns = deltaT*1000 #nanoseconds
# limmaxHz = (1/(deltaTns*math.pow(10.0,-9)))
# limmaxMHz = limmaxHz / math.pow(10,6)
#
# limmax = 2*deltaF*Npart #400-25
# print(limmax,limmaxMHz)
# nbins = residuals13param.GetSize() - 2
# hxform.SetBins(Npart,0,limmaxMHz)
# hxform.GetXaxis().SetRangeUser(0,limmaxMHz/2)
#
# c2.Draw()
# c2.Print("./images/"+prodString+"/"+prodString+"_13ParamResiduals.png")
# c2.Print("./images/"+prodString+"/"+prodString+"_13ParamResiduals.root")

# %% [raw]
# ### Comaprison of the 5 and 13 parameter fit residual FFT's

# %% [raw]
# c5 = r.TCanvas("c5","c5",1200,800)
# c5.Divide(1,2)
# c5.cd(1)
# #r.gPad.SetLogy()
# r.gPad.SetGrid()
#
# residuals5paramXform.SetLineColor(9)
# residuals5paramXform.SetMarkerColor(9)
# residuals5paramXform.Draw("HIST P0 L")
# residuals5paramXform.GetYaxis().SetRangeUser(0.1,75)
# c5.cd(2)
# #r.gPad.SetLogy()
# r.gPad.SetGrid()
# hxform.Draw("HIST P0 L")
# hxform.GetYaxis().SetRangeUser(0.1,75)
#
# residuals13paramXform = hxform.Clone()
#
# c5.Draw()
#
# c6 = r.TCanvas("c6","c6",1200,400)
# residuals5paramXform.Draw("HIST P0 L")
# hxform.SetLineColor(2)
# hxform.SetMarkerColor(2)
# hxform.Draw("HIST P0 L SAME")
# leg = r.TLegend(0.65,0.8,0.9,0.9)
# leg.AddEntry(residuals5paramXform ,"5-Parameter Residuals FFT", "l")
# leg.AddEntry(hxform ,"13-Parameter Residuals FFT", "l")
# leg.Draw()
# c6.SetGrid()
# c6.Draw()
#
# c6.Print("./images/"+prodString+"/"+prodString+"_ResidualComparison5_13.png")
# c6.Print("./images/"+prodString+"/"+prodString+"_ResidualComparison5_13.root")

# %% [raw]
# parameters13 = []
# for i in range(13):
#     parameters13.append( (func13.GetParameter(i) , func13.GetParError(i)) )
# #print(parameters13)
# par13,parErr13 = zip(*parameters13)
# print(par13)

# %% [raw]
# ---
#
# ### Now lets add in the veritcal waist term

# %% [raw]
# def blinded_wiggle_cbo_vw(x, p):
#     norm     = p[0]
#     life     = p[1]
#     asym     = p[2]
#     R        = p[3]
#     phi      = p[4]
#     A1       = p[5]
#     A2       = p[6]
#     A3       = p[7]
#     lifeCBO  = p[8]
#     omegaCBO = p[9]
#     phiCBO1  = p[10]
#     phiCBO2  = p[11]
#     phiCBO3  = p[12]
#     Avw      = p[13]
#     lifeVW   = p[14]
#     omegaVW  = p[15]
#     phiVW    = p[16]
#
#     time  = x[0]
#     omega = getBlinded.paramToFreq(R)
#
#     cCBO = 1-math.exp(-time/lifeCBO)*A1*math.cos(omegaCBO*time + phiCBO1)
#     ACBO = asym * (1 - math.exp(-time/lifeCBO) * A2 * math.cos(omegaCBO*time + phiCBO2))
#     phiCBO = phi + math.exp(-time/lifeCBO)*A3*math.cos(omegaCBO*time + phiCBO3)
#     cVW = 1 - Avw*math.exp(-time/lifeVW)*math.cos(omegaVW*time + phiVW)
#
#     return norm * math.exp(-time/life) * cCBO * cVW * (1 - ACBO*math.cos(omega*time + phiCBO))

# %% [raw]
# func17 = r.TF1("func17", blinded_wiggle_cbo_vw, 30,650,17)
# func17.SetParNames('N','#tau','A',
#                    'R','#phi','A_{1}',
#                    'A_{2}','A_{3}','#tau_{CBO}',
#                    '#omega_{CBO}','#phi_{CBO - 1}')
# func17.SetParName(11,'#phi_{CBO - 2}')
# func17.SetParName(12,'#phi_{CBO - 3}')
# func17.SetParName(13,'A_{VW}')
# func17.SetParName(14,'#tau_{VW}')
# func17.SetParName(15,'#omega_{VW}')
# func17.SetParName(16,'#phi_{VW}')
# func17.SetParLimits(8,0.0000001,100000000) #Avoid divide by 0 error
# func17.SetParLimits(14,0.0000001,100000000) #Avoid divide by 0 error
# #func17.SetParLimits(10,-6.3,6.3)
# #func17.SetParLimits(11,-6.3,6.3)
# #func17.SetParLimits(12,-6.3,6.3)
#
# #initial guesses, then updated with the first round of fit results
# for i in range(13):
#     func17.SetParameter(i, func13.GetParameter(i))
# func17.SetParameter(13, 1)
# func17.SetParameter(14, 24)
# func17.SetParameter(15, 14.41)
# func17.SetParameter(16, 0)
#
# func17.SetParameter(9, 2.307 ) #omega_cbo
#
#
# func17.SetLineColor(4)
# func17.SetNpx(2000)

# %% [raw]
# c2 = r.TCanvas("c2","c2",1200,800)
# c2.Divide(2,1)
# c2.cd(1)
# r.gPad.SetLogy()
#
# r.gStyle.SetOptFit(111)
# allCaloWiggle17 = f.Get("farline").Get("allCaloWiggle").Clone()
#
# allCaloWiggle17.GetXaxis().SetLimits(allCaloWiggle17.GetXaxis().GetXmin() / 1000 * 1.25,
#                                      allCaloWiggle17.GetXaxis().GetXmax() / 1000 * 1.25)
# allCaloWiggle17.GetXaxis().SetTitle("Time [#mus]")
#
# residuals17 = allCaloWiggle17.Clone() # this will be filled with the fit residuals later
#
# for i in range(2): #the fit won't converge the first time. Don't look at me like that!
#     print("Starting Fit:",i+1)
#     allCaloWiggle17.Fit("func17","REMB")
#
#
# allCaloWiggle17.Draw()
#
# c2.cd(2)
# ding17 =  allCaloWiggle17.Clone()
# ding17.GetXaxis().SetRangeUser(100,125)
# ding17.Draw()
#
# r.gPad.SetLogy()
# c2.Draw()

# %% [raw]
# #The class calculates the  difference between the histogram and the fit function at each point
# #    and divides it by the uncertainty.
# c3 = r.TCanvas("c","c",1600,600)
# allCaloWiggle17.Draw()
# c3.SetLogy()
# c3.Draw()
#
# rp17 = r.TRatioPlot(allCaloWiggle17)
# rp17.Draw()
# rp17.GetLowerRefYaxis().SetTitle("Residual")
# rp17.GetLowerRefYaxis().SetRangeUser(-5,5)
#
# allCaloWiggle17.GetXaxis().SetRangeUser(30,150)
#
# c3.Update()
# c3.Draw()
# c3.Print("./images/"+prodString+"/"+prodString+"_TmethodWiggleFitAllCalos_17Parameter.png")
# c3.Print("./images/"+prodString+"/"+prodString+"_TmethodWiggleFitAllCalos_17Parameter.root")

# %% [raw]
# for i in range(17):
#     print(func17.GetParName(i), " = ", func17.GetParameter(i), "+/-", func17.GetParError(i))

# %% [raw]
# ### Fourier xform of the residuals from the 17 parameter fit

# %% [raw]
# c3 = r.TCanvas()
# residuals17param = residuals17.Clone() # this will hold the residials from the 5-parameter fit
# nBins = residuals17param.GetSize() - 2 #total number of bins excluding over/underflow
# print(nBins)
# for i in range(nBins):
#     binCenterX = allCaloWiggle17.GetXaxis().GetBinCenter(i)
#     if (binCenterX > 30):
#         residuals17param.SetBinContent(i, allCaloWiggle17.GetBinContent(i) - func17.Eval(binCenterX))
#     else:
#         residuals17param.SetBinContent(i, 0)
#
# residuals17param.Draw()
# residuals17param.GetXaxis().SetRangeUser(30,350)
# residuals17param.SetTitle("Residuals of the 17-parameter Fit")
# c3.Draw()
#
# print(residuals17param.GetBinWidth(2), "wide")
#
# hxform = r.TH1D()
# hxform = 0
# r.TVirtualFFT.SetTransform(0)
# hxform = residuals17param.FFT(hxform,"MAG P")
# hxform.SetTitle("Magnitude of the First Transform (17 Parameter Residuals)")
# #NOTE: for "real" frequencies you have to divide the x-axes range with the range of your function
# #    y-axes has to be rescaled by a factor of 1/SQRT(n) to be right: this is not done automatically!
# normXform = hxform.GetEntries()
# hxform.Scale(1/normXform)
# c2 = r.TCanvas()
# c2.cd()
# #c2.SetLogy()
# hxform.GetXaxis().SetTitle("Frequency (MHz)")
# hxform.GetYaxis().SetTitle("Arb. Units")
# hxform.Draw("HIST P0 L")
# c2.Draw()
#
# Npart = residuals17param.GetSize() - 2
# minBinCenter = residuals17param.GetXaxis().GetBinCenter(0)
# maxBinCenter = residuals17param.GetXaxis().GetBinCenter(Npart)
#
# capT = maxBinCenter - minBinCenter
# print(Npart, capT, minBinCenter, maxBinCenter)
# deltaT = capT/Npart #microseconds
# deltaF = 1/capT
# print(deltaT, deltaF)
#
# deltaTns = deltaT*1000 #nanoseconds
# limmaxHz = (1/(deltaTns*math.pow(10.0,-9)))
# limmaxMHz = limmaxHz / math.pow(10,6)
#
# limmax = 2*deltaF*Npart #400-25
# print(limmax,limmaxMHz)
# nbins = residuals17param.GetSize() - 2
# hxform.SetBins(Npart,0,limmaxMHz)
# hxform.GetXaxis().SetRangeUser(0,limmaxMHz/2)
# residuals17paramXform = hxform.Clone()
#
# c2.Draw()
# c2.Print("./images/"+prodString+"/"+prodString+"_17ParamResiduals.png")
# c2.Print("./images/"+prodString+"/"+prodString+"_17ParamResiduals.root")

# %% [raw]
# c6 = r.TCanvas("c6","c6",1200,400)
# residuals5paramXform.Draw("HIST P0 L")
#
# residuals13paramXform.SetLineColor(2)
# residuals13paramXform.SetMarkerColor(2)
# residuals13paramXform.Draw("HIST P0 L SAME")
#
# residuals17paramXform.SetLineColor(3)
# residuals17paramXform.Draw("HIST P0 L SAME")
# leg = r.TLegend(0.65,0.7,0.9,0.9)
# leg.AddEntry(residuals5paramXform ,"5-Parameter Residuals FFT", "l")
# leg.AddEntry(residuals13paramXform ,"13-Parameter Residuals (CBO Only) FFT", "l")
# leg.AddEntry(residuals17paramXform ,"17-Parameter Residuals (CBO+VW) FFT", "l")
# leg.Draw()
# c6.SetGrid()
# c6.Draw()
#
# c6.Print("./images/"+prodString+"/"+prodString+"_ResidualComparison5_13_17.png")
# c6.Print("./images/"+prodString+"/"+prodString+"_ResidualComparison5_13_17.root")

# %% [markdown]
# ___
#
# # Now lets make some plots from the individual calorimeters.

# %%
caloNum = 1

wiggleFitParamVec = []
caloiWiggleVec = []
wiggleFitChiSquareVec = []

for caloNum in range(1,25):
    print("Starting Calo", caloNum)
    
    c4 = r.TCanvas("c4","c4",2400,800)
    c4.Divide(4,2)

    c4.cd(1)
    caloiEnergy = f.Get("farline").Get("calo"+str(caloNum)).Get("energy").Clone()
    caloiEnergy.Draw()
    r.gPad.SetLogy()
    c4.Draw()

    c4.cd(2)
    caloiXtalHits = f.Get("farline").Get("calo"+str(caloNum)).Get("hitPositions").Clone()
    caloiXtalHits.Draw("colz")
    r.gPad.SetLogz()

    c4.cd(3)
    caloiWiggle = f.Get("farline").Get("calo"+str(caloNum)).Get("wiggle").Clone()
    caloiWiggle.GetXaxis().SetRangeUser(30000,300000)
    caloiWiggle.Draw()
    r.gPad.SetLogy()

    caloiWiggle.GetXaxis().SetLimits(caloiWiggle.GetXaxis().GetXmin() / 1000 * 1.25,caloiWiggle.GetXaxis().GetXmax() / 1000 * 1.25)
    caloiWiggle.GetXaxis().SetTitle("Time [#mus]")
    
    for i in range(2):
        caloiWiggle.Fit("func","REMQ")
    
    wiggleFitParamVec.append( ( func.GetParameter(3) , func.GetParError(3) ) )
    wiggleFitChiSquareVec.append( ( func.GetNDF(),
                                  func.GetChisquare(),
                                  func.GetProb() ) )
    caloiWiggleVec.append( caloiWiggle.Clone("calo"+str(caloNum).zfill(2)+" Wiggle Plot") )

    c4.cd(4)
    caloiTimes = f.Get("farline").Get("calo"+str(caloNum)).Get("times").Clone()
    caloiTimes.GetXaxis().SetRangeUser(0,60000)
    caloiTimes.Draw()

    c4.cd(5)
    caloiXtal35Energy = f.Get("farline").Get("calo"+str(caloNum)).Get("xtal35Energy").Clone()
    caloiXtal35Energy.Draw()

    c4.cd(6)
    caloiXtal31Energy = f.Get("farline").Get("calo"+str(caloNum)).Get("xtal31Energy").Clone()
    caloiXtal31Energy.Draw()

    c4.cd(7)
    caloiXtal0Energy = f.Get("farline").Get("calo"+str(caloNum)).Get("xtal0Energy").Clone()
    caloiXtal0Energy.Draw()

    c4.cd(8)
    caloiXtal53Energy = f.Get("farline").Get("calo"+str(caloNum)).Get("xtal53Energy").Clone()
    caloiXtal53Energy.Draw()

    c4.Draw()
    c4.Print("./images/"+prodString+"/"+prodString+"_calo"+str(caloNum).zfill(2)+"_FullSet.png")
    c4.Print("./images/"+prodString+"/"+prodString+"_calo"+str(caloNum).zfill(2)+"_FullSet.root")
# Out:
# Starting Calo 1
# Starting Calo 2
# Starting Calo 3
# Starting Calo 4
# Starting Calo 5
# Starting Calo 6
# Starting Calo 7
# Starting Calo 8
# Starting Calo 9
# Starting Calo 10
# Starting Calo 11
# Starting Calo 12
# Starting Calo 13
# Starting Calo 14
# Starting Calo 15
# Starting Calo 16
# Starting Calo 17
# Starting Calo 18
# Starting Calo 19
# Starting Calo 20
# Starting Calo 21
# Starting Calo 22
# Starting Calo 23
# Starting Calo 24
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo01_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo01_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo02_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo02_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo03_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo03_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo04_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo04_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo05_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo05_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo06_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo06_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo07_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo07_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo08_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo08_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo09_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo09_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo10_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo10_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo11_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo11_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo12_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo12_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo13_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo13_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo14_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo14_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo15_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo15_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo16_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo16_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo17_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo17_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo18_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo18_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo19_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo19_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo20_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo20_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo21_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo21_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo22_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo22_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo23_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo23_FullSet.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c4
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_calo24_FullSet.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_calo24_FullSet.root has been created

# %%
pars, parErrs = zip(*wiggleFitParamVec)
calos = [x for x in range(1,25)]
plt.errorbar(x=calos,y=pars,yerr=parErrs,ls='none',capsize=3,capthick=1,marker='o',markersize=5)
plt.title(prodString+"\nVariation of R parameter vs. Calo Number for 5-Parameter Fit")
plt.xlabel("Calo Number")
plt.ylabel("R")
plt.show()

# %% [raw]
# This is some pretty worrying variation in the R value, but not entirely unexpected.
#
# We can also look at the rediced chi square for each of the calos.

# %%
ndfs, chisqs, probs = zip(*wiggleFitChiSquareVec)
plt.plot(calos,[x / ndfs[i] for i,x in enumerate(chisqs)],'o:',label='Individual Calos')

ding = [chiSqAll[1]/chiSqAll[0] for i in range(24)]
plt.plot(calos, ding, '-',label="All Calos")

plt.ylabel("$\chi^2$ / NDF")
plt.xlabel("Calorimeter Number")
plt.title(prodString+"\nReduced $\chi^2$ for Individual Calo Wiggle Plots")
plt.legend()
plt.show()
# Out:
# <>:7: DeprecationWarning: invalid escape sequence \c

# %% [raw]
# Now lets implement some of Kim's suggestions, starting with:
#     "FFT of raw wiggle plot, FFT of residual of 5-par-fit, for each calo"
#
# Why? Because it's easiest.

# %%
print(caloiWiggleVec)
caloiResidVec = []

for i in range(24):
    caloNum = i+1
    c = r.TCanvas()
    caloiWiggleVec[i].Draw("goff")
    funci = caloiWiggleVec[i].GetFunction("func")
    #c.Draw()
    
#    print("tau = ",funci.GetParameter(1), "for calo", caloNum)
    residuals5paramCaloi = caloiWiggleVec[i].Clone()
    nBins = residuals5paramCaloi.GetSize() - 2
#    print("    ", nbins , "bins" )
    for bini in range(int(nBins) ):
        binCenterX = caloiWiggleVec[i].GetXaxis().GetBinCenter(bini)
        if (binCenterX > 30):
            residuals5paramCaloi.SetBinContent(bini, caloiWiggleVec[i].GetBinContent(bini) - funci.Eval(binCenterX))
        else:
            residuals5paramCaloi.SetBinContent(bini, 0)
            
    residuals5paramCaloi.Draw("HIST P0 L")
#    c.Draw()
    
    hxformRaw = r.TH1D()
    hxformRaw = 0
    r.TVirtualFFT.SetTransform(0)
    hxformRaw = caloiWiggleVec[i].FFT(hxform,"MAG P")
    hxformRaw.SetTitle("Magnitude of the First Transform (Raw Wiggle) for Calo "+str(caloNum))
    #NOTE: for "real" frequencies you have to divide the x-axes range with the range of your function
    #    y-axes has to be rescaled by a factor of 1/SQRT(n) to be right: this is not done automatically!
    normXform = hxformRaw.GetEntries()
    hxformRaw.Scale(1/normXform)
    c2 = r.TCanvas()
    c2.cd()
    #c2.SetLogy()
    hxformRaw.GetXaxis().SetTitle("Frequency (MHz)")
    hxformRaw.GetYaxis().SetTitle("Arb. Units")
    hxformRaw.Draw("HIST P0 L")
#    c2.Draw()
    
    hxform = r.TH1D()
    hxform = 0
    r.TVirtualFFT.SetTransform(0)
    hxform = residuals5paramCaloi.FFT(hxform,"MAG P")
    hxform.SetTitle("Magnitude of the First Transform (5 Parameter Residuals) for Calo "+str(caloNum))
    #NOTE: for "real" frequencies you have to divide the x-axes range with the range of your function
    #    y-axes has to be rescaled by a factor of 1/SQRT(n) to be right: this is not done automatically!
    normXform = hxform.GetEntries()
    hxform.Scale(1/normXform)
    c2 = r.TCanvas()
    c2.cd()
    #c2.SetLogy()
    hxform.GetXaxis().SetTitle("Frequency (MHz)")
    hxform.GetYaxis().SetTitle("Arb. Units")
    hxform.Draw("HIST P0 L")
#    c2.Draw()

    Npart = residuals5paramCaloi.GetSize() - 2
    minBinCenter = residuals5paramCaloi.GetXaxis().GetBinCenter(0)
    maxBinCenter = residuals5paramCaloi.GetXaxis().GetBinCenter(Npart)

    capT = maxBinCenter - minBinCenter
#    print(Npart, capT, minBinCenter, maxBinCenter)
    deltaT = capT/Npart #microseconds
    deltaF = 1/capT
#    print(deltaT, deltaF)

    deltaTns = deltaT*1000 #nanoseconds
    limmaxHz = (1/(deltaTns*math.pow(10.0,-9)))
    limmaxMHz = limmaxHz / math.pow(10,6)

    limmax = 2*deltaF*Npart #400-25
#    print(limmax,limmaxMHz)
    nbins = residuals5paramCaloi.GetSize() - 2
    hxform.SetBins(Npart,0,limmaxMHz)
    hxform.GetXaxis().SetRangeUser(0,limmaxMHz/2)
    caloiResidVec.append( hxform.Clone() )
    
    hxformRaw.SetBins(Npart,0,limmaxMHz)
    hxformRaw.GetXaxis().SetRangeUser(0,limmaxMHz/2)
    
    caloiWiggleVec[i].GetXaxis().SetRangeUser(0,700)
    residuals5paramCaloi.GetXaxis().SetRangeUser(0,700)
    
    c3 = r.TCanvas("c3","c3",1200,1200)
    c3.Divide(2,2)
    c3.cd(1)
    caloiWiggleVec[i].Draw()
    r.gPad.SetLogy()    
    c3.cd(2)
    r.gPad.SetLogy()    
    hxformRaw.Draw("HIST P0 L")
    c3.cd(3)
    residuals5paramCaloi.SetTitle("5 Parameter Residuals Calo"+str(caloNum))
    residuals5paramCaloi.Draw("HIST P0 L")
    c3.cd(4)
    r.gPad.SetLogy()    
    hxform.Draw("HIST P0 L")
    c3.Draw()
    c3.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_Calo"+str(caloNum).zfill(2)+".png")
    c3.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_Calo"+str(caloNum).zfill(2)+".root")
# Out:
# [<ROOT.TH1D object ("calo01 Wiggle Plot") at 0x7fffe36e9680>, <ROOT.TH1D object ("calo02 Wiggle Plot") at 0x7fffe36d64e0>, <ROOT.TH1D object ("calo03 Wiggle Plot") at 0x7fffe36f6640>, <ROOT.TH1D object ("calo04 Wiggle Plot") at 0x7fffe36d1150>, <ROOT.TH1D object ("calo05 Wiggle Plot") at 0x7f4228737b10>, <ROOT.TH1D object ("calo06 Wiggle Plot") at 0x7f42217cec10>, <ROOT.TH1D object ("calo07 Wiggle Plot") at 0x7f4220c68d70>, <ROOT.TH1D object ("calo08 Wiggle Plot") at 0x7fffe395a790>, <ROOT.TH1D object ("calo09 Wiggle Plot") at 0x7f421bfed0a0>, <ROOT.TH1D object ("calo10 Wiggle Plot") at 0x7f421bfaea70>, <ROOT.TH1D object ("calo11 Wiggle Plot") at 0x7f421bfecc40>, <ROOT.TH1D object ("calo12 Wiggle Plot") at 0x7f421bfe31b0>, <ROOT.TH1D object ("calo13 Wiggle Plot") at 0x7fffe3996d20>, <ROOT.TH1D object ("calo14 Wiggle Plot") at 0x7f421ae9bb20>, <ROOT.TH1D object ("calo15 Wiggle Plot") at 0x7fffe39cc5a0>, <ROOT.TH1D object ("calo16 Wiggle Plot") at 0x7f421aed0fe0>, <ROOT.TH1D object ("calo17 Wiggle Plot") at 0x7f4219d7cc20>, <ROOT.TH1D object ("calo18 Wiggle Plot") at 0x7fffe39e06f0>, <ROOT.TH1D object ("calo19 Wiggle Plot") at 0x7f4219da7d20>, <ROOT.TH1D object ("calo20 Wiggle Plot") at 0x7fffe3a341b0>, <ROOT.TH1D object ("calo21 Wiggle Plot") at 0x7fffe3a606e0>, <ROOT.TH1D object ("calo22 Wiggle Plot") at 0x7fffe3a48af0>, <ROOT.TH1D object ("calo23 Wiggle Plot") at 0x7f42183e0290>, <ROOT.TH1D object ("calo24 Wiggle Plot") at 0x7fffe3a92810>]
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo01.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo01.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo02.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo02.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo03.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo03.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo04.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo04.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo05.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo05.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo06.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo06.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo07.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo07.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo08.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo08.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo09.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo09.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo10.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo10.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo11.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo11.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo12.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo12.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo13.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo13.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo14.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo14.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo15.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo15.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo16.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo16.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo17.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo17.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo18.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo18.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo19.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo19.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo20.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo20.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo21.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo21.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo22.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo22.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo23.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo23.root has been created
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: out_MAG P (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo24.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_Calo24.root has been created

# %%
c6 = r.TCanvas("c6","c6",1200,500)
leg = r.TLegend(0.65,0.65,0.9,0.9)
c6.cd()
for i, hist in enumerate(caloiResidVec):
    hist.SetLineColor(i+1)
    if(i>3):
        hist.SetLineColor(i+2)
    if(i>6):
        hist.SetLineStyle(2)
    if(i>7):
        hist.SetLineColor(i+40-12)
    if (i < 0.9):
        hist.SetTitle("Magnitude of the First Transform (5-Parameter Residuals) for Calos 1 - 24")
        hist.Draw("HIST P0 L")
    else:
        hist.Draw("HIST P0 L SAME")
    leg.AddEntry(hist ,"Calo "+str(i+1)+" FFT", "l")

leg.SetNColumns(3)
leg.Draw()
c6.Draw()
c6.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_all.root")
c6.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_all.png")

c7 = r.TCanvas("c7","c7",1200,500)
hsum = caloiResidVec[0].Clone()
for i in range(1,24):
    hsum.Add(caloiResidVec[i])
hsum.SetTitle("Sum of the Magnitude of the First Transform (5-Parameter Residuals) for Calos 1 - 24")
hsum.Draw("HIST P0 L")
c7.Draw()
c7.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_allSum.root")
c7.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_allSum.png")
# Out:
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_all.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_all.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_allSum.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_allSum.png has been created

# %% [markdown]
# Now lets compare the 5-parameter residuals from the 24 calos to those from the total.

# %%
c = r.TCanvas("c","c",1200,500)
leg = r.TLegend(0.65,0.8,0.9,0.9)

hsum.Draw("HIST P0 L")
hsum.GetYaxis().SetRangeUser(0.1,1000)
residuals5paramXform.SetLineColor(2)
residuals5paramXform.SetMarkerColor(2)
residuals5paramXform.Draw("HIST P0 L SAME")

leg.AddEntry(hsum,"Sum of the 24 Calorimeter FFT's",'l')
leg.AddEntry(residuals5paramXform,"FFT of the Total Wiggle Residuals",'l')
leg.Draw()
c.SetLogy()
c.Draw()
c.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_allSum_Comparison.root")
c.Print("./images/"+prodString+"/"+prodString+"_Residual5Param_allSum_Comparison.png")
# Out:
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_allSum_Comparison.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_Residual5Param_allSum_Comparison.png has been created

# %% [raw]
# Now we generate the plots which used to be part of f2, but now have been migrated into part of the original file to save time

# %% [raw]
# 1) normalized energy spectrum for different times like what Jason showed in his talk
#     (to catch noise pulses, every 10 T_a ~ 43.7 us will do) (edited)

# %%
for calo in range(1,25): 
    print("Starting calo", calo)
    c3 = r.TCanvas("c3","c3",4500,4500)
    c3.Divide(4,4)

    nDivs = 16
    for div in range(nDivs):
        c3.cd(div+1)
        r.gROOT.SetSelectedPad(r.gPad)
        
        #hi = f2.Get("energySpectrum_calo"+str(calo).zfill(2)+"_div"+str(div))
        hi = f.Get("farline").Get("calo"+str(calo)).Get("calo"+str(calo)+"TimeCut"+str(div)+"Energy")
        int2000_3000 = hi.Integral( hi.FindBin(2000), hi.FindBin(3000) )
        intTotal = hi.Integral()
        if(np.abs(int2000_3000) > 0):
            hi.Scale(1/int2000_3000)
            #hi.Scale(1/intTotal)
            
        hi.GetXaxis().SetRangeUser(0,4000)
        hi.GetYaxis().SetRangeUser(0.001,1)
        hi.SetFillColorAlpha(38,0.5)
        hi.Draw("HIST P0 L")

        r.gPad.SetLogy()
        
    c3.Draw()

    c3.Print("./images/"+prodString+"/"+prodString+"_energySpectrum_calo"+str(calo).zfill(2)+".png")
    c3.Print("./images/"+prodString+"/"+prodString+"_energySpectrum_calo"+str(calo).zfill(2)+".root")
# Out:
# Starting calo 1
# Starting calo 2
# Starting calo 3
# Starting calo 4
# Starting calo 5
# Starting calo 6
# Starting calo 7
# Starting calo 8
# Starting calo 9
# Starting calo 10
# Starting calo 11
# Starting calo 12
# Starting calo 13
# Starting calo 14
# Starting calo 15
# Starting calo 16
# Starting calo 17
# Starting calo 18
# Starting calo 19
# Starting calo 20
# Starting calo 21
# Starting calo 22
# Starting calo 23
# Starting calo 24
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo01.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo01.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo02.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo02.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo03.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo03.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo04.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo04.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo05.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo05.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo06.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo06.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo07.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo07.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo08.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo08.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo09.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo09.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo10.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo10.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo11.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo11.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo12.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo12.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo13.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo13.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo14.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo14.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo15.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo15.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo16.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo16.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo17.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo17.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo18.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo18.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo19.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo19.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo20.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo20.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo21.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo21.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo22.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo22.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo23.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo23.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo24.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_energySpectrum_calo24.root has been created

# %% [raw]
# 2) energy histogram for sync laser pulse cluster for each calo
#     (use time cut, like between 4000-6000 c.t. and energy cut, like > 40 GeV)

# %%
caloStdVec = []

for calo in range(1,25): 
    print("Starting calo", calo)
    c3 = r.TCanvas()

    #hi = f2.Get("laserEnergyPulse_calo"+str(calo).zfill(2))
    hi = f.Get("farline").Get("calo"+str(calo)).Get("laserSyncEnergies")
    hi.GetXaxis().SetTitle("Energy [MeV]")
    hi.Draw("HIST P0 L")
    
    #print("    Mean: ", hi.GetMean(), "and stdev: ", hi.GetStdDev())
    caloStdVec.append((calo, hi.GetMean(), hi.GetStdDev()))
        
    c3.SetLogy()
    c3.Draw()

    c3.Print("./images/"+prodString+"/"+prodString+"_laserEnergyPulse_calo"+str(calo).zfill(2)+".png")
    c3.Print("./images/"+prodString+"/"+prodString+"_laserEnergyPulse_calo"+str(calo).zfill(2)+".root")
    
print(caloStdVec)
# Out:
# Starting calo 1
# Starting calo 2
# Starting calo 3
# Starting calo 4
# Starting calo 5
# Starting calo 6
# Starting calo 7
# Starting calo 8
# Starting calo 9
# Starting calo 10
# Starting calo 11
# Starting calo 12
# Starting calo 13
# Starting calo 14
# Starting calo 15
# Starting calo 16
# Starting calo 17
# Starting calo 18
# Starting calo 19
# Starting calo 20
# Starting calo 21
# Starting calo 22
# Starting calo 23
# Starting calo 24
# [(1, 87347.09766077838, 1353.6141087531316), (2, 88713.6414331389, 1535.7830378111485), (3, 90470.65890989098, 1390.9667709596015), (4, 88463.74205843829, 1496.1342472909644), (5, 89137.4195433646, 1414.6690770497821), (6, 94541.52374010526, 1732.545919746671), (7, 89740.12181708156, 1258.2091448457302), (8, 84984.63554234173, 1323.3011548294612), (9, 102553.61276292415, 1651.16033483201), (10, 111647.17311946799, 1669.7986913104999), (11, 93231.5054583982, 1559.3128610251458), (12, 83754.33041417741, 1240.1557346530847), (13, 89245.54476099319, 1377.6037916965756), (14, 79307.76506562182, 1051.640178692851), (15, 95266.25884296479, 1656.0715148066545), (16, 70490.68629290858, 941.341633937952), (17, 70662.85561677314, 1084.0526068540894), (18, 77498.37354171195, 1322.4986451205143), (19, 78410.30966895612, 1378.0440560109678), (20, 79680.59437396201, 1249.1275254411762), (21, 88337.89111111379, 1963.2989600362584), (22, 76456.33845899493, 1629.642492054277), (23, 85816.08249040537, 1580.631102163498), (24, 84373.15103370165, 1524.3238337129574)]
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo01.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo01.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo02.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo02.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo03.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo03.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo04.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo04.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo05.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo05.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo06.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo06.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo07.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo07.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo08.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo08.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo09.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo09.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo10.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo10.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo11.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo11.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo12.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo12.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo13.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo13.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo14.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo14.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo15.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo15.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo16.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo16.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo17.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo17.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo18.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo18.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo19.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo19.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo20.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo20.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo21.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo21.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo22.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo22.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo23.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo23.root has been created
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo24.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_calo24.root has been created

# %%
calos, means, stds = zip(*caloStdVec)

fig, ax = plt.subplots(1,2, figsize=(15,5))
fig.tight_layout()
fig.subplots_adjust(wspace=.25)

ax[1].plot(calos,stds,'o:')
ax[1].set_ylabel("STDEV [MeV]")
ax[1].set_xlabel("Calo Number")
ax[1].set_title("STDEV For Laser Pulses in Various Calorimeters")
ax[1].grid()

ax[0].plot(calos,means,'o:')
ax[0].set_ylabel("Mean [MeV]")
ax[0].set_xlabel("Calo Number")
ax[0].set_title("Mean For Laser Pulses in Various Calorimeters")
ax[0].grid()

plt.savefig("./images/"+prodString+"/"+prodString+"_laserEnergyMeans_allcalo.png", bbox_inches='tight')
plt.show()

# %%
calos, means, stds = zip(*caloStdVec)

fig, ax = plt.subplots(figsize=(7,5))
fig.tight_layout()
#fig.subplots_adjust(wspace=.25)

plt.errorbar(x=calos,y=means,xerr=0,yerr=stds)
plt.ylabel("Mean [MeV]")
plt.xlabel("Calo Number")
plt.title("Mean For Laser Pulses in Various Calorimeters (With Error Bars)")

plt.show()

# %%
c3 = r.TCanvas("c3","c3",1800,1000)
leg = r.TLegend(0.7,0.72,0.9,0.9)
leg.SetNColumns(3)

for calo in range(1,25): 
    print("Starting calo", calo)

    hi.SetLineColor(calo-1)
    hi.SetLineWidth(3)
    if(calo>3):
        hi.SetLineColor(calo+2)
    if(calo>6):
        hi.SetLineStyle(2)
    if(calo>7):
        hi.SetLineColor(calo+40-12)
    
    hi = f.Get("farline").Get("calo"+str(calo)).Get("laserSyncEnergies")
    hi.SetDirectory(0)
    hi.GetXaxis().SetTitle("Energy [MeV]")
    hi.SetTitle("Laser Energy (All Calos)")
    hi.GetXaxis().SetRangeUser(50000,150000)
    if calo < 1.5:
        hi.Draw()
    else:
        hi.Draw("SAME")
        
    leg.AddEntry(hi ,"Calo "+str(calo), "l")

leg.Draw()

c3.SetLogy()
c3.Draw()
c3.Print("./images/"+prodString+"/"+prodString+"_laserEnergyPulse_allcalo.png")
c3.Print("./images/"+prodString+"/"+prodString+"_laserEnergyPulse_allcalo.root")
# Out:
# Starting calo 1
# Starting calo 2
# Starting calo 3
# Starting calo 4
# Starting calo 5
# Starting calo 6
# Starting calo 7
# Starting calo 8
# Starting calo 9
# Starting calo 10
# Starting calo 11
# Starting calo 12
# Starting calo 13
# Starting calo 14
# Starting calo 15
# Starting calo 16
# Starting calo 17
# Starting calo 18
# Starting calo 19
# Starting calo 20
# Starting calo 21
# Starting calo 22
# Starting calo 23
# Starting calo 24
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_allcalo.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_laserEnergyPulse_allcalo.root has been created

# %%
for calo in range(1,25):
    print("Starting calo", calo)
    c = r.TCanvas("c","c",4500,2000)
    c.Divide(4,2)
    for i in range(8):
        c.cd(i+1)
        hi = f.Get("farline").Get("calo"+str(calo)).Get("calo"+str(calo)+"EnergyCut"+str(i)+"Energy").Clone()
        hi.Rebin2D(1,1)
        hi.GetXaxis().SetTitle("x")
        hi.GetYaxis().SetTitle("y")
        r.gPad.SetLogz()
        r.gPad.SetRightMargin(0.15)
        hi.GetZaxis().SetRangeUser(1,100000)
        hi.Draw("COLZ")
    c.Draw()
    c.Print("./images/"+prodString+"/"+prodString+"_hitDistribution_calo"+str(calo).zfill(2)+".png")
    c.Print("./images/"+prodString+"/"+prodString+"_hitDistribution_calo"+str(calo).zfill(2)+".root")
# Out:
# Starting calo 1
# Starting calo 2
# Starting calo 3
# Starting calo 4
# Starting calo 5
# Starting calo 6
# Starting calo 7
# Starting calo 8
# Starting calo 9
# Starting calo 10
# Starting calo 11
# Starting calo 12
# Starting calo 13
# Starting calo 14
# Starting calo 15
# Starting calo 16
# Starting calo 17
# Starting calo 18
# Starting calo 19
# Starting calo 20
# Starting calo 21
# Starting calo 22
# Starting calo 23
# Starting calo 24
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo01.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo01.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo02.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo02.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo03.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo03.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo04.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo04.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo05.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo05.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo06.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo06.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo07.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo07.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo08.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo08.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo09.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo09.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo10.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo10.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo11.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo11.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo12.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo12.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo13.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo13.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo14.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo14.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo15.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo15.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo16.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo16.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo17.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo17.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo18.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo18.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo19.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo19.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo20.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo20.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo21.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo21.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo22.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo22.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo23.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo23.root has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo24.png has been created
# Info in <TCanvas::SaveAs>: ROOT file ./images/EndGame_5040A/EndGame_5040A_hitDistribution_calo24.root has been created
