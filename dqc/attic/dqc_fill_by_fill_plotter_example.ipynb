# %%
from si import *
# Out:
# Not a jupyter notebook. Not enabling notebook functions.
# Welcome to JupyROOT 6.20/04
# For interactive plots, run: setint()
# To return to non-interactive plots (default state), run: noint()

# %%
f = r.TFile("./data/gm2DQCtest_ana.root")
f.cd("DQCcheck")
f.ls()
# Out:
# TFile**		./data/gm2DQCtest_ana.root
#  TFile*		./data/gm2DQCtest_ana.root
#   TDirectoryFile*		DQCcheck	DQCcheck (DQCcheck) folder
#    KEY: TTree	dqc;1	dqc
#    KEY: TH2C	dqcHist;1	trigger_paths:["asyncPath","inFillLaserPath","inFillLaserPathWithDQC","inFillLaserPathWithKickerDQC","inFillLaserPathWithLaserDQC","inFillLaserPathWithT0DQC","laserPath","muonPath","muonPathWithDQC","muonPathWithKickerDQC","muonPathWithLaserDQC","muonPathWithT0DQC","pedestalPath","strawPath","strawPathWithDQC","strawPathWithKickerDQC","strawPathWithLaserDQC","strawPathWithT0DQC"]
#   KEY: TDirectoryFile	DQCcheck;1	DQCcheck (DQCcheck) folder

# %%
h = f.Get("DQCcheck/dqcHist").Clone()

# %%
t = f.Get("DQCcheck/dqc")
t.Print()
# Out:
# ******************************************************************************
# *Tree    :dqc       : dqc                                                    *
# *Entries :       10 : Total =            4926 bytes  File  Size =       1682 *
# *        :          : Tree compression factor =   1.28                       *
# ******************************************************************************
# *Br    0 :eventNum  : eventNum/i                                             *
# *Entries :       10 : Total  Size=        611 bytes  File Size  =        102 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.12     *
# *............................................................................*
# *Br    1 :bunchNum  : bunchNum/i                                             *
# *Entries :       10 : Total  Size=        611 bytes  File Size  =        102 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.12     *
# ...

# %%
c = r.TCanvas()
h.Draw("colz")
c.Draw()

# %%
c = r.TCanvas()
h.GetXaxis().SetRangeUser(26058,26060)
h.Draw("colz")
c.Draw()

# %%
c = r.TCanvas()
t.Draw("dqcPass:dqcName","","colz")
c.Draw()

# %%
c = r.TCanvas()
t.Draw("dqcName","dqcPass","colz")
c.Draw()

# %%
for i, e in enumerate(t):
    print(e.runNum, e.subRunNum, e.eventNum, e.dqcName, "\t\t\t", e.dqcPass)
# Out:
# 26059 104 2 "muonPath" 			 1
# 26059 104 2 "muonPathWithDQC" 			 0
# 26059 104 2 "muonPathWithKickerDQC" 			 0
# 26059 104 2 "muonPathWithLaserDQC" 			 1
# 26059 104 2 "muonPathWithT0DQC" 			 1
# 26059 104 4 "muonPath" 			 1
# 26059 104 4 "muonPathWithDQC" 			 1
# 26059 104 4 "muonPathWithKickerDQC" 			 1
# 26059 104 4 "muonPathWithLaserDQC" 			 1
# 26059 104 4 "muonPathWithT0DQC" 			 1
